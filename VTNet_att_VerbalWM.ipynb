# %% [markdown]
# <a href="https://colab.research.google.com/github/ethanwongca/hai_work/blob/main/VTNet_att_VerbalWM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
BASE_DIR = "/content/drive/My Drive/msnv_data/VTNet_att/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import random
import shutil
import math

import torch
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets
import matplotlib.pyplot as plt
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch import autograd

from PIL import Image

import numpy as np
import pickle
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
import sys
sys.path.append("/content/drive/My Drive/msnv_data/VTNet_att/")
import utils

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

BATCH_SIZE=4
MANUAL_SEED = 1
HIDDEN_SIZE = 256
INPUT_SIZE=6
utils.INPUT_SIZE = INPUT_SIZE

# %%
transform = transforms.Compose(
    [transforms.Resize((150,150)),
     transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# %%
class VTNet(nn.Module):
    def __init__(self,
                 input_size=6,
                 rnn_hidden_size=256,
                 output_size=2,
                 batch_size=4,
                 rnn_type='gru',
                 rnn_num_layers=1,
                 n_channels_1=6,
                 kernel_size_1=5,
                 n_channels_2=16,
                 kernel_size_2=5,
                 img_n_vert=150,
                 img_n_hor=150):
        """

        Args:
            input_size (int):
            hidden_size (int):
            output_size (int):
            batch_size (int):
            rnn_type (int):
            num_layers (int):
        """
        super(VTNet, self).__init__()

        self.n_channels_2 = n_channels_2


        # CNN portion
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=n_channels_1, kernel_size=kernel_size_1, stride=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(in_channels=n_channels_1, out_channels=n_channels_2, kernel_size=kernel_size_2, stride=1)
        # output size calculations
        self.conv1_out_vert = img_n_vert - kernel_size_1 + 1
        self.conv1_out_hor = img_n_hor - kernel_size_1 + 1
        self.mp1_out_vert = int(np.floor((self.conv1_out_vert - 2)/2) + 1)
        self.mp1_out_hor = int(np.floor((self.conv1_out_hor - 2) / 2) + 1)
        self.conv2_out_vert = self.mp1_out_vert - kernel_size_2 + 1
        self.conv2_out_hor = self.mp1_out_hor - kernel_size_2 + 1
        self.mp2_out_vert = int(np.floor((self.conv2_out_vert - 2)/2) + 1)
        self.mp2_out_hor = int(np.floor((self.conv2_out_hor - 2) / 2) + 1)
        self.fc1 = nn.Linear(n_channels_2 * self.mp2_out_hor * self.mp2_out_vert, 50)
        self.fc2 = nn.Linear(rnn_hidden_size + 50, 20)
        self.fc3 = nn.Linear(20, output_size)

        # RNN portion
        self.multihead_attn1 = nn.MultiheadAttention(embed_dim=6, num_heads=1)
        #self.multihead_attn2 = nn.MultiheadAttention(embed_dim=256, num_heads=1)
        self.rnn_type = rnn_type
        self.input_size = input_size
        self.rnn_hidden_size = rnn_hidden_size
        self.output_size = output_size
        self.batch_size = batch_size
        self.rnn_num_layers = rnn_num_layers



        if rnn_type == 'gru':
            self.rnn = nn.GRU(input_size=input_size, hidden_size=rnn_hidden_size,
                              num_layers=rnn_num_layers)
        elif rnn_type == 'lstm':
            self.rnn = nn.LSTM(input_size=input_size, hidden_size=rnn_hidden_size,
                               num_layers=rnn_num_layers)
        else:
            self.rnn = nn.RNN(input_size=input_size, hidden_size=rnn_hidden_size,
                              num_layers=rnn_num_layers)

        self.out = nn.Linear(rnn_hidden_size, output_size)

    def forward(self, scan_path, time_series, hidden):
        """
            Args:
                scan_path (torch.Tensor): must be 349x231 for now
                time_series (torch.Tensor):
            Returns:
                x (float): logit for confusion prediction - requires cross entropy loss
        """
        x1 = self.pool(F.relu(self.conv1(scan_path)))
        x1 = self.pool(F.relu(self.conv2(x1)))
        x1 = x1.view(-1, self.n_channels_2 * self.mp2_out_hor * self.mp2_out_vert)
        x1 = F.relu(self.fc1(x1))

        # change input shape to (max_seq_size, batch_size, input_features):
        x2 = time_series.permute(1, 0, 2)
        x2, _ = self.multihead_attn1(x2, x2, x2, need_weights=False)
        x2, hidden = self.rnn(x2, hidden)
        #x2, _ = self.multihead_attn2(x2, x2, x2, need_weights=False)
        x2 = x2[-1, :, :]  # take only the last output

        x = torch.cat((x1, x2), 1)
        x = F.relu(self.fc2(x))
        x = self.fc3(x)

        return x

    def init_hidden(self, batch_size):
        """ Initializes the hidden state with zero tensors.
        """
        if self.rnn_type == 'lstm':
            return (autograd.Variable(torch.zeros(self.rnn_num_layers, batch_size, self.rnn_hidden_size)).double().to(device),
                    autograd.Variable(torch.zeros(self.rnn_num_layers, batch_size, self.rnn_hidden_size)).double().to(device))
        else:
            return autograd.Variable(torch.zeros(self.rnn_num_layers, batch_size, self.rnn_hidden_size)).double().to(device)


def st_pickle_loader(input_file_path, max_length=1000):
    """ Processes a raw data item into a scan path image and a time series
        for input into a STNet.

        Args:
            input_file_name (string): the name of the data item to be loaded
            max_length (int): max number of samples to use for a given item.
                If -1, use all samples
        Returns:
            item (numpy.ndarray): the fully processed data item for RNN input
            item_sp (PIL Image):

    """
    # Example of input_file_path = D:\Canary\multimodal-dl-framework
    # \dataset\alzheimer\tasks\cookie_theft\modalities\preprocessed\sequences
    # \eye_tracking\augmented\0_control\something.pkl

    transform = transforms.Compose([transforms.Resize((150,150)),
                                    transforms.ToTensor(),
                                    transforms.Normalize((0.5, 0.5, 0.5, 0.5), (0.5, 0.5, 0.5, 0.5))])

    """
    0 GazePointLeftX (ADCSpx)
    1 GazePointLeftY (ADCSpx)
    2 GazePointRightX (ADCSpx)
    3 GazePointRightY (ADCSpx)
    4 GazePointX (ADCSpx)
    5 GazePointY (ADCSpx)
    6 GazePointX (MCSpx)
    7 GazePointY (MCSpx)
    8 GazePointLeftX (ADCSmm)
    9 GazePointLeftY (ADCSmm)
    10 GazePointRightX (ADCSmm)
    11 GazePointRightY (ADCSmm)
    12 DistanceLeft
    13 DistanceRight
    14 PupilLeft
    15 PupilRight
    16 FixationPointX (MCSpx)
    17 FixationPointY (MCSpx)
    18 FixationLength
    """

    file = open(input_file_path, 'rb')
    item = pickle.load(file)
    item = item.values
    item[:,0] = (item[:,0] + item[:,2])/2 #column 0 is now ave Gx
    item[:,1] = (item[:,1] + item[:,3])/2 #column 1 is now ave Gy
    item = item[item[:,0] > 0]
    item = abs(item)
    item[item == 1.0] = -1.0
    item = item[:,[0, 1, 12, 13, 14, 15]] # drop all but Gx average, Gy average, Left eye distance, left eye pupil, right eye distance, right eye pupil

    if len(item) == 0:
        item = np.zeros((1000, 6))
    else:
        if max_length != -1:
            item = item[-max_length:,:]
            if len(item) < max_length:
                num_zeros_to_pad = (max_length)-len(item)
                item = np.append(np.zeros((num_zeros_to_pad, len(item[0]))), item, axis=0)
    file.close()

    # input_filepath_example: r"D:\Canary\dataset\augmented\train2\patient\Gaze_HE-224-4.pkl"
    filename = input_file_path.split(os.sep)[-1].split('.')[0]
    category = input_file_path.split(os.sep)[-3]

    #check high low
    path_to_sp = os.path.join(BASE_DIR, "msnv_final_data", TASK, "high", "images", filename + '.png')

    # Check if the file exists, if not, try "low"
    if not os.path.exists(path_to_sp):
        path_to_sp = os.path.join(BASE_DIR, "msnv_final_data", TASK, "low", "images", filename + '.png')

    im = Image.open(path_to_sp)
    item_sp = transform(im)[0:3,:,:]
    return item, item_sp

# %% [markdown]
# # Cookie_theft

# %%
TASK = "VerbalWM_label"

# %%
def cross_validate( model_type,
                    folds,
                    epochs,
                    criterion_type,
                    optimizer_type,
                    confused_path,
                    not_confused_path,
                    print_every,
                    plot_every,
                    hidden_size,
                    num_layers,
                    down_sample_training=False,
                    learning_rate=0.0001,
                    path_to_data_split = os.path.join(BASE_DIR, "verbal_wm.pickle"),
                    verbose=False,
                   patience=3
                  ):
    """
        Perform Cross Validation of the model using k-folds.

        Args:
            model_type (string): the type of RNN to use. Must be 'lstm', 'gru', or 'rnn'
            epochs (int): the max number of epochs to train the model for each fold
            criterion_type (string): the name loss function to use for training. Currently must be 'NLLLoss'
            optimizer_type (string): the name of learning algorithm to use for training. ex 'Adam'
            confused_path (string): the path to the folder containing the confused data samples
            not_confused_path (string): the path to the folder containing the not_confused data samples
            print_every (int): the number of batches to train for before printing relevant stats
            plot_every (int): the number of batches to train for before recording relevant stats, which
                will be plotted after each fold
            hidden_size (int): the number of hidden units for each layer of the RNN
            num_layers (int): the number of hidden_unit sized layers of the RNN
            down_sample_training (boolean): if True training set will be balanced by down sampling not_confused
            learning_rate (float): the first learning rate to be used by the optimizer
            path_to_data_split (string): relative path to the file containing the item names for each CV fold
            verbose (boolean): if True, function will print additional stats

        Returns: (list,list,list,list,list)
            cv_val_sens (list): list containing the validation sensitivity for each fold
            cv_val_spec (list): list containing the validation specificity for each fold
            cv_test_combined (list): list containing the combined test accuracy for each fold
    """

    #ensure same items appear in folds, for reproducibility:
    infile = open(path_to_data_split,'rb')
    split = pickle.load(infile)
    infile.close()

    train_confused_splits = split[0]
    test_confused_splits = split[1]
    train_not_confused_splits = split[2]
    test_not_confused_splits = split[3]


    cv_test_sens = []
    cv_test_spec = []
    cv_test_combined = []
    cv_auc = []

    for k in range(folds):
        print("\nFold ", k+1)
        # Get data item file names for this fold and downsample not_confused to balance training set
        train_confused, \
        train_not_confused, \
        val_confused, \
        val_not_confused = \
        utils.get_train_val_split(train_confused_splits[k],
                                  train_not_confused_splits[k],
                                  percent_val_set=0.2)

        if down_sample_training:
            if len(train_not_confused) > len(train_confused):
                train_not_confused = random.sample(train_not_confused, k=(len(train_confused)))
            elif len(train_confused) > len(train_not_confused):
                train_confused = random.sample(train_confused, k=(len(train_not_confused)))

        test_confused = test_confused_splits[k]
        test_not_confused = test_not_confused_splits[k]

        if verbose:
            print("Patient items in training set: ", len(train_confused))
            print("Control items in training set: ", len(train_not_confused))
            print("Patient items in validation set: ", len(val_confused))
            print("Control items in validation set: ", len(val_not_confused))

        if verbose:
            print("\nTest patient items:\n")
            print(test_confused)

        local_train_confused_path = os.path.join(BASE_DIR, 'dataset/augmented_verb/train_cookie_theft/patient/')
        local_val_confused_path = os.path.join(BASE_DIR, 'dataset/augmented_verb/val_cookie_theft/patient/')
        local_test_confused_path = os.path.join(BASE_DIR, 'dataset/augmented_verb/test_cookie_theft/patient/')
        local_train_not_confused_path = os.path.join(BASE_DIR, 'dataset/augmented_verb/train_cookie_theft/control/')
        local_val_not_confused_path = os.path.join(BASE_DIR, 'dataset/augmented_verb/val_cookie_theft/control/')
        local_test_not_confused_path = os.path.join(BASE_DIR, 'dataset/augmented_verb/test_cookie_theft/control/')

        # Remove any old directories
        if os.path.exists(local_train_confused_path):
            shutil.rmtree(local_train_confused_path)
        if os.path.exists(local_val_confused_path):
            shutil.rmtree(local_val_confused_path)
        if os.path.exists(local_test_confused_path):
            shutil.rmtree(local_test_confused_path)

        if os.path.exists(local_train_not_confused_path):
            shutil.rmtree(local_train_not_confused_path)
        if os.path.exists(local_val_not_confused_path):
            shutil.rmtree(local_val_not_confused_path)
        if os.path.exists(local_test_not_confused_path):
            shutil.rmtree(local_test_not_confused_path)

        # Make new temp directories
        os.makedirs(local_train_confused_path)
        for i in train_confused:
            shutil.copy(src=confused_path+i,dst=local_train_confused_path+i)

        os.makedirs(local_val_confused_path)
        for i in val_confused:
            shutil.copy(src=confused_path+i,dst=local_val_confused_path+i)

        os.makedirs(local_test_confused_path)
        for i in test_confused:
            shutil.copy(src=confused_path+i,dst=local_test_confused_path+i)

        os.makedirs(local_train_not_confused_path)
        for i in train_not_confused:
            shutil.copy(src=not_confused_path+i,dst=local_train_not_confused_path+i)

        os.makedirs(local_val_not_confused_path)
        for i in val_not_confused:
            shutil.copy(src=not_confused_path+i,dst=local_val_not_confused_path+i)

        os.makedirs(local_test_not_confused_path)
        for i in test_not_confused:
            shutil.copy(src=not_confused_path+i,dst=local_test_not_confused_path+i)

        # Prepare training and validation data
        trainset = datasets.DatasetFolder(os.path.join(BASE_DIR, 'dataset/augmented_verb/train_cookie_theft'),
                                               loader=st_pickle_loader,
                                               extensions='.pkl')

        valset = datasets.DatasetFolder(os.path.join(BASE_DIR, 'dataset/augmented_verb/val_cookie_theft'),
                                                 loader=st_pickle_loader,
                                                 extensions='.pkl')

        testset = datasets.DatasetFolder(os.path.join(BASE_DIR, 'dataset/augmented_verb/test_cookie_theft'),
                                                 loader=st_pickle_loader,
                                                 extensions='.pkl')


        trainloader = torch.utils.data.DataLoader(trainset, batch_size=4, shuffle=True, drop_last=True)

        testloader = torch.utils.data.DataLoader(testset, batch_size=4, shuffle=True, drop_last=True)


        valloader = torch.utils.data.DataLoader(valset, batch_size=4, shuffle=True, drop_last=True)

        print("Training data: ", trainset)
        print("Validation data: ", valset)
        print("Test data: ", testset)

        torch.manual_seed(MANUAL_SEED)
        if model_type == 'gru':
            model = VTNet(rnn_type='gru', rnn_num_layers=num_layers, rnn_hidden_size=hidden_size).double().to(device)
        elif model_type == 'lstm':
            model = VTNet(rnn_type='lstm', rnn_num_layers=num_layers, rnn_hidden_size=hidden_size).double().to(device)
        else:
            model = VTNet(rnn_type='rnn', rnn_num_layers=num_layers, rnn_hidden_size=hidden_size).double().to(device)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        #save fresh model to clear any old ones out
        torch.save(model.state_dict(), './best_STNet_fold_pd_'+str(k) +'.pt')
        best_val_combined = 0.0
        #Train model
        epochs_without_improvement = 0
        for epoch in range(epochs):  # loop over the dataset multiple times
            running_loss = 0.0
            epoch_loss = 0.0
            for i, data in enumerate(trainloader, 0):
                # get the inputs; data is a list of [inputs, labels]
                inputs, labels = data
                item, item_sp = inputs[0].double(), inputs[1].double()
                item, item_sp, labels = item.to(device), item_sp[:,0,:,:].unsqueeze(1).to(device), labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()
                hidden = model.init_hidden(BATCH_SIZE)
                # forward + backward + optimize
                outputs = model(scan_path=item_sp, time_series=item, hidden=hidden)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()

                # print statistics
                running_loss += loss.item()
                epoch_loss += loss.item()
                if i % 10 == 0:
                    print('[%d, %5d] loss: %.5f' %
                          (epoch + 1, i + 1, running_loss / 10))
                    running_loss = 0.0
            print('epoch %d average training loss: %.5f' % (epoch + 1, epoch_loss/ len(trainloader)))

            #check validation set metrics
            running_val_loss = 0.0
            y_true = torch.zeros((len(valloader)*4))
            y_scores = torch.zeros((len(valloader)*4, 2))
            with torch.no_grad():

                for i, data in enumerate(valloader, 0):
                    # get the inputs; data is a list of [inputs, labels]
                    inputs, labels = data
                    item, item_sp = inputs[0].double(), inputs[1].double()
                    item, item_sp, labels = item.to(device), item_sp[:,0,:,:].unsqueeze(1).to(device), labels.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()
                    hidden = model.init_hidden(BATCH_SIZE)
                    # forward + backward + optimize
                    outputs = model(scan_path=item_sp, time_series=item, hidden=hidden)
                    loss = criterion(outputs, labels)
                    running_val_loss += loss.item()
                    #keep track of predictions
                    num_items = outputs.shape[0]
                    y_true[i*num_items: i*num_items + num_items] = labels
                    y_scores[i*num_items: i*num_items + num_items, :] = outputs.squeeze()

                val_loss = running_val_loss/ len(valloader)
                print('epoch %d average val loss: %.5f' % (epoch + 1, val_loss))

                #check metrics:
                # no option to specify positive label, so flipping for confused=1
                y_true_flipped = np.array(y_true.numpy(), copy=True)
                y_true_flipped[y_true == 1] = 0
                y_true_flipped[y_true == 0] = 1
                #auc = roc_auc_score(y_true_flipped, y_scores.numpy()[:,0])
                # roc_curve expects y_scores to be probability values of the positive class
                fpr, tpr, thresholds = roc_curve(y_true, y_scores.numpy()[:,0], pos_label=0)

                sensitivity, specificity, \
                accuracy = utils.optimal_threshold_sensitivity_specificity(thresholds[1:],
                                                                           tpr[1:],
                                                                           fpr[1:],
                                                                           y_true,
                                                                           y_scores.numpy()[:,0])
                combined = (sensitivity + specificity ) / 2.0
                print("epoch %d validation sens. : %.5f, spec. : %.5f; combined: %.5f"
                      % (epoch + 1, sensitivity, specificity, combined))
                if combined > best_val_combined:
                    print("New best validation combined accuracy found. Saving model...")
                    best_val_combined = combined
                    torch.save(model.state_dict(), './best_base_STNet_fold_pd_'+str(k) +'.pt')
                    epochs_without_improvement = 0
                else:
                    epochs_without_improvement = epochs_without_improvement + 1

                print("\n Epochs without improvement = ", epochs_without_improvement)

            if epochs_without_improvement == patience:
                print("\n Stopped training because {} epochs without improvement. . .".format(patience))
                break

        y_true = torch.tensor([]).to(device)
        y_scores = torch.tensor([]).to(device)
        with torch.no_grad():
            model.load_state_dict(torch.load('./best_base_STNet_fold_pd_'+str(k) +'.pt', map_location=device))
            for i, data in enumerate(testloader, 0):
                # get the inputs; data is a list of [inputs, labels]
                inputs, labels = data
                item, item_sp = inputs[0].double(), inputs[1].double()
                item, item_sp, labels = item.to(device), item_sp[:,0,:,:].unsqueeze(1).to(device), labels.to(device)
                # zero the parameter gradients
                optimizer.zero_grad()
                hidden = model.init_hidden(BATCH_SIZE)
                # forward + backward + optimize
                outputs = model(scan_path=item_sp, time_series=item, hidden=hidden)
                loss = criterion(outputs, labels)
                running_val_loss += loss.item()
                #keep track of predictions
                num_items = outputs.shape[0]
                y_true = torch.cat((y_true, labels))
                y_scores = torch.cat((y_scores,outputs.squeeze()))
                #y_true[i*num_items: i*num_items + num_items] = labels
                #y_scores[i*num_items: i*num_items + num_items, :] = outputs.squeeze()

            #y_pred = torch.argmax(y_scores, axis=1)

            #check metrics:
            # no option to specify positive label, so flipping for confused=1
            y_true = y_true.cpu()
            y_scores = y_scores.cpu()
            y_true_flipped = np.array(y_true.numpy(), copy=True)
            y_true_flipped[y_true == 1] = 0
            y_true_flipped[y_true == 0] = 1
            auc = roc_auc_score(y_true_flipped, y_scores.numpy()[:,0])
            # roc_curve expects y_scores to be probability values of the positive class
            fpr, tpr, thresholds = roc_curve(y_true, y_scores.numpy()[:,0], pos_label=0)

            sensitivity, specificity, \
            accuracy = utils.optimal_threshold_sensitivity_specificity(thresholds[1:],
                                                                       tpr[1:],
                                                                       fpr[1:],
                                                                       y_true,
                                                                       y_scores.numpy()[:,0])
            combined = (sensitivity + specificity ) / 2.0

            print("Test set sens. : %.5f, spec. : %.5f, combined: %.5f, auc: %.5f" % (sensitivity, specificity, combined, auc))
            cv_test_sens.append(sensitivity)
            cv_test_spec.append(specificity)
            cv_test_combined.append(combined)
            cv_auc.append(auc)

    print("\n Average 10-fold CV test sensitivity: %.5f, specificity: %.5f, combined: %.5f, AUC: %.5f" %
          ((sum(cv_test_sens)/len(cv_test_sens)),
           (sum(cv_test_spec)/len(cv_test_spec)),
           (sum(cv_test_combined)/len(cv_test_combined)),
           (sum(cv_auc)/len(cv_auc))))
    return cv_test_sens, cv_test_spec, cv_test_combined, cv_auc

# %%
# compute for 10 different seeds
sens = []
spec = []
comb = []
auc = []


for i in range(1):
# baseline 10-fold CV with GRU
    np.random.seed(MANUAL_SEED+i)
    random.seed(MANUAL_SEED+i)
    torch.manual_seed(MANUAL_SEED+i)

    sens_list, spec_list, comb_list, auc_list = cross_validate(model_type='gru',
                                               folds=10,
                                               epochs=100,
                                               criterion_type='NLLLoss',
                                               optimizer_type='Adam',
                                               confused_path=os.path.join(
    BASE_DIR, "msnv_final_data",
    TASK, "high/pickle_files/"
),
                                               not_confused_path=os.path.join(
    BASE_DIR, "msnv_final_data",
    TASK, "low/pickle_files/"
),
                                               print_every=1,
                                               plot_every=1,
                                               hidden_size=HIDDEN_SIZE,
                                               down_sample_training=False,
                                               num_layers=1,
                                               learning_rate=0.0001,
                                               verbose=True)
    # add mean of each measure for 10-fold CV to list
    sens.append(np.mean(sens_list))
    spec.append(np.mean(spec_list))
    comb.append(np.mean(comb_list))
    auc.append(np.mean(auc_list))

print("sensitivities: ", sens)
print("specificities: ", spec)
print("combined: ", comb)
print("auc: ", auc)

print("average sensitivity: ", np.mean(sens))
print("average specificity: ", np.mean(spec))
print("average combined: ", np.mean(comb))
print("average auc: ", np.mean(auc))
# Out:
# Fold  1
# Patient items in training set:  217
# Control items in training set:  151
# Patient items in validation set:  43
# Control items in validation set:  49
#
# Test patient items:
#
# ['bar_46_1.pkl', 'bar_46_2.pkl', 'bar_46_3.pkl', 'bar_46_4.pkl', 'ctrl_18_1.pkl', 'ctrl_18_2.pkl', 'ctrl_18_3.pkl', 'ctrl_18_4.pkl', 'ctrl_58_1.pkl', 'ctrl_58_2.pkl', 'ctrl_58_3.pkl', 'ctrl_58_4.pkl', 'ctrl_68_1.pkl', 'ctrl_68_2.pkl', 'ctrl_68_3.pkl', 'ctrl_68_4.pkl', 'ctrl_97_1.pkl', 'ctrl_97_2.pkl', 'ctrl_97_3.pkl', 'ctrl_97_4.pkl', 'link_34_1.pkl', 'link_34_2.pkl', 'link_34_3.pkl', 'link_34_4.pkl']
# Training data:  Dataset DatasetFolder
#     Number of datapoints: 368
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented_verb/train_cookie_theft
# Validation data:  Dataset DatasetFolder
#     Number of datapoints: 92
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented_verb/val_cookie_theft
# Test data:  Dataset DatasetFolder
#     Number of datapoints: 52
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented_verb/test_cookie_theft
# [1,     1] loss: 0.06864
# [1,    11] loss: 0.69914
# [1,    21] loss: 0.69545
# [1,    31] loss: 0.69393
# [1,    41] loss: 0.68199
# [1,    51] loss: 0.67039
# [1,    61] loss: 0.64327
# [1,    71] loss: 0.61244
# [1,    81] loss: 0.70147
# [1,    91] loss: 0.70617
# epoch 1 average training loss: 0.67727
# epoch 1 average val loss: 0.70862
# epoch 1 validation sens. : 0.63265, spec. : 0.53488; combined: 0.58377
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [2,     1] loss: 0.08368
# [2,    11] loss: 0.63836
# [2,    21] loss: 0.67485
# [2,    31] loss: 0.64959
# [2,    41] loss: 0.69521
# [2,    51] loss: 0.62591
# [2,    61] loss: 0.65381
# [2,    71] loss: 0.63619
# [2,    81] loss: 0.65951
# [2,    91] loss: 0.65522
# epoch 2 average training loss: 0.65647
# epoch 2 average val loss: 0.69944
# epoch 2 validation sens. : 0.73469, spec. : 0.53488; combined: 0.63479
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [3,     1] loss: 0.07381
# [3,    11] loss: 0.59032
# [3,    21] loss: 0.68585
# [3,    31] loss: 0.64144
# [3,    41] loss: 0.61283
# [3,    51] loss: 0.62348
# [3,    61] loss: 0.65951
# [3,    71] loss: 0.66720
# [3,    81] loss: 0.61897
# [3,    91] loss: 0.62585
# epoch 3 average training loss: 0.63745
# epoch 3 average val loss: 0.68638
# epoch 3 validation sens. : 0.83673, spec. : 0.60465; combined: 0.72069
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [4,     1] loss: 0.06986
# [4,    11] loss: 0.61042
# [4,    21] loss: 0.59792
# [4,    31] loss: 0.60618
# [4,    41] loss: 0.62152
# [4,    51] loss: 0.59114
# [4,    61] loss: 0.58779
# [4,    71] loss: 0.63621
# [4,    81] loss: 0.56570
# [4,    91] loss: 0.58231
# epoch 4 average training loss: 0.60063
# epoch 4 average val loss: 0.64690
# epoch 4 validation sens. : 0.67347, spec. : 0.74419; combined: 0.70883
#
#  Epochs without improvement =  1
# [5,     1] loss: 0.04923
# [5,    11] loss: 0.56351
# [5,    21] loss: 0.50752
# [5,    31] loss: 0.50342
# [5,    41] loss: 0.57753
# [5,    51] loss: 0.56142
# [5,    61] loss: 0.45592
# [5,    71] loss: 0.55567
# [5,    81] loss: 0.56946
# [5,    91] loss: 0.50049
# epoch 5 average training loss: 0.53054
# epoch 5 average val loss: 0.68357
# epoch 5 validation sens. : 0.73469, spec. : 0.81395; combined: 0.77432
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [6,     1] loss: 0.03148
# [6,    11] loss: 0.52552
# [6,    21] loss: 0.40768
# [6,    31] loss: 0.39109
# [6,    41] loss: 0.42046
# [6,    51] loss: 0.35718
# [6,    61] loss: 0.46905
# [6,    71] loss: 0.47597
# [6,    81] loss: 0.38376
# [6,    91] loss: 0.38948
# epoch 6 average training loss: 0.42401
# epoch 6 average val loss: 0.57406
# epoch 6 validation sens. : 0.81633, spec. : 0.74419; combined: 0.78026
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [7,     1] loss: 0.04305
# [7,    11] loss: 0.35646
# [7,    21] loss: 0.27764
# [7,    31] loss: 0.30283
# [7,    41] loss: 0.34568
# [7,    51] loss: 0.24375
# [7,    61] loss: 0.31460
# [7,    71] loss: 0.33060
# [7,    81] loss: 0.21167
# [7,    91] loss: 0.31992
# epoch 7 average training loss: 0.30022
# epoch 7 average val loss: 0.47683
# epoch 7 validation sens. : 0.77551, spec. : 0.81395; combined: 0.79473
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [8,     1] loss: 0.01480
# [8,    11] loss: 0.25765
# [8,    21] loss: 0.20071
# [8,    31] loss: 0.14850
# [8,    41] loss: 0.34436
# [8,    51] loss: 0.24378
# [8,    61] loss: 0.22125
# [8,    71] loss: 0.15929
# [8,    81] loss: 0.20360
# [8,    91] loss: 0.20129
# epoch 8 average training loss: 0.21760
# epoch 8 average val loss: 0.52408
# epoch 8 validation sens. : 0.81633, spec. : 0.81395; combined: 0.81514
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [9,     1] loss: 0.02412
# [9,    11] loss: 0.18019
# [9,    21] loss: 0.16331
# [9,    31] loss: 0.13677
# [9,    41] loss: 0.14623
# [9,    51] loss: 0.11787
# [9,    61] loss: 0.14388
# [9,    71] loss: 0.20106
# [9,    81] loss: 0.12132
# [9,    91] loss: 0.13316
# epoch 9 average training loss: 0.14928
# epoch 9 average val loss: 0.45216
# epoch 9 validation sens. : 0.79592, spec. : 0.81395; combined: 0.80494
#
#  Epochs without improvement =  1
# [10,     1] loss: 0.00392
# [10,    11] loss: 0.14720
# [10,    21] loss: 0.11402
# [10,    31] loss: 0.07361
# [10,    41] loss: 0.07492
# [10,    51] loss: 0.06928
# [10,    61] loss: 0.11487
# [10,    71] loss: 0.06038
# [10,    81] loss: 0.10411
# [10,    91] loss: 0.11678
# epoch 10 average training loss: 0.09651
# epoch 10 average val loss: 0.44522
# epoch 10 validation sens. : 0.81633, spec. : 0.81395; combined: 0.81514
#
#  Epochs without improvement =  2
# [11,     1] loss: 0.01574
# [11,    11] loss: 0.06494
# [11,    21] loss: 0.12527
# [11,    31] loss: 0.05491
# [11,    41] loss: 0.03891
# [11,    51] loss: 0.08711
# [11,    61] loss: 0.07095
# [11,    71] loss: 0.05655
# [11,    81] loss: 0.07507
# [11,    91] loss: 0.07384
# epoch 11 average training loss: 0.07233
# epoch 11 average val loss: 0.44015
# epoch 11 validation sens. : 0.89796, spec. : 0.79070; combined: 0.84433
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [12,     1] loss: 0.00133
# [12,    11] loss: 0.08513
# [12,    21] loss: 0.04191
# [12,    31] loss: 0.05777
# [12,    41] loss: 0.06457
# [12,    51] loss: 0.02165
# [12,    61] loss: 0.03409
# [12,    71] loss: 0.03127
# [12,    81] loss: 0.05546
# [12,    91] loss: 0.04495
# epoch 12 average training loss: 0.04817
# epoch 12 average val loss: 0.43461
# epoch 12 validation sens. : 0.85714, spec. : 0.81395; combined: 0.83555
#
#  Epochs without improvement =  1
# [13,     1] loss: 0.00152
# [13,    11] loss: 0.03037
# [13,    21] loss: 0.05174
# [13,    31] loss: 0.01949
# [13,    41] loss: 0.02611
# [13,    51] loss: 0.04700
# [13,    61] loss: 0.03236
# [13,    71] loss: 0.02808
# [13,    81] loss: 0.05443
# [13,    91] loss: 0.02330
# epoch 13 average training loss: 0.03429
# epoch 13 average val loss: 0.44334
# epoch 13 validation sens. : 0.83673, spec. : 0.86047; combined: 0.84860
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [14,     1] loss: 0.00050
# [14,    11] loss: 0.02465
# [14,    21] loss: 0.02142
# [14,    31] loss: 0.01629
# [14,    41] loss: 0.02270
# [14,    51] loss: 0.03183
# [14,    61] loss: 0.02170
# [14,    71] loss: 0.01845
# [14,    81] loss: 0.02427
# [14,    91] loss: 0.01133
# epoch 14 average training loss: 0.02105
# epoch 14 average val loss: 0.43511
# epoch 14 validation sens. : 0.89796, spec. : 0.81395; combined: 0.85596
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [15,     1] loss: 0.00339
# [15,    11] loss: 0.01835
# [15,    21] loss: 0.01794
# [15,    31] loss: 0.01322
# [15,    41] loss: 0.01661
# [15,    51] loss: 0.01528
# [15,    61] loss: 0.02149
# [15,    71] loss: 0.01449
# [15,    81] loss: 0.01460
# [15,    91] loss: 0.01261
# epoch 15 average training loss: 0.01614
# epoch 15 average val loss: 0.47280
# epoch 15 validation sens. : 0.89796, spec. : 0.81395; combined: 0.85596
#
#  Epochs without improvement =  1
# [16,     1] loss: 0.00085
# [16,    11] loss: 0.00701
# [16,    21] loss: 0.01399
# [16,    31] loss: 0.00828
# [16,    41] loss: 0.01279
# [16,    51] loss: 0.00830
# [16,    61] loss: 0.01004
# [16,    71] loss: 0.00926
# [16,    81] loss: 0.01975
# [16,    91] loss: 0.01028
# epoch 16 average training loss: 0.01096
# epoch 16 average val loss: 0.46434
# epoch 16 validation sens. : 0.89796, spec. : 0.81395; combined: 0.85596
#
#  Epochs without improvement =  2
# [17,     1] loss: 0.00046
# [17,    11] loss: 0.00764
# [17,    21] loss: 0.00527
# [17,    31] loss: 0.00825
# [17,    41] loss: 0.00885
# [17,    51] loss: 0.01155
# [17,    61] loss: 0.00743
# [17,    71] loss: 0.00978
# [17,    81] loss: 0.00869
# [17,    91] loss: 0.00831
# epoch 17 average training loss: 0.00846
# epoch 17 average val loss: 0.47485
# epoch 17 validation sens. : 0.91837, spec. : 0.81395; combined: 0.86616
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [18,     1] loss: 0.00030
# [18,    11] loss: 0.00620
# [18,    21] loss: 0.01006
# [18,    31] loss: 0.00769
# [18,    41] loss: 0.00760
# [18,    51] loss: 0.00551
# [18,    61] loss: 0.00810
# [18,    71] loss: 0.00494
# [18,    81] loss: 0.00391
# [18,    91] loss: 0.00615
# epoch 18 average training loss: 0.00658
# epoch 18 average val loss: 0.48414
# epoch 18 validation sens. : 0.91837, spec. : 0.81395; combined: 0.86616
#
#  Epochs without improvement =  1
# [19,     1] loss: 0.00088
# [19,    11] loss: 0.00735
# [19,    21] loss: 0.00356
# [19,    31] loss: 0.00560
# [19,    41] loss: 0.00335
# [19,    51] loss: 0.00261
# [19,    61] loss: 0.00673
# [19,    71] loss: 0.00538
# [19,    81] loss: 0.00672
# [19,    91] loss: 0.00466
# epoch 19 average training loss: 0.00513
# epoch 19 average val loss: 0.49003
# epoch 19 validation sens. : 0.81633, spec. : 0.93023; combined: 0.87328
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [20,     1] loss: 0.00111
# [20,    11] loss: 0.00265
# [20,    21] loss: 0.00492
# [20,    31] loss: 0.00494
# [20,    41] loss: 0.00339
# [20,    51] loss: 0.00570
# [20,    61] loss: 0.00252
# [20,    71] loss: 0.00455
# [20,    81] loss: 0.00367
# [20,    91] loss: 0.00474
# epoch 20 average training loss: 0.00416
# epoch 20 average val loss: 0.50218
# epoch 20 validation sens. : 0.87755, spec. : 0.86047; combined: 0.86901
#
#  Epochs without improvement =  1
# [21,     1] loss: 0.00020
# [21,    11] loss: 0.00424
# [21,    21] loss: 0.00355
# [21,    31] loss: 0.00415
# [21,    41] loss: 0.00253
# [21,    51] loss: 0.00230
# [21,    61] loss: 0.00467
# [21,    71] loss: 0.00331
# [21,    81] loss: 0.00312
# [21,    91] loss: 0.00295
# epoch 21 average training loss: 0.00337
# epoch 21 average val loss: 0.51349
# epoch 21 validation sens. : 0.87755, spec. : 0.86047; combined: 0.86901
#
#  Epochs without improvement =  2
# [22,     1] loss: 0.00036
# [22,    11] loss: 0.00178
# [22,    21] loss: 0.00234
# [22,    31] loss: 0.00277
# [22,    41] loss: 0.00445
# [22,    51] loss: 0.00206
# [22,    61] loss: 0.00271
# [22,    71] loss: 0.00221
# [22,    81] loss: 0.00274
# [22,    91] loss: 0.00559
# epoch 22 average training loss: 0.00298
# epoch 22 average val loss: 0.52510
# epoch 22 validation sens. : 0.87755, spec. : 0.86047; combined: 0.86901
#
#  Epochs without improvement =  3
#
#  Stopped training because 3 epochs without improvement. . .
# <ipython-input-13-659fe441e304>:267: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('./best_base_STNet_fold_pd_'+str(k) +'.pt', map_location=device))
# Test set sens. : 0.53571, spec. : 0.58333, combined: 0.55952, auc: 0.52232
#
# Fold  2
# Patient items in training set:  210
# Control items in training set:  158
# Patient items in validation set:  42
# Control items in validation set:  50
#
# Test patient items:
#
# ['bar_35_1.pkl', 'bar_35_2.pkl', 'bar_35_3.pkl', 'bar_35_4.pkl', 'bar_49_1.pkl', 'bar_49_2.pkl', 'bar_49_3.pkl', 'bar_49_4.pkl', 'bar_77_1.pkl', 'bar_77_2.pkl', 'bar_77_3.pkl', 'bar_77_4.pkl', 'ctrl_19_1.pkl', 'ctrl_19_2.pkl', 'ctrl_19_3.pkl', 'ctrl_19_4.pkl', 'ctrl_59_1.pkl', 'ctrl_59_2.pkl', 'ctrl_59_3.pkl', 'ctrl_59_4.pkl', 'ctrl_69_1.pkl', 'ctrl_69_2.pkl', 'ctrl_69_3.pkl', 'ctrl_69_4.pkl', 'ctrl_90_1.pkl', 'ctrl_90_2.pkl', 'ctrl_90_3.pkl', 'ctrl_90_4.pkl', 'link_8_1.pkl', 'link_8_2.pkl', 'link_8_3.pkl', 'link_8_4.pkl']
# Training data:  Dataset DatasetFolder
#     Number of datapoints: 368
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented_verb/train_cookie_theft
# Validation data:  Dataset DatasetFolder
#     Number of datapoints: 92
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented_verb/val_cookie_theft
# Test data:  Dataset DatasetFolder
#     Number of datapoints: 52
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented_verb/test_cookie_theft
# [1,     1] loss: 0.06926
# [1,    11] loss: 0.68973
# [1,    21] loss: 0.71376
# [1,    31] loss: 0.69520
# [1,    41] loss: 0.69130
# [1,    51] loss: 0.66923
# [1,    61] loss: 0.66182
# [1,    71] loss: 0.64986
# [1,    81] loss: 0.69372
# [1,    91] loss: 0.69528
# epoch 1 average training loss: 0.68401
# epoch 1 average val loss: 0.70950
# epoch 1 validation sens. : 0.50000, spec. : 0.61905; combined: 0.55952
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [2,     1] loss: 0.07839
# [2,    11] loss: 0.64384
# [2,    21] loss: 0.67110
# [2,    31] loss: 0.67944
# [2,    41] loss: 0.68676
# [2,    51] loss: 0.64038
# [2,    61] loss: 0.67023
# [2,    71] loss: 0.68611
# [2,    81] loss: 0.65052
# [2,    91] loss: 0.66209
# epoch 2 average training loss: 0.66690
# epoch 2 average val loss: 0.70012
# epoch 2 validation sens. : 0.62000, spec. : 0.54762; combined: 0.58381
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [3,     1] loss: 0.08482
# [3,    11] loss: 0.58965
# [3,    21] loss: 0.68125
# [3,    31] loss: 0.69730
# [3,    41] loss: 0.63775
# [3,    51] loss: 0.65379
# [3,    61] loss: 0.63764
# [3,    71] loss: 0.65306
# [3,    81] loss: 0.63281
# [3,    91] loss: 0.61215
# epoch 3 average training loss: 0.64699
# epoch 3 average val loss: 0.68152
# epoch 3 validation sens. : 0.44000, spec. : 0.83333; combined: 0.63667
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [4,     1] loss: 0.06917
# [4,    11] loss: 0.60494
# [4,    21] loss: 0.61805
# [4,    31] loss: 0.56877
# [4,    41] loss: 0.63930
# [4,    51] loss: 0.58466
# [4,    61] loss: 0.57567
# [4,    71] loss: 0.59151
# [4,    81] loss: 0.51206
# [4,    91] loss: 0.54150
# epoch 4 average training loss: 0.58266
# epoch 4 average val loss: 0.64212
# epoch 4 validation sens. : 0.66000, spec. : 0.80952; combined: 0.73476
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [5,     1] loss: 0.05678
# [5,    11] loss: 0.46249
# [5,    21] loss: 0.44320
# [5,    31] loss: 0.44125
# [5,    41] loss: 0.50888
# [5,    51] loss: 0.48945
# [5,    61] loss: 0.42202
# [5,    71] loss: 0.43944
# [5,    81] loss: 0.41290
# [5,    91] loss: 0.46819
# epoch 5 average training loss: 0.45276
# epoch 5 average val loss: 0.67825
# epoch 5 validation sens. : 0.80000, spec. : 0.80952; combined: 0.80476
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [6,     1] loss: 0.01647
# [6,    11] loss: 0.34140
# [6,    21] loss: 0.36396
# [6,    31] loss: 0.33607
# [6,    41] loss: 0.32711
# [6,    51] loss: 0.30687
# [6,    61] loss: 0.38733
# [6,    71] loss: 0.24652
# [6,    81] loss: 0.25452
# [6,    91] loss: 0.23479
# epoch 6 average training loss: 0.30766
# epoch 6 average val loss: 0.54653
# epoch 6 validation sens. : 0.86000, spec. : 0.80952; combined: 0.83476
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [7,     1] loss: 0.02415
# [7,    11] loss: 0.15905
# [7,    21] loss: 0.22158
# [7,    31] loss: 0.17287
# [7,    41] loss: 0.17855
# [7,    51] loss: 0.16073
# [7,    61] loss: 0.16834
# [7,    71] loss: 0.19653
# [7,    81] loss: 0.10358
# [7,    91] loss: 0.26771
# epoch 7 average training loss: 0.18448
# epoch 7 average val loss: 0.43365
# epoch 7 validation sens. : 0.86000, spec. : 0.80952; combined: 0.83476
#
#  Epochs without improvement =  1
# [8,     1] loss: 0.01002
# [8,    11] loss: 0.13344
# [8,    21] loss: 0.10414
# [8,    31] loss: 0.07669
# [8,    41] loss: 0.16450
# [8,    51] loss: 0.07801
# [8,    61] loss: 0.21845
# [8,    71] loss: 0.13300
# [8,    81] loss: 0.11425
# [8,    91] loss: 0.10815
# epoch 8 average training loss: 0.12421
# epoch 8 average val loss: 0.42151
# epoch 8 validation sens. : 0.84000, spec. : 0.88095; combined: 0.86048
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [9,     1] loss: 0.00415
# [9,    11] loss: 0.05559
# [9,    21] loss: 0.06189
# [9,    31] loss: 0.05346
# [9,    41] loss: 0.08544
# [9,    51] loss: 0.09157
# [9,    61] loss: 0.07689
# [9,    71] loss: 0.04985
# [9,    81] loss: 0.08460
# [9,    91] loss: 0.05806
# epoch 9 average training loss: 0.06778
# epoch 9 average val loss: 0.42466
# epoch 9 validation sens. : 0.88000, spec. : 0.88095; combined: 0.88048
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [10,     1] loss: 0.01330
# [10,    11] loss: 0.04555
# [10,    21] loss: 0.04645
# [10,    31] loss: 0.04962
# [10,    41] loss: 0.03027
# [10,    51] loss: 0.03415
# [10,    61] loss: 0.05239
# [10,    71] loss: 0.05697
# [10,    81] loss: 0.03580
# [10,    91] loss: 0.01844
# epoch 10 average training loss: 0.04429
# epoch 10 average val loss: 0.42120
# epoch 10 validation sens. : 0.88000, spec. : 0.90476; combined: 0.89238
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [11,     1] loss: 0.00040
# [11,    11] loss: 0.04784
# [11,    21] loss: 0.02905
# [11,    31] loss: 0.02592
# [11,    41] loss: 0.01710
# [11,    51] loss: 0.02686
# [11,    61] loss: 0.02901
# [11,    71] loss: 0.01713
# [11,    81] loss: 0.01704
# [11,    91] loss: 0.01090
# epoch 11 average training loss: 0.02640
# epoch 11 average val loss: 0.42277
# epoch 11 validation sens. : 0.88000, spec. : 0.92857; combined: 0.90429
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [12,     1] loss: 0.00038
# [12,    11] loss: 0.02126
# [12,    21] loss: 0.00572
# [12,    31] loss: 0.02194
# [12,    41] loss: 0.01506
# [12,    51] loss: 0.02530
# [12,    61] loss: 0.01566
# [12,    71] loss: 0.01495
# [12,    81] loss: 0.01484
# [12,    91] loss: 0.01539
# epoch 12 average training loss: 0.01639
# epoch 12 average val loss: 0.42770
# epoch 12 validation sens. : 0.88000, spec. : 0.92857; combined: 0.90429
#
#  Epochs without improvement =  1
# [13,     1] loss: 0.00140
# [13,    11] loss: 0.00738
# [13,    21] loss: 0.01462
# [13,    31] loss: 0.00651
# [13,    41] loss: 0.00661
# [13,    51] loss: 0.01046
# [13,    61] loss: 0.00722
# [13,    71] loss: 0.01299
# [13,    81] loss: 0.01067
# [13,    91] loss: 0.00848
# epoch 13 average training loss: 0.00940
# epoch 13 average val loss: 0.43752
# epoch 13 validation sens. : 0.88000, spec. : 0.92857; combined: 0.90429
#
#  Epochs without improvement =  2
# [14,     1] loss: 0.00209
# [14,    11] loss: 0.00801
# [14,    21] loss: 0.00759
# [14,    31] loss: 0.00555
# [14,    41] loss: 0.00621
# [14,    51] loss: 0.00654
# [14,    61] loss: 0.00677
# [14,    71] loss: 0.00658
# [14,    81] loss: 0.00633
# [14,    91] loss: 0.00733
# epoch 14 average training loss: 0.00697
# epoch 14 average val loss: 0.45418
# epoch 14 validation sens. : 0.88000, spec. : 0.92857; combined: 0.90429
#
#  Epochs without improvement =  3
#
#  Stopped training because 3 epochs without improvement. . .
# <ipython-input-13-659fe441e304>:267: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('./best_base_STNet_fold_pd_'+str(k) +'.pt', map_location=device))
# Test set sens. : 0.55000, spec. : 0.75000, combined: 0.65000, auc: 0.65156
#
# Fold  3
# Patient items in training set:  208
# Control items in training set:  160
# Patient items in validation set:  48
# Control items in validation set:  44
#
# Test patient items:
#
# ['bar_2_1.pkl', 'bar_2_2.pkl', 'bar_2_3.pkl', 'bar_2_4.pkl', 'bar_54_1.pkl', 'bar_54_2.pkl', 'bar_54_3.pkl', 'bar_54_4.pkl', 'bar_6_1.pkl', 'bar_6_2.pkl', 'bar_6_3.pkl', 'bar_6_4.pkl', 'bar_78_1.pkl', 'bar_78_2.pkl', 'bar_78_3.pkl', 'bar_78_4.pkl', 'ctrl_21_1.pkl', 'ctrl_21_2.pkl', 'ctrl_21_3.pkl', 'ctrl_21_4.pkl', 'ctrl_71_1.pkl', 'ctrl_71_2.pkl', 'ctrl_71_3.pkl', 'ctrl_71_4.pkl', 'link_4_1.pkl', 'link_4_2.pkl', 'link_4_3.pkl', 'link_4_4.pkl']
# Training data:  Dataset DatasetFolder
#     Number of datapoints: 368
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented_verb/train_cookie_theft
# Validation data:  Dataset DatasetFolder
#     Number of datapoints: 92
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented_verb/val_cookie_theft
# Test data:  Dataset DatasetFolder
#     Number of datapoints: 52
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented_verb/test_cookie_theft
# [1,     1] loss: 0.06881
# [1,    11] loss: 0.70308
# [1,    21] loss: 0.69992
# [1,    31] loss: 0.69661
# [1,    41] loss: 0.69882
# [1,    51] loss: 0.68144
# [1,    61] loss: 0.66815
# [1,    71] loss: 0.66011
# [1,    81] loss: 0.69434
# [1,    91] loss: 0.69915
# epoch 1 average training loss: 0.68859
# epoch 1 average val loss: 0.68621
# epoch 1 validation sens. : 0.36364, spec. : 0.77083; combined: 0.56723
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [2,     1] loss: 0.07448
# [2,    11] loss: 0.64937
# [2,    21] loss: 0.69317
# [2,    31] loss: 0.67692
# [2,    41] loss: 0.71171
# [2,    51] loss: 0.65635
# [2,    61] loss: 0.67553
# [2,    71] loss: 0.67489
# [2,    81] loss: 0.64198
# [2,    91] loss: 0.66016
# epoch 2 average training loss: 0.67218
# epoch 2 average val loss: 0.67470
# epoch 2 validation sens. : 0.40909, spec. : 0.81250; combined: 0.61080
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [3,     1] loss: 0.07593
# [3,    11] loss: 0.62336
# [3,    21] loss: 0.68404
# [3,    31] loss: 0.68800
# [3,    41] loss: 0.65439
# [3,    51] loss: 0.64314
# [3,    61] loss: 0.65368
# [3,    71] loss: 0.66614
# [3,    81] loss: 0.65419
# [3,    91] loss: 0.64071
# epoch 3 average training loss: 0.65741
# epoch 3 average val loss: 0.66034
# epoch 3 validation sens. : 0.63636, spec. : 0.64583; combined: 0.64110
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [4,     1] loss: 0.06509
# [4,    11] loss: 0.65164
# [4,    21] loss: 0.63826
# [4,    31] loss: 0.59580
# [4,    41] loss: 0.64508
# [4,    51] loss: 0.58811
# [4,    61] loss: 0.60641
# [4,    71] loss: 0.65260
# [4,    81] loss: 0.59810
# [4,    91] loss: 0.61867
# epoch 4 average training loss: 0.62160
# epoch 4 average val loss: 0.61355
# epoch 4 validation sens. : 0.79545, spec. : 0.62500; combined: 0.71023
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [5,     1] loss: 0.06222
# [5,    11] loss: 0.54941
# [5,    21] loss: 0.50848
# [5,    31] loss: 0.52755
# [5,    41] loss: 0.53181
# [5,    51] loss: 0.53879
# [5,    61] loss: 0.49069
# [5,    71] loss: 0.57590
# [5,    81] loss: 0.60790
# [5,    91] loss: 0.48293
# epoch 5 average training loss: 0.53543
# epoch 5 average val loss: 0.62215
# epoch 5 validation sens. : 0.72727, spec. : 0.75000; combined: 0.73864
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [6,     1] loss: 0.03509
# [6,    11] loss: 0.50327
# [6,    21] loss: 0.54109
# [6,    31] loss: 0.39981
# [6,    41] loss: 0.35948
# [6,    51] loss: 0.41762
# [6,    61] loss: 0.40056
# [6,    71] loss: 0.39660
# [6,    81] loss: 0.41626
# [6,    91] loss: 0.27719
# epoch 6 average training loss: 0.40932
# epoch 6 average val loss: 0.47344
# epoch 6 validation sens. : 0.79545, spec. : 0.81250; combined: 0.80398
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [7,     1] loss: 0.02782
# [7,    11] loss: 0.29216
# [7,    21] loss: 0.25553
# [7,    31] loss: 0.29384
# [7,    41] loss: 0.27889
# [7,    51] loss: 0.25344
# [7,    61] loss: 0.30882
# [7,    71] loss: 0.30147
# [7,    81] loss: 0.32657
# [7,    91] loss: 0.24379
# epoch 7 average training loss: 0.28427
# epoch 7 average val loss: 0.40187
# epoch 7 validation sens. : 0.86364, spec. : 0.83333; combined: 0.84848
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [8,     1] loss: 0.04844
# [8,    11] loss: 0.21385
# [8,    21] loss: 0.11950
# [8,    31] loss: 0.23317
# [8,    41] loss: 0.23350
# [8,    51] loss: 0.24738
# [8,    61] loss: 0.17762
# [8,    71] loss: 0.15536
# [8,    81] loss: 0.13259
# [8,    91] loss: 0.20367
# epoch 8 average training loss: 0.19456
# epoch 8 average val loss: 0.36722
# epoch 8 validation sens. : 0.90909, spec. : 0.83333; combined: 0.87121
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [9,     1] loss: 0.00764
# [9,    11] loss: 0.14092
# [9,    21] loss: 0.14606
# [9,    31] loss: 0.11305
# [9,    41] loss: 0.08839
# [9,    51] loss: 0.18793
# [9,    61] loss: 0.08151
# [9,    71] loss: 0.11394
# [9,    81] loss: 0.10606
# [9,    91] loss: 0.11967
# epoch 9 average training loss: 0.12044
# epoch 9 average val loss: 0.32620
# epoch 9 validation sens. : 0.86364, spec. : 0.83333; combined: 0.84848
#
#  Epochs without improvement =  1
# [10,     1] loss: 0.00892
# [10,    11] loss: 0.09049
# [10,    21] loss: 0.08506
# [10,    31] loss: 0.09265
# [10,    41] loss: 0.05711
# [10,    51] loss: 0.08296
# [10,    61] loss: 0.08004
# [10,    71] loss: 0.07148
# [10,    81] loss: 0.03969
# [10,    91] loss: 0.08302
# epoch 10 average training loss: 0.07585
# epoch 10 average val loss: 0.31383
# epoch 10 validation sens. : 0.88636, spec. : 0.85417; combined: 0.87027
#
#  Epochs without improvement =  2
# [11,     1] loss: 0.00465
# [11,    11] loss: 0.03345
# [11,    21] loss: 0.03836
# [11,    31] loss: 0.03993
# [11,    41] loss: 0.05578
# [11,    51] loss: 0.06686
# [11,    61] loss: 0.04182
# [11,    71] loss: 0.05646
# [11,    81] loss: 0.03547
# [11,    91] loss: 0.03223
# epoch 11 average training loss: 0.04441
# epoch 11 average val loss: 0.34517
# epoch 11 validation sens. : 0.88636, spec. : 0.87500; combined: 0.88068
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [12,     1] loss: 0.00077
# [12,    11] loss: 0.03188
# [12,    21] loss: 0.02773
# [12,    31] loss: 0.03043
# [12,    41] loss: 0.03401
# [12,    51] loss: 0.03394
# [12,    61] loss: 0.01957
# [12,    71] loss: 0.03392
# [12,    81] loss: 0.02403
# [12,    91] loss: 0.02866
# epoch 12 average training loss: 0.02906
# epoch 12 average val loss: 0.33088
# epoch 12 validation sens. : 0.90909, spec. : 0.85417; combined: 0.88163
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [13,     1] loss: 0.00082
# [13,    11] loss: 0.02013
# [13,    21] loss: 0.02295
# [13,    31] loss: 0.01425
# [13,    41] loss: 0.01772
# [13,    51] loss: 0.01837
# [13,    61] loss: 0.01079
# [13,    71] loss: 0.02430
# [13,    81] loss: 0.03086
# [13,    91] loss: 0.02768
# epoch 13 average training loss: 0.02075
# epoch 13 average val loss: 0.33330
# epoch 13 validation sens. : 0.90909, spec. : 0.87500; combined: 0.89205
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [14,     1] loss: 0.00145
# [14,    11] loss: 0.01478
# [14,    21] loss: 0.01023
# [14,    31] loss: 0.01475
# [14,    41] loss: 0.01391
# [14,    51] loss: 0.01029
# [14,    61] loss: 0.01480
# [14,    71] loss: 0.01417
# [14,    81] loss: 0.01795
# [14,    91] loss: 0.01464
# epoch 14 average training loss: 0.01400
# epoch 14 average val loss: 0.33136
# epoch 14 validation sens. : 0.90909, spec. : 0.87500; combined: 0.89205
#
#  Epochs without improvement =  1
# [15,     1] loss: 0.00169
# [15,    11] loss: 0.00912
# [15,    21] loss: 0.00934
# [15,    31] loss: 0.01150
# [15,    41] loss: 0.00793
# [15,    51] loss: 0.00858
# [15,    61] loss: 0.00923
# [15,    71] loss: 0.01158
# [15,    81] loss: 0.00534
# [15,    91] loss: 0.00921
# epoch 15 average training loss: 0.00916
# epoch 15 average val loss: 0.34004
# epoch 15 validation sens. : 0.88636, spec. : 0.89583; combined: 0.89110
#
#  Epochs without improvement =  2
# [16,     1] loss: 0.00071
# [16,    11] loss: 0.00525
# [16,    21] loss: 0.00629
# [16,    31] loss: 0.00856
# [16,    41] loss: 0.00676
# [16,    51] loss: 0.00777
# [16,    61] loss: 0.00593
# [16,    71] loss: 0.00653
# [16,    81] loss: 0.00625
# [16,    91] loss: 0.00836
# epoch 16 average training loss: 0.00680
# epoch 16 average val loss: 0.34406
# epoch 16 validation sens. : 0.88636, spec. : 0.89583; combined: 0.89110
#
#  Epochs without improvement =  3
#
#  Stopped training because 3 epochs without improvement. . .
# <ipython-input-13-659fe441e304>:267: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('./best_base_STNet_fold_pd_'+str(k) +'.pt', map_location=device))
# Test set sens. : 0.33333, spec. : 0.92857, combined: 0.63095, auc: 0.55655
#
# Fold  4
# Patient items in training set:  216
# Control items in training set:  152
# Patient items in validation set:  44
# Control items in validation set:  48
#
# Test patient items:
#
# ['bar_38_1.pkl', 'bar_38_2.pkl', 'bar_38_3.pkl', 'bar_38_4.pkl', 'bar_51_1.pkl', 'bar_51_2.pkl', 'bar_51_3.pkl', 'bar_51_4.pkl', 'bar_60_1.pkl', 'bar_60_2.pkl', 'bar_60_3.pkl', 'bar_60_4.pkl', 'bar_79_1.pkl', 'bar_79_2.pkl', 'bar_79_3.pkl', 'bar_79_4.pkl', 'ctrl_89_1.pkl', 'ctrl_89_2.pkl', 'ctrl_89_3.pkl', 'ctrl_89_4.pkl', 'link_5_1.pkl', 'link_5_2.pkl', 'link_5_3.pkl', 'link_5_4.pkl']
# Training data:  Dataset DatasetFolder
#     Number of datapoints: 368
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented_verb/train_cookie_theft
# Validation data:  Dataset DatasetFolder
#     Number of datapoints: 92
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented_verb/val_cookie_theft
# Test data:  Dataset DatasetFolder
#     Number of datapoints: 52
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented_verb/test_cookie_theft
# [1,     1] loss: 0.06819
# [1,    11] loss: 0.69141
# [1,    21] loss: 0.69889
# [1,    31] loss: 0.68874
# [1,    41] loss: 0.67737
# [1,    51] loss: 0.65861
# [1,    61] loss: 0.65008
# [1,    71] loss: 0.63170
# [1,    81] loss: 0.70768
# [1,    91] loss: 0.69646
# epoch 1 average training loss: 0.67688
# epoch 1 average val loss: 0.69895
# epoch 1 validation sens. : 0.52083, spec. : 0.68182; combined: 0.60133
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [2,     1] loss: 0.08003
# [2,    11] loss: 0.62086
# [2,    21] loss: 0.67084
# [2,    31] loss: 0.65096
# [2,    41] loss: 0.68582
# [2,    51] loss: 0.62689
# [2,    61] loss: 0.66210
# [2,    71] loss: 0.64080
# [2,    81] loss: 0.63923
# [2,    91] loss: 0.65618
# epoch 2 average training loss: 0.65216
# epoch 2 average val loss: 0.68314
# epoch 2 validation sens. : 0.66667, spec. : 0.65909; combined: 0.66288
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [3,     1] loss: 0.07133
# [3,    11] loss: 0.55847
# [3,    21] loss: 0.66931
# [3,    31] loss: 0.64626
# [3,    41] loss: 0.57105
# [3,    51] loss: 0.67171
# [3,    61] loss: 0.63068
# [3,    71] loss: 0.63537
# [3,    81] loss: 0.59417
# [3,    91] loss: 0.60758
# epoch 3 average training loss: 0.62140
# epoch 3 average val loss: 0.65612
# epoch 3 validation sens. : 0.70833, spec. : 0.72727; combined: 0.71780
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [4,     1] loss: 0.06367
# [4,    11] loss: 0.55624
# [4,    21] loss: 0.58091
# [4,    31] loss: 0.49913
# [4,    41] loss: 0.58367
# [4,    51] loss: 0.55649
# [4,    61] loss: 0.54298
# [4,    71] loss: 0.50739
# [4,    81] loss: 0.51854
# [4,    91] loss: 0.55020
# epoch 4 average training loss: 0.54520
# epoch 4 average val loss: 0.58933
# epoch 4 validation sens. : 0.75000, spec. : 0.75000; combined: 0.75000
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [5,     1] loss: 0.04935
# [5,    11] loss: 0.42818
# [5,    21] loss: 0.40606
# [5,    31] loss: 0.38456
# [5,    41] loss: 0.49568
# [5,    51] loss: 0.43069
# [5,    61] loss: 0.35456
# [5,    71] loss: 0.44810
# [5,    81] loss: 0.38903
# [5,    91] loss: 0.38861
# epoch 5 average training loss: 0.41383
# epoch 5 average val loss: 0.68291
# epoch 5 validation sens. : 0.64583, spec. : 0.86364; combined: 0.75473
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [6,     1] loss: 0.03178
# [6,    11] loss: 0.31891
# [6,    21] loss: 0.36899
# [6,    31] loss: 0.25207
# [6,    41] loss: 0.24750
# [6,    51] loss: 0.25148
# [6,    61] loss: 0.28953
# [6,    71] loss: 0.24569
# [6,    81] loss: 0.23967
# [6,    91] loss: 0.22087
# epoch 6 average training loss: 0.27512
# epoch 6 average val loss: 0.50257
# epoch 6 validation sens. : 0.81250, spec. : 0.72727; combined: 0.76989
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [7,     1] loss: 0.02606
# [7,    11] loss: 0.20559
# [7,    21] loss: 0.18602
# [7,    31] loss: 0.15653
# [7,    41] loss: 0.16974
# [7,    51] loss: 0.19396
# [7,    61] loss: 0.17340
# [7,    71] loss: 0.14250
# [7,    81] loss: 0.23814
# [7,    91] loss: 0.11851
# epoch 7 average training loss: 0.17588
# epoch 7 average val loss: 0.44487
# epoch 7 validation sens. : 0.79167, spec. : 0.77273; combined: 0.78220
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [8,     1] loss: 0.01371
# [8,    11] loss: 0.15362
# [8,    21] loss: 0.06765
# [8,    31] loss: 0.14867
# [8,    41] loss: 0.20271
# [8,    51] loss: 0.08472
# [8,    61] loss: 0.10376
# [8,    71] loss: 0.13233
# [8,    81] loss: 0.08714
# [8,    91] loss: 0.09148
# epoch 8 average training loss: 0.11907
# epoch 8 average val loss: 0.46973
# epoch 8 validation sens. : 0.89583, spec. : 0.72727; combined: 0.81155
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [9,     1] loss: 0.01403
# [9,    11] loss: 0.08444
# [9,    21] loss: 0.06244
# [9,    31] loss: 0.05214
# [9,    41] loss: 0.07403
# [9,    51] loss: 0.12082
# [9,    61] loss: 0.07030
# [9,    71] loss: 0.03121
# [9,    81] loss: 0.05879
# [9,    91] loss: 0.07115
# epoch 9 average training loss: 0.06969
# epoch 9 average val loss: 0.43594
# epoch 9 validation sens. : 0.77083, spec. : 0.84091; combined: 0.80587
#
#  Epochs without improvement =  1
# [10,     1] loss: 0.00220
# [10,    11] loss: 0.06758
# [10,    21] loss: 0.04251
# [10,    31] loss: 0.04259
# [10,    41] loss: 0.05435
# [10,    51] loss: 0.05145
# [10,    61] loss: 0.03891
# [10,    71] loss: 0.04247
# [10,    81] loss: 0.04267
# [10,    91] loss: 0.03241
# epoch 10 average training loss: 0.04568
# epoch 10 average val loss: 0.44353
# epoch 10 validation sens. : 0.89583, spec. : 0.77273; combined: 0.83428
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [11,     1] loss: 0.00172
# [11,    11] loss: 0.02208
# [11,    21] loss: 0.02144
# [11,    31] loss: 0.02830
# [11,    41] loss: 0.04614
# [11,    51] loss: 0.02095
# [11,    61] loss: 0.02287
# [11,    71] loss: 0.03731
# [11,    81] loss: 0.02488
# [11,    91] loss: 0.02053
# epoch 11 average training loss: 0.02702
# epoch 11 average val loss: 0.46611
# epoch 11 validation sens. : 0.89583, spec. : 0.77273; combined: 0.83428
#
#  Epochs without improvement =  1
# [12,     1] loss: 0.00165
# [12,    11] loss: 0.01493
# [12,    21] loss: 0.01462
# [12,    31] loss: 0.01309
# [12,    41] loss: 0.01407
# [12,    51] loss: 0.02435
# [12,    61] loss: 0.01685
# [12,    71] loss: 0.01281
# [12,    81] loss: 0.01611
# [12,    91] loss: 0.01840
# epoch 12 average training loss: 0.01604
# epoch 12 average val loss: 0.46147
# epoch 12 validation sens. : 0.89583, spec. : 0.77273; combined: 0.83428
#
#  Epochs without improvement =  2
# [13,     1] loss: 0.00084
# [13,    11] loss: 0.01100
# [13,    21] loss: 0.00883
# [13,    31] loss: 0.00766
# [13,    41] loss: 0.01374
# [13,    51] loss: 0.01183
# [13,    61] loss: 0.01081
# [13,    71] loss: 0.01350
# [13,    81] loss: 0.01512
# [13,    91] loss: 0.01152
# epoch 13 average training loss: 0.01144
# epoch 13 average val loss: 0.47974
# epoch 13 validation sens. : 0.89583, spec. : 0.77273; combined: 0.83428
#
#  Epochs without improvement =  3
#
#  Stopped training because 3 epochs without improvement. . .
# <ipython-input-13-659fe441e304>:267: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('./best_base_STNet_fold_pd_'+str(k) +'.pt', map_location=device))
# Test set sens. : 0.64286, spec. : 0.50000, combined: 0.57143, auc: 0.43304
#
# Fold  5
# Patient items in training set:  197
# Control items in training set:  171
# Patient items in validation set:  43
# Control items in validation set:  49
#
# Test patient items:
#
# ['bar_21_1.pkl', 'bar_21_2.pkl', 'bar_21_3.pkl', 'bar_21_4.pkl', 'bar_29_1.pkl', 'bar_29_2.pkl', 'bar_29_3.pkl', 'bar_29_4.pkl', 'bar_39_1.pkl', 'bar_39_2.pkl', 'bar_39_3.pkl', 'bar_39_4.pkl', 'bar_63_1.pkl', 'bar_63_2.pkl', 'bar_63_3.pkl', 'bar_63_4.pkl', 'bar_81_1.pkl', 'bar_81_2.pkl', 'bar_81_3.pkl', 'bar_81_4.pkl', 'ctrl_26_1.pkl', 'ctrl_26_2.pkl', 'ctrl_26_3.pkl', 'ctrl_26_4.pkl', 'ctrl_46_1.pkl', 'ctrl_46_2.pkl', 'ctrl_46_3.pkl', 'ctrl_46_4.pkl', 'ctrl_62_1.pkl', 'ctrl_62_2.pkl', 'ctrl_62_3.pkl', 'ctrl_62_4.pkl', 'ctrl_72_1.pkl', 'ctrl_72_2.pkl', 'ctrl_72_3.pkl', 'ctrl_72_4.pkl', 'ctrl_84_1.pkl', 'ctrl_84_2.pkl', 'ctrl_84_3.pkl', 'ctrl_84_4.pkl', 'link_12_1.pkl', 'link_12_2.pkl', 'link_12_3.pkl', 'link_12_4.pkl']
# Training data:  Dataset DatasetFolder
#     Number of datapoints: 368
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented_verb/train_cookie_theft
# Validation data:  Dataset DatasetFolder
#     Number of datapoints: 92
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented_verb/val_cookie_theft
# Test data:  Dataset DatasetFolder
#     Number of datapoints: 52
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented_verb/test_cookie_theft
# [1,     1] loss: 0.06818
# [1,    11] loss: 0.70312
# [1,    21] loss: 0.68842
# [1,    31] loss: 0.70222
# [1,    41] loss: 0.69023
# [1,    51] loss: 0.67850
# [1,    61] loss: 0.69048
# [1,    71] loss: 0.67070
# [1,    81] loss: 0.70023
# [1,    91] loss: 0.70177
# epoch 1 average training loss: 0.69131
# epoch 1 average val loss: 0.69481
# epoch 1 validation sens. : 0.59184, spec. : 0.65116; combined: 0.62150
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [2,     1] loss: 0.07723
# [2,    11] loss: 0.67352
# [2,    21] loss: 0.68995
# [2,    31] loss: 0.67619
# [2,    41] loss: 0.70726
# [2,    51] loss: 0.66451
# [2,    61] loss: 0.67590
# [2,    71] loss: 0.66581
# [2,    81] loss: 0.67310
# [2,    91] loss: 0.65780
# epoch 2 average training loss: 0.67675
# epoch 2 average val loss: 0.68879
# epoch 2 validation sens. : 0.61224, spec. : 0.65116; combined: 0.63170
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [3,     1] loss: 0.07710
# [3,    11] loss: 0.62931
# [3,    21] loss: 0.69463
# [3,    31] loss: 0.69325
# [3,    41] loss: 0.63656
# [3,    51] loss: 0.62752
# [3,    61] loss: 0.67346
# [3,    71] loss: 0.65894
# [3,    81] loss: 0.64417
# [3,    91] loss: 0.66334
# epoch 3 average training loss: 0.65989
# epoch 3 average val loss: 0.67447
# epoch 3 validation sens. : 0.59184, spec. : 0.65116; combined: 0.62150
#
#  Epochs without improvement =  1
# [4,     1] loss: 0.07748
# [4,    11] loss: 0.65299
# [4,    21] loss: 0.64004
# [4,    31] loss: 0.62153
# [4,    41] loss: 0.63732
# [4,    51] loss: 0.64285
# [4,    61] loss: 0.61490
# [4,    71] loss: 0.64299
# [4,    81] loss: 0.62044
# [4,    91] loss: 0.59213
# epoch 4 average training loss: 0.62975
# epoch 4 average val loss: 0.63639
# epoch 4 validation sens. : 0.71429, spec. : 0.69767; combined: 0.70598
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [5,     1] loss: 0.06486
# [5,    11] loss: 0.54359
# [5,    21] loss: 0.55645
# [5,    31] loss: 0.52828
# [5,    41] loss: 0.58907
# [5,    51] loss: 0.53952
# [5,    61] loss: 0.48843
# [5,    71] loss: 0.60423
# [5,    81] loss: 0.55480
# [5,    91] loss: 0.48698
# epoch 5 average training loss: 0.54211
# epoch 5 average val loss: 0.66352
# epoch 5 validation sens. : 0.85714, spec. : 0.55814; combined: 0.70764
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [6,     1] loss: 0.03915
# [6,    11] loss: 0.51077
# [6,    21] loss: 0.41583
# [6,    31] loss: 0.38155
# [6,    41] loss: 0.44015
# [6,    51] loss: 0.38121
# [6,    61] loss: 0.37017
# [6,    71] loss: 0.41264
# [6,    81] loss: 0.39573
# [6,    91] loss: 0.37881
# epoch 6 average training loss: 0.40936
# epoch 6 average val loss: 0.52879
# epoch 6 validation sens. : 0.75510, spec. : 0.69767; combined: 0.72639
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [7,     1] loss: 0.07790
# [7,    11] loss: 0.26455
# [7,    21] loss: 0.29640
# [7,    31] loss: 0.37283
# [7,    41] loss: 0.29582
# [7,    51] loss: 0.30508
# [7,    61] loss: 0.25862
# [7,    71] loss: 0.18142
# [7,    81] loss: 0.23694
# [7,    91] loss: 0.21635
# epoch 7 average training loss: 0.27383
# epoch 7 average val loss: 0.47750
# epoch 7 validation sens. : 0.85714, spec. : 0.72093; combined: 0.78904
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [8,     1] loss: 0.01360
# [8,    11] loss: 0.18298
# [8,    21] loss: 0.16099
# [8,    31] loss: 0.20311
# [8,    41] loss: 0.23608
# [8,    51] loss: 0.18273
# [8,    61] loss: 0.16753
# [8,    71] loss: 0.17650
# [8,    81] loss: 0.19910
# [8,    91] loss: 0.17181
# epoch 8 average training loss: 0.18697
# epoch 8 average val loss: 0.43899
# epoch 8 validation sens. : 0.73469, spec. : 0.83721; combined: 0.78595
#
#  Epochs without improvement =  1
# [9,     1] loss: 0.01289
# [9,    11] loss: 0.13896
# [9,    21] loss: 0.11048
# [9,    31] loss: 0.09458
# [9,    41] loss: 0.11616
# [9,    51] loss: 0.10747
# [9,    61] loss: 0.10935
# [9,    71] loss: 0.17057
# [9,    81] loss: 0.11082
# [9,    91] loss: 0.12148
# epoch 9 average training loss: 0.11930
# epoch 9 average val loss: 0.44090
# epoch 9 validation sens. : 0.73469, spec. : 0.88372; combined: 0.80921
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [10,     1] loss: 0.01066
# [10,    11] loss: 0.11609
# [10,    21] loss: 0.10352
# [10,    31] loss: 0.07648
# [10,    41] loss: 0.08794
# [10,    51] loss: 0.05181
# [10,    61] loss: 0.11101
# [10,    71] loss: 0.07237
# [10,    81] loss: 0.06431
# [10,    91] loss: 0.08755
# epoch 10 average training loss: 0.08515
# epoch 10 average val loss: 0.42956
# epoch 10 validation sens. : 0.81633, spec. : 0.90698; combined: 0.86165
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [11,     1] loss: 0.00277
# [11,    11] loss: 0.06756
# [11,    21] loss: 0.05140
# [11,    31] loss: 0.04683
# [11,    41] loss: 0.07499
# [11,    51] loss: 0.04963
# [11,    61] loss: 0.04219
# [11,    71] loss: 0.04454
# [11,    81] loss: 0.08890
# [11,    91] loss: 0.03990
# epoch 11 average training loss: 0.05552
# epoch 11 average val loss: 0.40663
# epoch 11 validation sens. : 0.83673, spec. : 0.83721; combined: 0.83697
#
#  Epochs without improvement =  1
# [12,     1] loss: 0.00063
# [12,    11] loss: 0.02658
# [12,    21] loss: 0.05032
# [12,    31] loss: 0.03000
# [12,    41] loss: 0.03730
# [12,    51] loss: 0.03186
# [12,    61] loss: 0.02706
# [12,    71] loss: 0.04239
# [12,    81] loss: 0.01838
# [12,    91] loss: 0.03480
# epoch 12 average training loss: 0.03298
# epoch 12 average val loss: 0.44626
# epoch 12 validation sens. : 0.85714, spec. : 0.86047; combined: 0.85880
#
#  Epochs without improvement =  2
# [13,     1] loss: 0.00116
# [13,    11] loss: 0.02704
# [13,    21] loss: 0.02785
# [13,    31] loss: 0.01963
# [13,    41] loss: 0.02356
# [13,    51] loss: 0.01996
# [13,    61] loss: 0.01215
# [13,    71] loss: 0.03202
# [13,    81] loss: 0.03495
# [13,    91] loss: 0.02557
# epoch 13 average training loss: 0.02448
# epoch 13 average val loss: 0.40984
# epoch 13 validation sens. : 0.87755, spec. : 0.86047; combined: 0.86901
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [14,     1] loss: 0.00108
# [14,    11] loss: 0.02542
# [14,    21] loss: 0.01278
# [14,    31] loss: 0.01767
# [14,    41] loss: 0.01488
# [14,    51] loss: 0.01668
# [14,    61] loss: 0.01257
# [14,    71] loss: 0.00731
# [14,    81] loss: 0.01543
# [14,    91] loss: 0.02488
# epoch 14 average training loss: 0.01673
# epoch 14 average val loss: 0.42265
# epoch 14 validation sens. : 0.83673, spec. : 0.88372; combined: 0.86023
#
#  Epochs without improvement =  1
# [15,     1] loss: 0.00262
# [15,    11] loss: 0.02212
# [15,    21] loss: 0.01120
# [15,    31] loss: 0.00702
# ...
# [13,    41] loss: 0.02926
# [13,    51] loss: 0.02850
# [13,    61] loss: 0.02586
# [13,    71] loss: 0.02486
# [13,    81] loss: 0.02332
# [13,    91] loss: 0.01756
# epoch 13 average training loss: 0.02579
# epoch 13 average val loss: 0.27140
# epoch 13 validation sens. : 0.88095, spec. : 0.92000; combined: 0.90048
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [14,     1] loss: 0.00152
# [14,    11] loss: 0.01888
# [14,    21] loss: 0.01716
# [14,    31] loss: 0.01205
# [14,    41] loss: 0.01580
# [14,    51] loss: 0.02255
# [14,    61] loss: 0.02047
# [14,    71] loss: 0.01304
# [14,    81] loss: 0.01825
# [14,    91] loss: 0.01396
# epoch 14 average training loss: 0.01682
# epoch 14 average val loss: 0.26962
# epoch 14 validation sens. : 0.95122, spec. : 0.86275; combined: 0.90698
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [15,     1] loss: 0.00068
# [15,    11] loss: 0.01365
# [15,    21] loss: 0.01396
# [15,    31] loss: 0.01319
# [15,    41] loss: 0.01106
# [15,    51] loss: 0.01566
# [15,    61] loss: 0.01062
# [15,    71] loss: 0.00919
# [15,    81] loss: 0.00784
# [15,    91] loss: 0.01322
# epoch 15 average training loss: 0.01274
# epoch 15 average val loss: 0.25653
# epoch 15 validation sens. : 0.95238, spec. : 0.88000; combined: 0.91619
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [16,     1] loss: 0.00006
# [16,    11] loss: 0.00842
# [16,    21] loss: 0.01105
# [16,    31] loss: 0.00901
# [16,    41] loss: 0.00743
# [16,    51] loss: 0.00995
# [16,    61] loss: 0.00822
# [16,    71] loss: 0.00946
# [16,    81] loss: 0.01041
# [16,    91] loss: 0.00959
# epoch 16 average training loss: 0.00917
# epoch 16 average val loss: 0.27815
# epoch 16 validation sens. : 0.88095, spec. : 0.94000; combined: 0.91048
#
#  Epochs without improvement =  1
# [17,     1] loss: 0.00112
# [17,    11] loss: 0.00663
# [17,    21] loss: 0.00581
# [17,    31] loss: 0.00847
# [17,    41] loss: 0.00704
# [17,    51] loss: 0.00924
# [17,    61] loss: 0.00674
# [17,    71] loss: 0.00367
# [17,    81] loss: 0.00563
# [17,    91] loss: 0.00687
# epoch 17 average training loss: 0.00670
# epoch 17 average val loss: 0.28478
# epoch 17 validation sens. : 0.90476, spec. : 0.90000; combined: 0.90238
#
#  Epochs without improvement =  2
# [18,     1] loss: 0.00013
# [18,    11] loss: 0.00486
# [18,    21] loss: 0.00591
# [18,    31] loss: 0.00542
# [18,    41] loss: 0.00558
# [18,    51] loss: 0.00415
# [18,    61] loss: 0.00522
# [18,    71] loss: 0.00679
# [18,    81] loss: 0.00496
# [18,    91] loss: 0.00500
# epoch 18 average training loss: 0.00532
# epoch 18 average val loss: 0.28813
# epoch 18 validation sens. : 0.88095, spec. : 0.94000; combined: 0.91048
#
#  Epochs without improvement =  3
#
#  Stopped training because 3 epochs without improvement. . .
# <ipython-input-13-659fe441e304>:267: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('./best_base_STNet_fold_pd_'+str(k) +'.pt', map_location=device))
# Test set sens. : 0.60000, spec. : 0.67857, combined: 0.63929, auc: 0.58571
#
# Fold  10
# Patient items in training set:  210
# Control items in training set:  161
# Patient items in validation set:  50
# Control items in validation set:  43
#
# Test patient items:
#
# ['bar_50_1.pkl', 'bar_50_2.pkl', 'bar_50_3.pkl', 'bar_50_4.pkl', 'ctrl_40_1.pkl', 'ctrl_40_2.pkl', 'ctrl_40_3.pkl', 'ctrl_40_4.pkl', 'ctrl_55_1.pkl', 'ctrl_55_2.pkl', 'ctrl_55_3.pkl', 'ctrl_55_4.pkl', 'ctrl_77_1.pkl', 'ctrl_77_2.pkl', 'ctrl_77_3.pkl', 'ctrl_77_4.pkl', 'link_18_1.pkl', 'link_18_2.pkl', 'link_18_3.pkl', 'link_18_4.pkl', 'link_33_1.pkl', 'link_33_2.pkl', 'link_33_3.pkl', 'link_33_4.pkl']
# Training data:  Dataset DatasetFolder
#     Number of datapoints: 371
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented_verb/train_cookie_theft
# Validation data:  Dataset DatasetFolder
#     Number of datapoints: 93
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented_verb/val_cookie_theft
# Test data:  Dataset DatasetFolder
#     Number of datapoints: 48
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented_verb/test_cookie_theft
# [1,     1] loss: 0.06782
# [1,    11] loss: 0.68829
# [1,    21] loss: 0.70463
# [1,    31] loss: 0.68922
# [1,    41] loss: 0.69149
# [1,    51] loss: 0.65831
# [1,    61] loss: 0.67921
# [1,    71] loss: 0.66107
# [1,    81] loss: 0.69501
# [1,    91] loss: 0.69877
# epoch 1 average training loss: 0.68609
# epoch 1 average val loss: 0.68426
# epoch 1 validation sens. : 0.47619, spec. : 0.62000; combined: 0.54810
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [2,     1] loss: 0.05906
# [2,    11] loss: 0.63767
# [2,    21] loss: 0.68070
# [2,    31] loss: 0.64568
# [2,    41] loss: 0.63129
# [2,    51] loss: 0.68895
# [2,    61] loss: 0.70210
# [2,    71] loss: 0.66546
# [2,    81] loss: 0.68132
# [2,    91] loss: 0.67457
# epoch 2 average training loss: 0.66748
# epoch 2 average val loss: 0.67814
# epoch 2 validation sens. : 0.73810, spec. : 0.40000; combined: 0.56905
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [3,     1] loss: 0.05719
# [3,    11] loss: 0.69162
# [3,    21] loss: 0.64497
# [3,    31] loss: 0.63859
# [3,    41] loss: 0.67021
# [3,    51] loss: 0.64256
# [3,    61] loss: 0.69105
# [3,    71] loss: 0.65881
# [3,    81] loss: 0.67934
# [3,    91] loss: 0.64562
# epoch 3 average training loss: 0.66126
# epoch 3 average val loss: 0.66721
# epoch 3 validation sens. : 0.74419, spec. : 0.40816; combined: 0.57617
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [4,     1] loss: 0.06517
# [4,    11] loss: 0.62450
# [4,    21] loss: 0.63289
# [4,    31] loss: 0.63341
# [4,    41] loss: 0.66164
# [4,    51] loss: 0.64138
# [4,    61] loss: 0.64980
# [4,    71] loss: 0.62019
# [4,    81] loss: 0.60605
# [4,    91] loss: 0.64841
# epoch 4 average training loss: 0.63714
# epoch 4 average val loss: 0.64649
# epoch 4 validation sens. : 0.55814, spec. : 0.67347; combined: 0.61580
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [5,     1] loss: 0.05614
# [5,    11] loss: 0.60309
# [5,    21] loss: 0.56278
# [5,    31] loss: 0.61477
# [5,    41] loss: 0.58910
# [5,    51] loss: 0.58057
# [5,    61] loss: 0.55565
# [5,    71] loss: 0.66247
# [5,    81] loss: 0.56823
# [5,    91] loss: 0.54491
# epoch 5 average training loss: 0.58775
# epoch 5 average val loss: 0.60675
# epoch 5 validation sens. : 0.57143, spec. : 0.76000; combined: 0.66571
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [6,     1] loss: 0.05923
# [6,    11] loss: 0.54853
# [6,    21] loss: 0.48003
# [6,    31] loss: 0.57213
# [6,    41] loss: 0.48186
# [6,    51] loss: 0.53095
# [6,    61] loss: 0.51582
# [6,    71] loss: 0.53829
# [6,    81] loss: 0.44709
# [6,    91] loss: 0.39799
# epoch 6 average training loss: 0.50292
# epoch 6 average val loss: 0.55168
# epoch 6 validation sens. : 0.76744, spec. : 0.73469; combined: 0.75107
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [7,     1] loss: 0.03990
# [7,    11] loss: 0.37068
# [7,    21] loss: 0.36450
# [7,    31] loss: 0.34065
# [7,    41] loss: 0.48486
# [7,    51] loss: 0.35742
# [7,    61] loss: 0.35548
# [7,    71] loss: 0.37194
# [7,    81] loss: 0.48643
# [7,    91] loss: 0.38126
# epoch 7 average training loss: 0.38801
# epoch 7 average val loss: 0.51561
# epoch 7 validation sens. : 0.71429, spec. : 0.80000; combined: 0.75714
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [8,     1] loss: 0.03972
# [8,    11] loss: 0.29436
# [8,    21] loss: 0.24231
# [8,    31] loss: 0.30475
# [8,    41] loss: 0.29743
# [8,    51] loss: 0.27440
# [8,    61] loss: 0.25382
# [8,    71] loss: 0.34050
# [8,    81] loss: 0.19264
# [8,    91] loss: 0.25551
# epoch 8 average training loss: 0.27637
# epoch 8 average val loss: 0.44553
# epoch 8 validation sens. : 0.81395, spec. : 0.81633; combined: 0.81514
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [9,     1] loss: 0.01396
# [9,    11] loss: 0.22261
# [9,    21] loss: 0.19708
# [9,    31] loss: 0.18712
# [9,    41] loss: 0.16817
# [9,    51] loss: 0.19695
# [9,    61] loss: 0.19771
# [9,    71] loss: 0.17236
# [9,    81] loss: 0.22338
# [9,    91] loss: 0.24719
# epoch 9 average training loss: 0.20443
# epoch 9 average val loss: 0.45572
# epoch 9 validation sens. : 0.80952, spec. : 0.82000; combined: 0.81476
#
#  Epochs without improvement =  1
# [10,     1] loss: 0.01985
# [10,    11] loss: 0.10624
# [10,    21] loss: 0.13373
# [10,    31] loss: 0.18198
# [10,    41] loss: 0.11993
# [10,    51] loss: 0.14646
# [10,    61] loss: 0.14306
# [10,    71] loss: 0.21252
# [10,    81] loss: 0.11417
# [10,    91] loss: 0.12477
# epoch 10 average training loss: 0.14232
# epoch 10 average val loss: 0.36634
# epoch 10 validation sens. : 0.85714, spec. : 0.88000; combined: 0.86857
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [11,     1] loss: 0.00588
# [11,    11] loss: 0.08222
# [11,    21] loss: 0.13593
# [11,    31] loss: 0.09664
# [11,    41] loss: 0.08069
# [11,    51] loss: 0.10627
# [11,    61] loss: 0.12909
# [11,    71] loss: 0.04660
# [11,    81] loss: 0.10080
# [11,    91] loss: 0.08963
# epoch 11 average training loss: 0.09714
# epoch 11 average val loss: 0.35643
# epoch 11 validation sens. : 0.85714, spec. : 0.90000; combined: 0.87857
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [12,     1] loss: 0.00292
# [12,    11] loss: 0.06676
# [12,    21] loss: 0.05736
# [12,    31] loss: 0.06116
# [12,    41] loss: 0.08468
# [12,    51] loss: 0.06831
# [12,    61] loss: 0.03724
# [12,    71] loss: 0.10694
# [12,    81] loss: 0.05895
# [12,    91] loss: 0.04200
# epoch 12 average training loss: 0.06504
# epoch 12 average val loss: 0.34697
# epoch 12 validation sens. : 0.85714, spec. : 0.90000; combined: 0.87857
#
#  Epochs without improvement =  1
# [13,     1] loss: 0.00111
# [13,    11] loss: 0.03149
# [13,    21] loss: 0.04681
# [13,    31] loss: 0.04930
# [13,    41] loss: 0.03066
# [13,    51] loss: 0.06355
# [13,    61] loss: 0.04669
# [13,    71] loss: 0.03341
# [13,    81] loss: 0.03199
# [13,    91] loss: 0.06624
# epoch 13 average training loss: 0.04367
# epoch 13 average val loss: 0.37361
# epoch 13 validation sens. : 0.88372, spec. : 0.87755; combined: 0.88064
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [14,     1] loss: 0.00980
# [14,    11] loss: 0.03036
# [14,    21] loss: 0.03234
# [14,    31] loss: 0.02803
# [14,    41] loss: 0.02403
# [14,    51] loss: 0.04096
# [14,    61] loss: 0.02028
# [14,    71] loss: 0.02488
# [14,    81] loss: 0.02613
# [14,    91] loss: 0.02542
# epoch 14 average training loss: 0.02865
# epoch 14 average val loss: 0.37049
# epoch 14 validation sens. : 0.90476, spec. : 0.86000; combined: 0.88238
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [15,     1] loss: 0.00038
# [15,    11] loss: 0.01380
# [15,    21] loss: 0.02576
# [15,    31] loss: 0.02282
# [15,    41] loss: 0.01165
# [15,    51] loss: 0.01860
# [15,    61] loss: 0.01431
# [15,    71] loss: 0.01346
# [15,    81] loss: 0.02447
# [15,    91] loss: 0.02681
# epoch 15 average training loss: 0.01880
# epoch 15 average val loss: 0.40848
# epoch 15 validation sens. : 0.88372, spec. : 0.87755; combined: 0.88064
#
#  Epochs without improvement =  1
# [16,     1] loss: 0.00242
# [16,    11] loss: 0.01769
# [16,    21] loss: 0.01226
# [16,    31] loss: 0.01413
# [16,    41] loss: 0.01248
# [16,    51] loss: 0.01531
# [16,    61] loss: 0.01372
# [16,    71] loss: 0.00918
# [16,    81] loss: 0.01365
# [16,    91] loss: 0.01911
# epoch 16 average training loss: 0.01421
# epoch 16 average val loss: 0.41005
# epoch 16 validation sens. : 0.86047, spec. : 0.89796; combined: 0.87921
#
#  Epochs without improvement =  2
# [17,     1] loss: 0.00094
# [17,    11] loss: 0.01114
# [17,    21] loss: 0.01160
# [17,    31] loss: 0.00779
# [17,    41] loss: 0.00680
# [17,    51] loss: 0.00946
# [17,    61] loss: 0.00851
# [17,    71] loss: 0.00841
# [17,    81] loss: 0.00801
# [17,    91] loss: 0.01135
# epoch 17 average training loss: 0.00916
# epoch 17 average val loss: 0.40010
# epoch 17 validation sens. : 0.90698, spec. : 0.87755; combined: 0.89226
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [18,     1] loss: 0.00155
# [18,    11] loss: 0.00776
# [18,    21] loss: 0.00642
# [18,    31] loss: 0.00703
# [18,    41] loss: 0.00524
# [18,    51] loss: 0.00912
# [18,    61] loss: 0.00956
# [18,    71] loss: 0.00991
# [18,    81] loss: 0.00764
# [18,    91] loss: 0.00316
# epoch 18 average training loss: 0.00741
# epoch 18 average val loss: 0.43699
# epoch 18 validation sens. : 0.86047, spec. : 0.89796; combined: 0.87921
#
#  Epochs without improvement =  1
# [19,     1] loss: 0.00032
# [19,    11] loss: 0.00647
# [19,    21] loss: 0.00662
# [19,    31] loss: 0.00472
# [19,    41] loss: 0.00502
# [19,    51] loss: 0.00464
# [19,    61] loss: 0.00434
# [19,    71] loss: 0.00547
# [19,    81] loss: 0.00621
# [19,    91] loss: 0.00968
# epoch 19 average training loss: 0.00585
# epoch 19 average val loss: 0.44189
# epoch 19 validation sens. : 0.88372, spec. : 0.87755; combined: 0.88064
#
#  Epochs without improvement =  2
# [20,     1] loss: 0.00027
# [20,    11] loss: 0.00562
# [20,    21] loss: 0.00309
# [20,    31] loss: 0.00679
# [20,    41] loss: 0.00296
# [20,    51] loss: 0.00472
# [20,    61] loss: 0.00418
# [20,    71] loss: 0.00428
# [20,    81] loss: 0.00378
# [20,    91] loss: 0.00543
# epoch 20 average training loss: 0.00449
# epoch 20 average val loss: 0.43631
# epoch 20 validation sens. : 0.86047, spec. : 0.91837; combined: 0.88942
#
#  Epochs without improvement =  3
#
#  Stopped training because 3 epochs without improvement. . .
# <ipython-input-13-659fe441e304>:267: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('./best_base_STNet_fold_pd_'+str(k) +'.pt', map_location=device))
# Test set sens. : 0.66667, spec. : 0.45833, combined: 0.56250, auc: 0.51215
#
#  Average 10-fold CV test sensitivity: 0.54714, specificity: 0.68088, combined: 0.61401, AUC: 0.56458
# sensitivities:  [0.5471428571428572]
# specificities:  [0.6808847402597402]
# combined:  [0.6140137987012988]
# auc:  [0.5645804022366522]
# average sensitivity:  0.5471428571428572
# average specificity:  0.6808847402597402
# average combined:  0.6140137987012988
# average auc:  0.5645804022366522
