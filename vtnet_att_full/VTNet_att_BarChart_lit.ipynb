# %% [markdown]
# <a href="https://colab.research.google.com/github/ethanwongca/hai_work/blob/main/vtnet_att_full/VTNet_att_BarChart_lit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
BASE_DIR = "/content/drive/My Drive/msnv_data/VTNet_att/"
# Out:
# Mounted at /content/drive

# %%
import os
import random
import shutil
import math

import torch
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets
import matplotlib.pyplot as plt
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch import autograd

from PIL import Image

import numpy as np
import pickle
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
import sys
sys.path.append("/content/drive/My Drive/msnv_data/VTNet_att/")
import utils

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

BATCH_SIZE=2
MANUAL_SEED = 1
HIDDEN_SIZE = 256
INPUT_SIZE=6
utils.INPUT_SIZE = INPUT_SIZE

# %%
transform = transforms.Compose(
    [transforms.Resize((150,150)),
     transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# %%
class VTNet(nn.Module):
    def __init__(self,
                 input_size=6,
                 rnn_hidden_size=256,
                 output_size=2,
                 batch_size=2,
                 rnn_type='gru',
                 rnn_num_layers=1,
                 n_channels_1=6,
                 kernel_size_1=5,
                 n_channels_2=16,
                 kernel_size_2=5,
                 img_n_vert=150,
                 img_n_hor=150):
        """

        Args:
            input_size (int):
            hidden_size (int):
            output_size (int):
            batch_size (int):
            rnn_type (int):
            num_layers (int):
        """
        super(VTNet, self).__init__()

        self.n_channels_2 = n_channels_2


        # CNN portion
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=n_channels_1, kernel_size=kernel_size_1, stride=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(in_channels=n_channels_1, out_channels=n_channels_2, kernel_size=kernel_size_2, stride=1)
        # output size calculations
        self.conv1_out_vert = img_n_vert - kernel_size_1 + 1
        self.conv1_out_hor = img_n_hor - kernel_size_1 + 1
        self.mp1_out_vert = int(np.floor((self.conv1_out_vert - 2)/2) + 1)
        self.mp1_out_hor = int(np.floor((self.conv1_out_hor - 2) / 2) + 1)
        self.conv2_out_vert = self.mp1_out_vert - kernel_size_2 + 1
        self.conv2_out_hor = self.mp1_out_hor - kernel_size_2 + 1
        self.mp2_out_vert = int(np.floor((self.conv2_out_vert - 2)/2) + 1)
        self.mp2_out_hor = int(np.floor((self.conv2_out_hor - 2) / 2) + 1)
        self.fc1 = nn.Linear(n_channels_2 * self.mp2_out_hor * self.mp2_out_vert, 50)
        self.fc2 = nn.Linear(rnn_hidden_size + 50, 20)
        self.fc3 = nn.Linear(20, output_size)

        # RNN portion
        self.multihead_attn1 = nn.MultiheadAttention(embed_dim=6, num_heads=1)
        #self.multihead_attn2 = nn.MultiheadAttention(embed_dim=256, num_heads=1)
        self.rnn_type = rnn_type
        self.input_size = input_size
        self.rnn_hidden_size = rnn_hidden_size
        self.output_size = output_size
        self.batch_size = batch_size
        self.rnn_num_layers = rnn_num_layers



        if rnn_type == 'gru':
            self.rnn = nn.GRU(input_size=input_size, hidden_size=rnn_hidden_size,
                              num_layers=rnn_num_layers)
        elif rnn_type == 'lstm':
            self.rnn = nn.LSTM(input_size=input_size, hidden_size=rnn_hidden_size,
                               num_layers=rnn_num_layers)
        else:
            self.rnn = nn.RNN(input_size=input_size, hidden_size=rnn_hidden_size,
                              num_layers=rnn_num_layers)

        self.out = nn.Linear(rnn_hidden_size, output_size)

    def forward(self, scan_path, time_series, hidden):
        """
            Args:
                scan_path (torch.Tensor): must be 349x231 for now
                time_series (torch.Tensor):
            Returns:
                x (float): logit for confusion prediction - requires cross entropy loss
        """
        x1 = self.pool(F.relu(self.conv1(scan_path)))
        x1 = self.pool(F.relu(self.conv2(x1)))
        x1 = x1.view(-1, self.n_channels_2 * self.mp2_out_hor * self.mp2_out_vert)
        x1 = F.relu(self.fc1(x1))

        # change input shape to (max_seq_size, batch_size, input_features):
        x2 = time_series.permute(1, 0, 2)
        x2, _ = self.multihead_attn1(x2, x2, x2, need_weights=False)
        x2, hidden = self.rnn(x2, hidden)
        #x2, _ = self.multihead_attn2(x2, x2, x2, need_weights=False)
        x2 = x2[-1, :, :]  # take only the last output

        x = torch.cat((x1, x2), 1)
        x = F.relu(self.fc2(x))
        x = self.fc3(x)

        return x

    def init_hidden(self, batch_size):
        """ Initializes the hidden state with zero tensors.
        """
        if self.rnn_type == 'lstm':
            return (autograd.Variable(torch.zeros(self.rnn_num_layers, batch_size, self.rnn_hidden_size)).float().to(device),
                    autograd.Variable(torch.zeros(self.rnn_num_layers, batch_size, self.rnn_hidden_size)).float().to(device))
        else:
            return autograd.Variable(torch.zeros(self.rnn_num_layers, batch_size, self.rnn_hidden_size)).float().to(device)


def st_pickle_loader(input_file_path, max_length=32000):
    """ Processes a raw data item into a scan path image and a time series
        for input into a STNet.

        Args:
            input_file_name (string): the name of the data item to be loaded
            max_length (int): max number of samples to use for a given item.
                If -1, use all samples
        Returns:
            item (numpy.ndarray): the fully processed data item for RNN input
            item_sp (PIL Image):

    """
    # Example of input_file_path = D:\Canary\multimodal-dl-framework
    # \dataset\alzheimer\tasks\cookie_theft\modalities\preprocessed\sequences
    # \eye_tracking\augmented\0_control\something.pkl

    transform = transforms.Compose([transforms.Resize((150,150)),
                                    transforms.ToTensor(),
                                    transforms.Normalize((0.5, 0.5, 0.5, 0.5), (0.5, 0.5, 0.5, 0.5))])

    """
    0 GazePointLeftX (ADCSpx)
    1 GazePointLeftY (ADCSpx)
    2 GazePointRightX (ADCSpx)
    3 GazePointRightY (ADCSpx)
    4 GazePointX (ADCSpx)
    5 GazePointY (ADCSpx)
    6 GazePointX (MCSpx)
    7 GazePointY (MCSpx)
    8 GazePointLeftX (ADCSmm)
    9 GazePointLeftY (ADCSmm)
    10 GazePointRightX (ADCSmm)
    11 GazePointRightY (ADCSmm)
    12 DistanceLeft
    13 DistanceRight
    14 PupilLeft
    15 PupilRight
    16 FixationPointX (MCSpx)
    17 FixationPointY (MCSpx)
    18 FixationLength
    """

    file = open(input_file_path, 'rb')
    item = pickle.load(file)
    item = item.values
    item[:,0] = (item[:,0] + item[:,2])/2 #column 0 is now ave Gx
    item[:,1] = (item[:,1] + item[:,3])/2 #column 1 is now ave Gy
    item = item[item[:,0] > 0]
    item = abs(item)
    item[item == 1.0] = -1.0
    item = item[:,[0, 1, 12, 13, 14, 15]] # drop all but Gx average, Gy average, Left eye distance, left eye pupil, right eye distance, right eye pupil

    if len(item) == 0:
        item = np.zeros((1000, 6))
    else:
        if max_length != -1:
            item = item[-max_length:,:]
            if len(item) < max_length:
                num_zeros_to_pad = (max_length)-len(item)
                item = np.append(np.zeros((num_zeros_to_pad, len(item[0]))), item, axis=0)
    file.close()

    # input_filepath_example: r"D:\Canary\dataset\augmented\train2\patient\Gaze_HE-224-4.pkl"
    filename = input_file_path.split(os.sep)[-1].split('.')[0]
    category = input_file_path.split(os.sep)[-3]

    #check high low
    path_to_sp = os.path.join(BASE_DIR, "msnv_final_data", TASK, "high", "images", filename + '.png')

    # Check if the file exists, if not, try "low"
    if not os.path.exists(path_to_sp):
        path_to_sp = os.path.join(BASE_DIR, "msnv_final_data", TASK, "low", "images", filename + '.png')

    im = Image.open(path_to_sp)
    item_sp = transform(im)[0:3,:,:]
    return item, item_sp

# %% [markdown]
# # Bar Chart Lit

# %%
TASK = "BarChartLit_label"

# %%
def cross_validate( model_type,
                    folds,
                    epochs,
                    criterion_type,
                    optimizer_type,
                    confused_path,
                    not_confused_path,
                    print_every,
                    plot_every,
                    hidden_size,
                    num_layers,
                    down_sample_training=False,
                    learning_rate=0.0001,
                    path_to_data_split = os.path.join(BASE_DIR, "barchart_lit.pickle"),
                    verbose=False,
                   patience=3
                  ):
    """
        Perform Cross Validation of the model using k-folds.

        Args:
            model_type (string): the type of RNN to use. Must be 'lstm', 'gru', or 'rnn'
            epochs (int): the max number of epochs to train the model for each fold
            criterion_type (string): the name loss function to use for training. Currently must be 'NLLLoss'
            optimizer_type (string): the name of learning algorithm to use for training. ex 'Adam'
            confused_path (string): the path to the folder containing the confused data samples
            not_confused_path (string): the path to the folder containing the not_confused data samples
            print_every (int): the number of batches to train for before printing relevant stats
            plot_every (int): the number of batches to train for before recording relevant stats, which
                will be plotted after each fold
            hidden_size (int): the number of hidden units for each layer of the RNN
            num_layers (int): the number of hidden_unit sized layers of the RNN
            down_sample_training (boolean): if True training set will be balanced by down sampling not_confused
            learning_rate (float): the first learning rate to be used by the optimizer
            path_to_data_split (string): relative path to the file containing the item names for each CV fold
            verbose (boolean): if True, function will print additional stats

        Returns: (list,list,list,list,list)
            cv_val_sens (list): list containing the validation sensitivity for each fold
            cv_val_spec (list): list containing the validation specificity for each fold
            cv_test_combined (list): list containing the combined test accuracy for each fold
    """

    #ensure same items appear in folds, for reproducibility:
    infile = open(path_to_data_split,'rb')
    split = pickle.load(infile)
    infile.close()

    train_confused_splits = split[0]
    test_confused_splits = split[1]
    train_not_confused_splits = split[2]
    test_not_confused_splits = split[3]


    cv_test_sens = []
    cv_test_spec = []
    cv_test_combined = []
    cv_auc = []

    for k in range(folds):
        print("\nFold ", k+1)
        # Get data item file names for this fold and downsample not_confused to balance training set
        train_confused, \
        train_not_confused, \
        val_confused, \
        val_not_confused = \
        utils.get_train_val_split(train_confused_splits[k],
                                  train_not_confused_splits[k],
                                  percent_val_set=0.2)

        if down_sample_training:
            if len(train_not_confused) > len(train_confused):
                train_not_confused = random.sample(train_not_confused, k=(len(train_confused)))
            elif len(train_confused) > len(train_not_confused):
                train_confused = random.sample(train_confused, k=(len(train_not_confused)))

        test_confused = test_confused_splits[k]
        test_not_confused = test_not_confused_splits[k]

        if verbose:
            print("Patient items in training set: ", len(train_confused))
            print("Control items in training set: ", len(train_not_confused))
            print("Patient items in validation set: ", len(val_confused))
            print("Control items in validation set: ", len(val_not_confused))

        if verbose:
            print("\nTest patient items:\n")
            print(test_confused)

        local_train_confused_path = os.path.join(BASE_DIR, 'dataset/augmented/train_cookie_theft/patient/')
        local_val_confused_path = os.path.join(BASE_DIR, 'dataset/augmented/val_cookie_theft/patient/')
        local_test_confused_path = os.path.join(BASE_DIR, 'dataset/augmented/test_cookie_theft/patient/')
        local_train_not_confused_path = os.path.join(BASE_DIR, 'dataset/augmented/train_cookie_theft/control/')
        local_val_not_confused_path = os.path.join(BASE_DIR, 'dataset/augmented/val_cookie_theft/control/')
        local_test_not_confused_path = os.path.join(BASE_DIR, 'dataset/augmented/test_cookie_theft/control/')

        # Remove any old directories
        if os.path.exists(local_train_confused_path):
            shutil.rmtree(local_train_confused_path)
        if os.path.exists(local_val_confused_path):
            shutil.rmtree(local_val_confused_path)
        if os.path.exists(local_test_confused_path):
            shutil.rmtree(local_test_confused_path)

        if os.path.exists(local_train_not_confused_path):
            shutil.rmtree(local_train_not_confused_path)
        if os.path.exists(local_val_not_confused_path):
            shutil.rmtree(local_val_not_confused_path)
        if os.path.exists(local_test_not_confused_path):
            shutil.rmtree(local_test_not_confused_path)

        # Make new temp directories
        os.makedirs(local_train_confused_path)
        for i in train_confused:
            shutil.copy(src=confused_path+i,dst=local_train_confused_path+i)

        os.makedirs(local_val_confused_path)
        for i in val_confused:
            shutil.copy(src=confused_path+i,dst=local_val_confused_path+i)

        os.makedirs(local_test_confused_path)
        for i in test_confused:
            shutil.copy(src=confused_path+i,dst=local_test_confused_path+i)

        os.makedirs(local_train_not_confused_path)
        for i in train_not_confused:
            shutil.copy(src=not_confused_path+i,dst=local_train_not_confused_path+i)

        os.makedirs(local_val_not_confused_path)
        for i in val_not_confused:
            shutil.copy(src=not_confused_path+i,dst=local_val_not_confused_path+i)

        os.makedirs(local_test_not_confused_path)
        for i in test_not_confused:
            shutil.copy(src=not_confused_path+i,dst=local_test_not_confused_path+i)

        # Prepare training and validation data
        trainset = datasets.DatasetFolder(os.path.join(BASE_DIR, 'dataset/augmented/train_cookie_theft'),
                                               loader=st_pickle_loader,
                                               extensions='.pkl')

        valset = datasets.DatasetFolder(os.path.join(BASE_DIR, 'dataset/augmented/val_cookie_theft'),
                                                 loader=st_pickle_loader,
                                                 extensions='.pkl')

        testset = datasets.DatasetFolder(os.path.join(BASE_DIR, 'dataset/augmented/test_cookie_theft'),
                                                 loader=st_pickle_loader,
                                                 extensions='.pkl')


        trainloader = torch.utils.data.DataLoader(trainset, batch_size=2, shuffle=True, drop_last=True)

        testloader = torch.utils.data.DataLoader(testset, batch_size=2, shuffle=True, drop_last=True)


        valloader = torch.utils.data.DataLoader(valset, batch_size=2, shuffle=True, drop_last=True)

        print("Training data: ", trainset)
        print("Validation data: ", valset)
        print("Test data: ", testset)

        torch.manual_seed(MANUAL_SEED)
        if model_type == 'gru':
            model = VTNet(rnn_type='gru', rnn_num_layers=num_layers, rnn_hidden_size=hidden_size).float().to(device)
        elif model_type == 'lstm':
            model = VTNet(rnn_type='lstm', rnn_num_layers=num_layers, rnn_hidden_size=hidden_size).float().to(device)
        else:
            model = VTNet(rnn_type='rnn', rnn_num_layers=num_layers, rnn_hidden_size=hidden_size).float().to(device)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        #save fresh model to clear any old ones out
        torch.save(model.state_dict(), './best_STNet_fold_pd_'+str(k) +'.pt')
        best_val_combined = 0.0
        #Train model
        epochs_without_improvement = 0
        for epoch in range(epochs):  # loop over the dataset multiple times
            running_loss = 0.0
            epoch_loss = 0.0
            for i, data in enumerate(trainloader, 0):
                # get the inputs; data is a list of [inputs, labels]
                inputs, labels = data
                item, item_sp = inputs[0].float(), inputs[1].float()
                item, item_sp, labels = item.to(device), item_sp[:,0,:,:].unsqueeze(1).to(device), labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()
                hidden = model.init_hidden(BATCH_SIZE)
                # forward + backward + optimize
                outputs = model(scan_path=item_sp, time_series=item, hidden=hidden)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()

                # print statistics
                running_loss += loss.item()
                epoch_loss += loss.item()
                if i % 10 == 0:
                    print('[%d, %5d] loss: %.5f' %
                          (epoch + 1, i + 1, running_loss / 10))
                    running_loss = 0.0
            print('epoch %d average training loss: %.5f' % (epoch + 1, epoch_loss/ len(trainloader)))

            #check validation set metrics
            running_val_loss = 0.0
            y_true = torch.zeros((len(valloader)*4))
            y_scores = torch.zeros((len(valloader)*4, 2))
            with torch.no_grad():

                for i, data in enumerate(valloader, 0):
                    # get the inputs; data is a list of [inputs, labels]
                    inputs, labels = data
                    item, item_sp = inputs[0].float(), inputs[1].float()
                    item, item_sp, labels = item.to(device), item_sp[:,0,:,:].unsqueeze(1).to(device), labels.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()
                    hidden = model.init_hidden(BATCH_SIZE)
                    # forward + backward + optimize
                    outputs = model(scan_path=item_sp, time_series=item, hidden=hidden)
                    loss = criterion(outputs, labels)
                    running_val_loss += loss.item()
                    #keep track of predictions
                    num_items = outputs.shape[0]
                    y_true[i*num_items: i*num_items + num_items] = labels
                    y_scores[i*num_items: i*num_items + num_items, :] = outputs.squeeze()

                val_loss = running_val_loss/ len(valloader)
                print('epoch %d average val loss: %.5f' % (epoch + 1, val_loss))

                #check metrics:
                # no option to specify positive label, so flipping for confused=1
                y_true_flipped = np.array(y_true.numpy(), copy=True)
                y_true_flipped[y_true == 1] = 0
                y_true_flipped[y_true == 0] = 1
                #auc = roc_auc_score(y_true_flipped, y_scores.numpy()[:,0])
                # roc_curve expects y_scores to be probability values of the positive class
                fpr, tpr, thresholds = roc_curve(y_true, y_scores.numpy()[:,0], pos_label=0)

                sensitivity, specificity, \
                accuracy = utils.optimal_threshold_sensitivity_specificity(thresholds[1:],
                                                                           tpr[1:],
                                                                           fpr[1:],
                                                                           y_true,
                                                                           y_scores.numpy()[:,0])
                combined = (sensitivity + specificity ) / 2.0
                print("epoch %d validation sens. : %.5f, spec. : %.5f; combined: %.5f"
                      % (epoch + 1, sensitivity, specificity, combined))
                if combined > best_val_combined:
                    print("New best validation combined accuracy found. Saving model...")
                    best_val_combined = combined
                    torch.save(model.state_dict(), './best_base_STNet_fold_pd_'+str(k) +'.pt')
                    epochs_without_improvement = 0
                else:
                    epochs_without_improvement = epochs_without_improvement + 1

                print("\n Epochs without improvement = ", epochs_without_improvement)

            if epochs_without_improvement == patience:
                print("\n Stopped training because {} epochs without improvement. . .".format(patience))
                break

        y_true = torch.tensor([]).to(device)
        y_scores = torch.tensor([]).to(device)
        with torch.no_grad():
            model.load_state_dict(torch.load('./best_base_STNet_fold_pd_'+str(k) +'.pt', map_location=device))
            for i, data in enumerate(testloader, 0):
                # get the inputs; data is a list of [inputs, labels]
                inputs, labels = data
                item, item_sp = inputs[0].float(), inputs[1].float()
                item, item_sp, labels = item.to(device), item_sp[:,0,:,:].unsqueeze(1).to(device), labels.to(device)
                # zero the parameter gradients
                optimizer.zero_grad()
                hidden = model.init_hidden(BATCH_SIZE)
                # forward + backward + optimize
                outputs = model(scan_path=item_sp, time_series=item, hidden=hidden)
                loss = criterion(outputs, labels)
                running_val_loss += loss.item()
                #keep track of predictions
                num_items = outputs.shape[0]
                y_true = torch.cat((y_true, labels))
                y_scores = torch.cat((y_scores,outputs.squeeze()))
                #y_true[i*num_items: i*num_items + num_items] = labels
                #y_scores[i*num_items: i*num_items + num_items, :] = outputs.squeeze()

            #y_pred = torch.argmax(y_scores, axis=1)

            #check metrics:
            # no option to specify positive label, so flipping for confused=1
            y_true = y_true.cpu()
            y_scores = y_scores.cpu()
            y_true_flipped = np.array(y_true.numpy(), copy=True)
            y_true_flipped[y_true == 1] = 0
            y_true_flipped[y_true == 0] = 1
            auc = roc_auc_score(y_true_flipped, y_scores.numpy()[:,0])
            # roc_curve expects y_scores to be probability values of the positive class
            fpr, tpr, thresholds = roc_curve(y_true, y_scores.numpy()[:,0], pos_label=0)

            sensitivity, specificity, \
            accuracy = utils.optimal_threshold_sensitivity_specificity(thresholds[1:],
                                                                       tpr[1:],
                                                                       fpr[1:],
                                                                       y_true,
                                                                       y_scores.numpy()[:,0])
            combined = (sensitivity + specificity ) / 2.0

            print("Test set sens. : %.5f, spec. : %.5f, combined: %.5f, auc: %.5f" % (sensitivity, specificity, combined, auc))
            cv_test_sens.append(sensitivity)
            cv_test_spec.append(specificity)
            cv_test_combined.append(combined)
            cv_auc.append(auc)

    print("\n Average 10-fold CV test sensitivity: %.5f, specificity: %.5f, combined: %.5f, AUC: %.5f" %
          ((sum(cv_test_sens)/len(cv_test_sens)),
           (sum(cv_test_spec)/len(cv_test_spec)),
           (sum(cv_test_combined)/len(cv_test_combined)),
           (sum(cv_auc)/len(cv_auc))))
    return cv_test_sens, cv_test_spec, cv_test_combined, cv_auc

# %%
# compute for 10 different seeds
sens = []
spec = []
comb = []
auc = []


for i in range(1):
# baseline 10-fold CV with GRU
    np.random.seed(MANUAL_SEED+i)
    random.seed(MANUAL_SEED+i)
    torch.manual_seed(MANUAL_SEED+i)

    sens_list, spec_list, comb_list, auc_list = cross_validate(model_type='gru',
                                               folds=10,
                                               epochs=100,
                                               criterion_type='NLLLoss',
                                               optimizer_type='Adam',
                                               confused_path=os.path.join(
    BASE_DIR, "msnv_final_data",
    TASK, "high/pickle_files/"
),
                                               not_confused_path=os.path.join(
    BASE_DIR, "msnv_final_data",
    TASK, "low/pickle_files/"
),
                                               print_every=1,
                                               plot_every=1,
                                               hidden_size=HIDDEN_SIZE,
                                               down_sample_training=False,
                                               num_layers=1,
                                               learning_rate=0.0001,
                                               verbose=True)
    # add mean of each measure for 10-fold CV to list
    sens.append(np.mean(sens_list))
    spec.append(np.mean(spec_list))
    comb.append(np.mean(comb_list))
    auc.append(np.mean(auc_list))

print("sensitivities: ", sens)
print("specificities: ", spec)
print("combined: ", comb)
print("auc: ", auc)

print("average sensitivity: ", np.mean(sens))
print("average specificity: ", np.mean(spec))
print("average combined: ", np.mean(comb))
print("average auc: ", np.mean(auc))
# Out:
# Fold  1
# Patient items in training set:  172
# Control items in training set:  196
# Patient items in validation set:  48
# Control items in validation set:  44
#
# Test patient items:
#
# ['bar_34_1.pkl', 'bar_34_2.pkl', 'bar_34_3.pkl', 'bar_34_4.pkl', 'bar_46_1.pkl', 'bar_46_2.pkl', 'bar_46_3.pkl', 'bar_46_4.pkl', 'ctrl_42_1.pkl', 'ctrl_42_2.pkl', 'ctrl_42_3.pkl', 'ctrl_42_4.pkl', 'ctrl_58_1.pkl', 'ctrl_58_2.pkl', 'ctrl_58_3.pkl', 'ctrl_58_4.pkl', 'ctrl_68_1.pkl', 'ctrl_68_2.pkl', 'ctrl_68_3.pkl', 'ctrl_68_4.pkl', 'ctrl_97_1.pkl', 'ctrl_97_2.pkl', 'ctrl_97_3.pkl', 'ctrl_97_4.pkl', 'link_34_1.pkl', 'link_34_2.pkl', 'link_34_3.pkl', 'link_34_4.pkl']
# Training data:  Dataset DatasetFolder
#     Number of datapoints: 368
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented/train_cookie_theft
# Validation data:  Dataset DatasetFolder
#     Number of datapoints: 92
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented/val_cookie_theft
# Test data:  Dataset DatasetFolder
#     Number of datapoints: 52
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented/test_cookie_theft
# [1,     1] loss: 0.06796
# [1,    11] loss: 0.69425
# [1,    21] loss: 0.68097
# [1,    31] loss: 0.67556
# [1,    41] loss: 0.68396
# [1,    51] loss: 0.66420
# [1,    61] loss: 0.72624
# [1,    71] loss: 0.65320
# [1,    81] loss: 0.66070
# [1,    91] loss: 0.65722
# [1,   101] loss: 0.69130
# [1,   111] loss: 0.73249
# [1,   121] loss: 0.72022
# [1,   131] loss: 0.68769
# [1,   141] loss: 0.67854
# [1,   151] loss: 0.67097
# [1,   161] loss: 0.72959
# [1,   171] loss: 0.69617
# [1,   181] loss: 0.66929
# epoch 1 average training loss: 0.68808
# epoch 1 average val loss: 0.69153
# epoch 1 validation sens. : 0.08824, spec. : 0.87500; combined: 0.48162
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [2,     1] loss: 0.06307
# [2,    11] loss: 0.64032
# [2,    21] loss: 0.70445
# [2,    31] loss: 0.63720
# [2,    41] loss: 0.62220
# [2,    51] loss: 0.64689
# [2,    61] loss: 0.69288
# [2,    71] loss: 0.65040
# [2,    81] loss: 0.63390
# [2,    91] loss: 0.72836
# [2,   101] loss: 0.74273
# [2,   111] loss: 0.66419
# [2,   121] loss: 0.68419
# [2,   131] loss: 0.66617
# [2,   141] loss: 0.66363
# [2,   151] loss: 0.67985
# [2,   161] loss: 0.63298
# [2,   171] loss: 0.63975
# [2,   181] loss: 0.66125
# epoch 2 average training loss: 0.66576
# epoch 2 average val loss: 0.66130
# epoch 2 validation sens. : 0.95588, spec. : 0.29167; combined: 0.62377
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [3,     1] loss: 0.06204
# [3,    11] loss: 0.66708
# [3,    21] loss: 0.64314
# [3,    31] loss: 0.59611
# [3,    41] loss: 0.64128
# [3,    51] loss: 0.62040
# [3,    61] loss: 0.58015
# [3,    71] loss: 0.67206
# [3,    81] loss: 0.62324
# [3,    91] loss: 0.59983
# [3,   101] loss: 0.61934
# [3,   111] loss: 0.59581
# [3,   121] loss: 0.70455
# [3,   131] loss: 0.57457
# [3,   141] loss: 0.62696
# [3,   151] loss: 0.57578
# [3,   161] loss: 0.59309
# [3,   171] loss: 0.63681
# [3,   181] loss: 0.58800
# epoch 3 average training loss: 0.62001
# epoch 3 average val loss: 0.64558
# epoch 3 validation sens. : 0.98529, spec. : 0.27083; combined: 0.62806
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [4,     1] loss: 0.07741
# [4,    11] loss: 0.47748
# [4,    21] loss: 0.49940
# [4,    31] loss: 0.48490
# [4,    41] loss: 0.53510
# [4,    51] loss: 0.56892
# [4,    61] loss: 0.49016
# [4,    71] loss: 0.54802
# [4,    81] loss: 0.69565
# [4,    91] loss: 0.50062
# [4,   101] loss: 0.57886
# [4,   111] loss: 0.51480
# [4,   121] loss: 0.52209
# [4,   131] loss: 0.55432
# [4,   141] loss: 0.43875
# [4,   151] loss: 0.51408
# [4,   161] loss: 0.46670
# [4,   171] loss: 0.44268
# [4,   181] loss: 0.50756
# epoch 4 average training loss: 0.51950
# epoch 4 average val loss: 0.58740
# epoch 4 validation sens. : 0.97794, spec. : 0.41667; combined: 0.69730
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [5,     1] loss: 0.03512
# [5,    11] loss: 0.44573
# [5,    21] loss: 0.39739
# [5,    31] loss: 0.40389
# [5,    41] loss: 0.45717
# [5,    51] loss: 0.33466
# [5,    61] loss: 0.35644
# [5,    71] loss: 0.34203
# [5,    81] loss: 0.39377
# [5,    91] loss: 0.38807
# [5,   101] loss: 0.27081
# [5,   111] loss: 0.44635
# [5,   121] loss: 0.36268
# [5,   131] loss: 0.48526
# [5,   141] loss: 0.37328
# [5,   151] loss: 0.30240
# [5,   161] loss: 0.33494
# [5,   171] loss: 0.27151
# [5,   181] loss: 0.34548
# epoch 5 average training loss: 0.37244
# epoch 5 average val loss: 0.48184
# epoch 5 validation sens. : 0.99265, spec. : 0.50000; combined: 0.74632
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [6,     1] loss: 0.03166
# [6,    11] loss: 0.20705
# [6,    21] loss: 0.25311
# [6,    31] loss: 0.28828
# [6,    41] loss: 0.18094
# [6,    51] loss: 0.24803
# [6,    61] loss: 0.19518
# [6,    71] loss: 0.33695
# [6,    81] loss: 0.09139
# [6,    91] loss: 0.25792
# [6,   101] loss: 0.28087
# [6,   111] loss: 0.21146
# [6,   121] loss: 0.16058
# [6,   131] loss: 0.22671
# [6,   141] loss: 0.19785
# [6,   151] loss: 0.18575
# [6,   161] loss: 0.28525
# [6,   171] loss: 0.12491
# [6,   181] loss: 0.22700
# epoch 6 average training loss: 0.21997
# epoch 6 average val loss: 0.42893
# epoch 6 validation sens. : 0.97794, spec. : 0.62500; combined: 0.80147
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [7,     1] loss: 0.00683
# [7,    11] loss: 0.17923
# [7,    21] loss: 0.12068
# [7,    31] loss: 0.18810
# [7,    41] loss: 0.14036
# [7,    51] loss: 0.08912
# [7,    61] loss: 0.14114
# [7,    71] loss: 0.13679
# [7,    81] loss: 0.10677
# [7,    91] loss: 0.12044
# [7,   101] loss: 0.14215
# [7,   111] loss: 0.07546
# [7,   121] loss: 0.13606
# [7,   131] loss: 0.10052
# [7,   141] loss: 0.09093
# [7,   151] loss: 0.10990
# [7,   161] loss: 0.16745
# [7,   171] loss: 0.13130
# [7,   181] loss: 0.09498
# epoch 7 average training loss: 0.12851
# epoch 7 average val loss: 0.38604
# epoch 7 validation sens. : 0.99265, spec. : 0.64583; combined: 0.81924
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [8,     1] loss: 0.00366
# [8,    11] loss: 0.10666
# [8,    21] loss: 0.05322
# [8,    31] loss: 0.06935
# [8,    41] loss: 0.08333
# [8,    51] loss: 0.07820
# [8,    61] loss: 0.06935
# [8,    71] loss: 0.05619
# [8,    81] loss: 0.04655
# [8,    91] loss: 0.04532
# [8,   101] loss: 0.09349
# [8,   111] loss: 0.06140
# [8,   121] loss: 0.03714
# [8,   131] loss: 0.03610
# [8,   141] loss: 0.06986
# [8,   151] loss: 0.05595
# [8,   161] loss: 0.04246
# [8,   171] loss: 0.03947
# [8,   181] loss: 0.04308
# epoch 8 average training loss: 0.05978
# epoch 8 average val loss: 0.34987
# epoch 8 validation sens. : 0.96324, spec. : 0.87500; combined: 0.91912
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [9,     1] loss: 0.00110
# [9,    11] loss: 0.02356
# [9,    21] loss: 0.01582
# [9,    31] loss: 0.02210
# [9,    41] loss: 0.02996
# [9,    51] loss: 0.04349
# [9,    61] loss: 0.03095
# [9,    71] loss: 0.06166
# [9,    81] loss: 0.02294
# [9,    91] loss: 0.04604
# [9,   101] loss: 0.04433
# [9,   111] loss: 0.04045
# [9,   121] loss: 0.03723
# [9,   131] loss: 0.05915
# [9,   141] loss: 0.02417
# [9,   151] loss: 0.03193
# [9,   161] loss: 0.04087
# [9,   171] loss: 0.02860
# [9,   181] loss: 0.02326
# epoch 9 average training loss: 0.03427
# epoch 9 average val loss: 0.34530
# epoch 9 validation sens. : 1.00000, spec. : 0.83333; combined: 0.91667
#
#  Epochs without improvement =  1
# [10,     1] loss: 0.00052
# [10,    11] loss: 0.01446
# [10,    21] loss: 0.01040
# [10,    31] loss: 0.02210
# [10,    41] loss: 0.01267
# [10,    51] loss: 0.01476
# [10,    61] loss: 0.02681
# [10,    71] loss: 0.00927
# [10,    81] loss: 0.02374
# [10,    91] loss: 0.02384
# [10,   101] loss: 0.01663
# [10,   111] loss: 0.02593
# [10,   121] loss: 0.03850
# [10,   131] loss: 0.01531
# [10,   141] loss: 0.01805
# [10,   151] loss: 0.01311
# [10,   161] loss: 0.01092
# [10,   171] loss: 0.01631
# [10,   181] loss: 0.01150
# epoch 10 average training loss: 0.01781
# epoch 10 average val loss: 0.40738
# epoch 10 validation sens. : 1.00000, spec. : 0.70833; combined: 0.85417
#
#  Epochs without improvement =  2
# [11,     1] loss: 0.00129
# [11,    11] loss: 0.01872
# [11,    21] loss: 0.01394
# [11,    31] loss: 0.00997
# [11,    41] loss: 0.00903
# [11,    51] loss: 0.01062
# [11,    61] loss: 0.00619
# [11,    71] loss: 0.01097
# [11,    81] loss: 0.01215
# [11,    91] loss: 0.01112
# [11,   101] loss: 0.01245
# [11,   111] loss: 0.00702
# [11,   121] loss: 0.01249
# [11,   131] loss: 0.01076
# [11,   141] loss: 0.00755
# [11,   151] loss: 0.01228
# [11,   161] loss: 0.01329
# [11,   171] loss: 0.01114
# [11,   181] loss: 0.01201
# epoch 11 average training loss: 0.01105
# epoch 11 average val loss: 0.40790
# epoch 11 validation sens. : 1.00000, spec. : 0.79167; combined: 0.89583
#
#  Epochs without improvement =  3
#
#  Stopped training because 3 epochs without improvement. . .
# <ipython-input-6-4cddcf9c6f9d>:267: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('./best_base_STNet_fold_pd_'+str(k) +'.pt', map_location=device))
# Test set sens. : 0.62500, spec. : 0.67857, combined: 0.65179, auc: 0.72470
#
# Fold  2
# Patient items in training set:  176
# Control items in training set:  192
# Patient items in validation set:  48
# Control items in validation set:  44
#
# Test patient items:
#
# ['bar_35_1.pkl', 'bar_35_2.pkl', 'bar_35_3.pkl', 'bar_35_4.pkl', 'bar_49_1.pkl', 'bar_49_2.pkl', 'bar_49_3.pkl', 'bar_49_4.pkl', 'bar_77_1.pkl', 'bar_77_2.pkl', 'bar_77_3.pkl', 'bar_77_4.pkl', 'ctrl_19_1.pkl', 'ctrl_19_2.pkl', 'ctrl_19_3.pkl', 'ctrl_19_4.pkl', 'ctrl_79_1.pkl', 'ctrl_79_2.pkl', 'ctrl_79_3.pkl', 'ctrl_79_4.pkl', 'link_1_1.pkl', 'link_1_2.pkl', 'link_1_3.pkl', 'link_1_4.pkl']
# Training data:  Dataset DatasetFolder
#     Number of datapoints: 368
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented/train_cookie_theft
# Validation data:  Dataset DatasetFolder
#     Number of datapoints: 92
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented/val_cookie_theft
# Test data:  Dataset DatasetFolder
#     Number of datapoints: 52
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented/test_cookie_theft
# [1,     1] loss: 0.06862
# [1,    11] loss: 0.67777
# [1,    21] loss: 0.68713
# [1,    31] loss: 0.67479
# [1,    41] loss: 0.68842
# [1,    51] loss: 0.68261
# [1,    61] loss: 0.73249
# [1,    71] loss: 0.66140
# [1,    81] loss: 0.67224
# [1,    91] loss: 0.68574
# [1,   101] loss: 0.69553
# [1,   111] loss: 0.74078
# [1,   121] loss: 0.70583
# [1,   131] loss: 0.70357
# [1,   141] loss: 0.67406
# [1,   151] loss: 0.68279
# [1,   161] loss: 0.71034
# [1,   171] loss: 0.70717
# [1,   181] loss: 0.68145
# epoch 1 average training loss: 0.69170
# epoch 1 average val loss: 0.68734
# epoch 1 validation sens. : 0.92647, spec. : 0.22917; combined: 0.57782
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [2,     1] loss: 0.06835
# [2,    11] loss: 0.67274
# [2,    21] loss: 0.70300
# [2,    31] loss: 0.67645
# [2,    41] loss: 0.66505
# [2,    51] loss: 0.66271
# [2,    61] loss: 0.71263
# [2,    71] loss: 0.65697
# [2,    81] loss: 0.63369
# [2,    91] loss: 0.69522
# [2,   101] loss: 0.74633
# [2,   111] loss: 0.65967
# [2,   121] loss: 0.68361
# [2,   131] loss: 0.69545
# [2,   141] loss: 0.65970
# [2,   151] loss: 0.68052
# [2,   161] loss: 0.67057
# [2,   171] loss: 0.65000
# [2,   181] loss: 0.63648
# epoch 2 average training loss: 0.67586
# epoch 2 average val loss: 0.66077
# epoch 2 validation sens. : 0.24265, spec. : 0.72917; combined: 0.48591
#
#  Epochs without improvement =  1
# [3,     1] loss: 0.06451
# [3,    11] loss: 0.64394
# [3,    21] loss: 0.65384
# [3,    31] loss: 0.61671
# [3,    41] loss: 0.64790
# [3,    51] loss: 0.61387
# [3,    61] loss: 0.59672
# [3,    71] loss: 0.73147
# [3,    81] loss: 0.58220
# [3,    91] loss: 0.62198
# [3,   101] loss: 0.63655
# [3,   111] loss: 0.62610
# [3,   121] loss: 0.68143
# [3,   131] loss: 0.60015
# [3,   141] loss: 0.64644
# [3,   151] loss: 0.68820
# [3,   161] loss: 0.63190
# [3,   171] loss: 0.62151
# [3,   181] loss: 0.60227
# epoch 3 average training loss: 0.63704
# epoch 3 average val loss: 0.65334
# epoch 3 validation sens. : 0.21324, spec. : 0.75000; combined: 0.48162
#
#  Epochs without improvement =  2
# [4,     1] loss: 0.08410
# [4,    11] loss: 0.53211
# [4,    21] loss: 0.57516
# [4,    31] loss: 0.48280
# [4,    41] loss: 0.53103
# [4,    51] loss: 0.70022
# [4,    61] loss: 0.55332
# [4,    71] loss: 0.56456
# [4,    81] loss: 0.48823
# [4,    91] loss: 0.65247
# [4,   101] loss: 0.49176
# [4,   111] loss: 0.45931
# [4,   121] loss: 0.61925
# [4,   131] loss: 0.58275
# [4,   141] loss: 0.57086
# [4,   151] loss: 0.66025
# [4,   161] loss: 0.47774
# [4,   171] loss: 0.52202
# [4,   181] loss: 0.62179
# epoch 4 average training loss: 0.56327
# epoch 4 average val loss: 0.57509
# epoch 4 validation sens. : 0.97794, spec. : 0.39583; combined: 0.68689
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [5,     1] loss: 0.06801
# [5,    11] loss: 0.42789
# [5,    21] loss: 0.50154
# [5,    31] loss: 0.41300
# [5,    41] loss: 0.40757
# [5,    51] loss: 0.45060
# [5,    61] loss: 0.52246
# [5,    71] loss: 0.50092
# [5,    81] loss: 0.45724
# [5,    91] loss: 0.49336
# [5,   101] loss: 0.40691
# [5,   111] loss: 0.56858
# [5,   121] loss: 0.35326
# [5,   131] loss: 0.28888
# [5,   141] loss: 0.48141
# [5,   151] loss: 0.58476
# [5,   161] loss: 0.34574
# [5,   171] loss: 0.31374
# [5,   181] loss: 0.46329
# epoch 5 average training loss: 0.44480
# epoch 5 average val loss: 0.55458
# epoch 5 validation sens. : 0.99265, spec. : 0.37500; combined: 0.68382
#
#  Epochs without improvement =  1
# [6,     1] loss: 0.04378
# [6,    11] loss: 0.35269
# [6,    21] loss: 0.50317
# [6,    31] loss: 0.35295
# [6,    41] loss: 0.21640
# [6,    51] loss: 0.37902
# [6,    61] loss: 0.33372
# [6,    71] loss: 0.36656
# [6,    81] loss: 0.23833
# [6,    91] loss: 0.28725
# [6,   101] loss: 0.25454
# [6,   111] loss: 0.41822
# [6,   121] loss: 0.27400
# [6,   131] loss: 0.39413
# [6,   141] loss: 0.42800
# [6,   151] loss: 0.25472
# [6,   161] loss: 0.22855
# [6,   171] loss: 0.14477
# [6,   181] loss: 0.26090
# epoch 6 average training loss: 0.31642
# epoch 6 average val loss: 0.49695
# epoch 6 validation sens. : 0.99265, spec. : 0.54167; combined: 0.76716
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [7,     1] loss: 0.02106
# [7,    11] loss: 0.25786
# [7,    21] loss: 0.27190
# [7,    31] loss: 0.24579
# [7,    41] loss: 0.36156
# [7,    51] loss: 0.18070
# [7,    61] loss: 0.28407
# [7,    71] loss: 0.25856
# [7,    81] loss: 0.12630
# [7,    91] loss: 0.20348
# [7,   101] loss: 0.23300
# [7,   111] loss: 0.18036
# [7,   121] loss: 0.19698
# [7,   131] loss: 0.20431
# [7,   141] loss: 0.13052
# [7,   151] loss: 0.18473
# [7,   161] loss: 0.10712
# [7,   171] loss: 0.21989
# [7,   181] loss: 0.21065
# epoch 7 average training loss: 0.21154
# epoch 7 average val loss: 0.39985
# epoch 7 validation sens. : 0.98529, spec. : 0.77083; combined: 0.87806
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [8,     1] loss: 0.01614
# [8,    11] loss: 0.14965
# [8,    21] loss: 0.17613
# [8,    31] loss: 0.18513
# [8,    41] loss: 0.27147
# [8,    51] loss: 0.06981
# [8,    61] loss: 0.11502
# [8,    71] loss: 0.13972
# [8,    81] loss: 0.06608
# [8,    91] loss: 0.09563
# [8,   101] loss: 0.30087
# [8,   111] loss: 0.14187
# [8,   121] loss: 0.15228
# [8,   131] loss: 0.10024
# [8,   141] loss: 0.10077
# [8,   151] loss: 0.18457
# [8,   161] loss: 0.09094
# [8,   171] loss: 0.12387
# [8,   181] loss: 0.12521
# epoch 8 average training loss: 0.14221
# epoch 8 average val loss: 0.35899
# epoch 8 validation sens. : 0.97794, spec. : 0.83333; combined: 0.90564
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [9,     1] loss: 0.00034
# [9,    11] loss: 0.07389
# [9,    21] loss: 0.06637
# [9,    31] loss: 0.05303
# [9,    41] loss: 0.06925
# [9,    51] loss: 0.07935
# [9,    61] loss: 0.09553
# [9,    71] loss: 0.11321
# [9,    81] loss: 0.15171
# [9,    91] loss: 0.03301
# [9,   101] loss: 0.10935
# [9,   111] loss: 0.10451
# [9,   121] loss: 0.06481
# [9,   131] loss: 0.10890
# [9,   141] loss: 0.05211
# [9,   151] loss: 0.10082
# [9,   161] loss: 0.05146
# [9,   171] loss: 0.04000
# [9,   181] loss: 0.12097
# epoch 9 average training loss: 0.08115
# epoch 9 average val loss: 0.32737
# epoch 9 validation sens. : 0.98529, spec. : 0.83333; combined: 0.90931
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [10,     1] loss: 0.00096
# [10,    11] loss: 0.03845
# [10,    21] loss: 0.01512
# [10,    31] loss: 0.05256
# [10,    41] loss: 0.03766
# [10,    51] loss: 0.03441
# [10,    61] loss: 0.04170
# [10,    71] loss: 0.06131
# [10,    81] loss: 0.04541
# [10,    91] loss: 0.03363
# [10,   101] loss: 0.06910
# [10,   111] loss: 0.03671
# [10,   121] loss: 0.02384
# [10,   131] loss: 0.05801
# [10,   141] loss: 0.05465
# [10,   151] loss: 0.05670
# [10,   161] loss: 0.05926
# [10,   171] loss: 0.04224
# [10,   181] loss: 0.02399
# epoch 10 average training loss: 0.04309
# epoch 10 average val loss: 0.36839
# epoch 10 validation sens. : 0.99265, spec. : 0.70833; combined: 0.85049
#
#  Epochs without improvement =  1
# [11,     1] loss: 0.00033
# [11,    11] loss: 0.02857
# [11,    21] loss: 0.03967
# [11,    31] loss: 0.02766
# [11,    41] loss: 0.02187
# [11,    51] loss: 0.03344
# [11,    61] loss: 0.03096
# [11,    71] loss: 0.04734
# [11,    81] loss: 0.03261
# [11,    91] loss: 0.01606
# [11,   101] loss: 0.01369
# [11,   111] loss: 0.03369
# [11,   121] loss: 0.01878
# [11,   131] loss: 0.01265
# [11,   141] loss: 0.02001
# [11,   151] loss: 0.00510
# [11,   161] loss: 0.01663
# [11,   171] loss: 0.02121
# [11,   181] loss: 0.02639
# epoch 11 average training loss: 0.02441
# epoch 11 average val loss: 0.32855
# epoch 11 validation sens. : 0.98529, spec. : 0.87500; combined: 0.93015
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [12,     1] loss: 0.00338
# [12,    11] loss: 0.01526
# [12,    21] loss: 0.01728
# [12,    31] loss: 0.00985
# [12,    41] loss: 0.01976
# [12,    51] loss: 0.01207
# [12,    61] loss: 0.01607
# [12,    71] loss: 0.00917
# [12,    81] loss: 0.02210
# [12,    91] loss: 0.01771
# [12,   101] loss: 0.01230
# [12,   111] loss: 0.02069
# [12,   121] loss: 0.01099
# [12,   131] loss: 0.02374
# [12,   141] loss: 0.00722
# [12,   151] loss: 0.01728
# [12,   161] loss: 0.02140
# [12,   171] loss: 0.01511
# [12,   181] loss: 0.01432
# epoch 12 average training loss: 0.01590
# epoch 12 average val loss: 0.33890
# epoch 12 validation sens. : 0.98529, spec. : 0.91667; combined: 0.95098
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [13,     1] loss: 0.00105
# [13,    11] loss: 0.00802
# [13,    21] loss: 0.00982
# [13,    31] loss: 0.01368
# [13,    41] loss: 0.02177
# [13,    51] loss: 0.00880
# [13,    61] loss: 0.00671
# [13,    71] loss: 0.01107
# [13,    81] loss: 0.01105
# [13,    91] loss: 0.01178
# [13,   101] loss: 0.00447
# [13,   111] loss: 0.00725
# [13,   121] loss: 0.00492
# [13,   131] loss: 0.01134
# [13,   141] loss: 0.01103
# [13,   151] loss: 0.00364
# [13,   161] loss: 0.00821
# [13,   171] loss: 0.00539
# [13,   181] loss: 0.01041
# epoch 13 average training loss: 0.00967
# epoch 13 average val loss: 0.34270
# epoch 13 validation sens. : 0.98529, spec. : 0.91667; combined: 0.95098
#
#  Epochs without improvement =  1
# [14,     1] loss: 0.00090
# [14,    11] loss: 0.00444
# [14,    21] loss: 0.01131
# [14,    31] loss: 0.00537
# [14,    41] loss: 0.00536
# [14,    51] loss: 0.00910
# [14,    61] loss: 0.00575
# [14,    71] loss: 0.01118
# [14,    81] loss: 0.00768
# [14,    91] loss: 0.00314
# [14,   101] loss: 0.00814
# [14,   111] loss: 0.00532
# [14,   121] loss: 0.00689
# [14,   131] loss: 0.00379
# [14,   141] loss: 0.01501
# [14,   151] loss: 0.00425
# [14,   161] loss: 0.02105
# [14,   171] loss: 0.00472
# [14,   181] loss: 0.01010
# epoch 14 average training loss: 0.00812
# epoch 14 average val loss: 0.34818
# epoch 14 validation sens. : 0.98529, spec. : 0.91667; combined: 0.95098
#
#  Epochs without improvement =  2
# [15,     1] loss: 0.00069
# [15,    11] loss: 0.00746
# [15,    21] loss: 0.00990
# [15,    31] loss: 0.00649
# [15,    41] loss: 0.00325
# [15,    51] loss: 0.00396
# [15,    61] loss: 0.00563
# [15,    71] loss: 0.00561
# [15,    81] loss: 0.00255
# [15,    91] loss: 0.00455
# [15,   101] loss: 0.00419
# [15,   111] loss: 0.00633
# [15,   121] loss: 0.00423
# [15,   131] loss: 0.00434
# [15,   141] loss: 0.00420
# [15,   151] loss: 0.00751
# [15,   161] loss: 0.00202
# [15,   171] loss: 0.00784
# [15,   181] loss: 0.00412
# epoch 15 average training loss: 0.00522
# epoch 15 average val loss: 0.34984
# epoch 15 validation sens. : 0.98529, spec. : 0.91667; combined: 0.95098
#
#  Epochs without improvement =  3
#
#  Stopped training because 3 epochs without improvement. . .
# <ipython-input-6-4cddcf9c6f9d>:267: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('./best_base_STNet_fold_pd_'+str(k) +'.pt', map_location=device))
# Test set sens. : 0.60714, spec. : 0.45833, combined: 0.53274, auc: 0.47768
#
# Fold  3
# Patient items in training set:  178
# Control items in training set:  190
# Patient items in validation set:  46
# Control items in validation set:  46
#
# Test patient items:
#
# ['bar_2_1.pkl', 'bar_2_2.pkl', 'bar_2_3.pkl', 'bar_2_4.pkl', 'bar_37_1.pkl', 'bar_37_2.pkl', 'bar_37_3.pkl', 'bar_37_4.pkl', 'bar_54_1.pkl', 'bar_54_2.pkl', 'bar_54_3.pkl', 'bar_54_4.pkl', 'ctrl_21_1.pkl', 'ctrl_21_2.pkl', 'ctrl_21_3.pkl', 'ctrl_21_4.pkl', 'ctrl_71_1.pkl', 'ctrl_71_2.pkl', 'ctrl_71_3.pkl', 'ctrl_71_4.pkl', 'link_10_1.pkl', 'link_10_2.pkl', 'link_10_3.pkl', 'link_10_4.pkl']
# Training data:  Dataset DatasetFolder
#     Number of datapoints: 368
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented/train_cookie_theft
# Validation data:  Dataset DatasetFolder
#     Number of datapoints: 92
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented/val_cookie_theft
# Test data:  Dataset DatasetFolder
#     Number of datapoints: 52
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented/test_cookie_theft
# [1,     1] loss: 0.06575
# [1,    11] loss: 0.68573
# [1,    21] loss: 0.67609
# [1,    31] loss: 0.66587
# [1,    41] loss: 0.68107
# [1,    51] loss: 0.70447
# [1,    61] loss: 0.71322
# [1,    71] loss: 0.65989
# [1,    81] loss: 0.67552
# [1,    91] loss: 0.69025
# [1,   101] loss: 0.71315
# [1,   111] loss: 0.72536
# [1,   121] loss: 0.72523
# [1,   131] loss: 0.69713
# [1,   141] loss: 0.67245
# [1,   151] loss: 0.68286
# [1,   161] loss: 0.71014
# [1,   171] loss: 0.68131
# [1,   181] loss: 0.69780
# epoch 1 average training loss: 0.69202
# epoch 1 average val loss: 0.68074
# epoch 1 validation sens. : 0.84783, spec. : 0.43478; combined: 0.64130
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [2,     1] loss: 0.06708
# [2,    11] loss: 0.64989
# [2,    21] loss: 0.71371
# [2,    31] loss: 0.68539
# [2,    41] loss: 0.63932
# [2,    51] loss: 0.65609
# [2,    61] loss: 0.71149
# [2,    71] loss: 0.66403
# [2,    81] loss: 0.63516
# [2,    91] loss: 0.71787
# [2,   101] loss: 0.73488
# [2,   111] loss: 0.66642
# [2,   121] loss: 0.67995
# [2,   131] loss: 0.67338
# [2,   141] loss: 0.69210
# [2,   151] loss: 0.66963
# [2,   161] loss: 0.66117
# [2,   171] loss: 0.66899
# [2,   181] loss: 0.68076
# epoch 2 average training loss: 0.67804
# epoch 2 average val loss: 0.67146
# epoch 2 validation sens. : 0.74638, spec. : 0.82609; combined: 0.78623
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [3,     1] loss: 0.06914
# [3,    11] loss: 0.63407
# [3,    21] loss: 0.63221
# [3,    31] loss: 0.62440
# [3,    41] loss: 0.66208
# [3,    51] loss: 0.66920
# [3,    61] loss: 0.58224
# [3,    71] loss: 0.74622
# [3,    81] loss: 0.60813
# [3,    91] loss: 0.65286
# [3,   101] loss: 0.64621
# [3,   111] loss: 0.68122
# [3,   121] loss: 0.63249
# [3,   131] loss: 0.65581
# [3,   141] loss: 0.66053
# [3,   151] loss: 0.65463
# [3,   161] loss: 0.61044
# [3,   171] loss: 0.62204
# [3,   181] loss: 0.65298
# epoch 3 average training loss: 0.64628
# epoch 3 average val loss: 0.64111
# epoch 3 validation sens. : 0.92029, spec. : 0.52174; combined: 0.72101
#
#  Epochs without improvement =  1
# [4,     1] loss: 0.07170
# [4,    11] loss: 0.58234
# [4,    21] loss: 0.58498
# [4,    31] loss: 0.52750
# [4,    41] loss: 0.59741
# [4,    51] loss: 0.56458
# [4,    61] loss: 0.61391
# [4,    71] loss: 0.59605
# [4,    81] loss: 0.56874
# [4,    91] loss: 0.59520
# [4,   101] loss: 0.54659
# [4,   111] loss: 0.50069
# [4,   121] loss: 0.57832
# [4,   131] loss: 0.50620
# [4,   141] loss: 0.49058
# [4,   151] loss: 0.61831
# [4,   161] loss: 0.56352
# [4,   171] loss: 0.59453
# [4,   181] loss: 0.64422
# epoch 4 average training loss: 0.57308
# epoch 4 average val loss: 0.58138
# epoch 4 validation sens. : 0.92754, spec. : 0.52174; combined: 0.72464
#
#  Epochs without improvement =  2
# [5,     1] loss: 0.04991
# [5,    11] loss: 0.58833
# [5,    21] loss: 0.52711
# [5,    31] loss: 0.41949
# [5,    41] loss: 0.55240
# [5,    51] loss: 0.39248
# [5,    61] loss: 0.39935
# [5,    71] loss: 0.42707
# [5,    81] loss: 0.30637
# [5,    91] loss: 0.52581
# [5,   101] loss: 0.29937
# [5,   111] loss: 0.40615
# [5,   121] loss: 0.49375
# [5,   131] loss: 0.36483
# [5,   141] loss: 0.40406
# [5,   151] loss: 0.43681
# [5,   161] loss: 0.30692
# [5,   171] loss: 0.41738
# [5,   181] loss: 0.41868
# epoch 5 average training loss: 0.42579
# epoch 5 average val loss: 0.51363
# epoch 5 validation sens. : 0.96377, spec. : 0.60870; combined: 0.78623
#
#  Epochs without improvement =  3
#
#  Stopped training because 3 epochs without improvement. . .
# <ipython-input-6-4cddcf9c6f9d>:267: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('./best_base_STNet_fold_pd_'+str(k) +'.pt', map_location=device))
# Test set sens. : 0.67857, spec. : 0.33333, combined: 0.50595, auc: 0.45982
#
# Fold  4
# Patient items in training set:  170
# Control items in training set:  198
# Patient items in validation set:  50
# Control items in validation set:  42
#
# Test patient items:
#
# ['bar_38_1.pkl', 'bar_38_2.pkl', 'bar_38_3.pkl', 'bar_38_4.pkl', 'bar_60_1.pkl', 'bar_60_2.pkl', 'bar_60_3.pkl', 'bar_60_4.pkl', 'bar_79_1.pkl', 'bar_79_2.pkl', 'bar_79_3.pkl', 'bar_79_4.pkl', 'ctrl_25_1.pkl', 'ctrl_25_2.pkl', 'ctrl_25_3.pkl', 'ctrl_25_4.pkl', 'ctrl_61_1.pkl', 'ctrl_61_2.pkl', 'ctrl_61_3.pkl', 'ctrl_61_4.pkl', 'ctrl_81_1.pkl', 'ctrl_81_2.pkl', 'ctrl_81_3.pkl', 'ctrl_81_4.pkl', 'link_23_1.pkl', 'link_23_2.pkl', 'link_23_3.pkl', 'link_23_4.pkl']
# Training data:  Dataset DatasetFolder
#     Number of datapoints: 368
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented/train_cookie_theft
# Validation data:  Dataset DatasetFolder
#     Number of datapoints: 92
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented/val_cookie_theft
# Test data:  Dataset DatasetFolder
#     Number of datapoints: 52
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented/test_cookie_theft
# [1,     1] loss: 0.06871
# [1,    11] loss: 0.67563
# [1,    21] loss: 0.67082
# [1,    31] loss: 0.68147
# [1,    41] loss: 0.67158
# [1,    51] loss: 0.65559
# [1,    61] loss: 0.74376
# [1,    71] loss: 0.64802
# [1,    81] loss: 0.64939
# [1,    91] loss: 0.66805
# [1,   101] loss: 0.66863
# [1,   111] loss: 0.75300
# [1,   121] loss: 0.73492
# [1,   131] loss: 0.69324
# [1,   141] loss: 0.71232
# [1,   151] loss: 0.69641
# [1,   161] loss: 0.70500
# [1,   171] loss: 0.68344
# [1,   181] loss: 0.68826
# epoch 1 average training loss: 0.68929
# epoch 1 average val loss: 0.68211
# epoch 1 validation sens. : 0.91791, spec. : 0.26000; combined: 0.58896
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [2,     1] loss: 0.07100
# [2,    11] loss: 0.67105
# [2,    21] loss: 0.69404
# [2,    31] loss: 0.66636
# [2,    41] loss: 0.64615
# [2,    51] loss: 0.65061
# [2,    61] loss: 0.71105
# [2,    71] loss: 0.66266
# [2,    81] loss: 0.61425
# [2,    91] loss: 0.71968
# [2,   101] loss: 0.75097
# [2,   111] loss: 0.65817
# [2,   121] loss: 0.67666
# [2,   131] loss: 0.66559
# [2,   141] loss: 0.66615
# [2,   151] loss: 0.69884
# [2,   161] loss: 0.64964
# [2,   171] loss: 0.69745
# [2,   181] loss: 0.63819
# epoch 2 average training loss: 0.67398
# epoch 2 average val loss: 0.66015
# epoch 2 validation sens. : 0.98507, spec. : 0.30000; combined: 0.64254
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [3,     1] loss: 0.05577
# [3,    11] loss: 0.64161
# [3,    21] loss: 0.67623
# [3,    31] loss: 0.66556
# [3,    41] loss: 0.62971
# [3,    51] loss: 0.65471
# [3,    61] loss: 0.59151
# [3,    71] loss: 0.70785
# [3,    81] loss: 0.62969
# [3,    91] loss: 0.59042
# [3,   101] loss: 0.66863
# [3,   111] loss: 0.62488
# [3,   121] loss: 0.68077
# [3,   131] loss: 0.62915
# [3,   141] loss: 0.63470
# [3,   151] loss: 0.65226
# [3,   161] loss: 0.64744
# [3,   171] loss: 0.66256
# [3,   181] loss: 0.61805
# epoch 3 average training loss: 0.64188
# epoch 3 average val loss: 0.64195
# epoch 3 validation sens. : 0.97015, spec. : 0.40000; combined: 0.68507
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [4,     1] loss: 0.08775
# [4,    11] loss: 0.58799
# [4,    21] loss: 0.62088
# [4,    31] loss: 0.53189
# [4,    41] loss: 0.66215
# [4,    51] loss: 0.57909
# [4,    61] loss: 0.52389
# [4,    71] loss: 0.59999
# [4,    81] loss: 0.61959
# [4,    91] loss: 0.50935
# [4,   101] loss: 0.55366
# [4,   111] loss: 0.56395
# [4,   121] loss: 0.52775
# [4,   131] loss: 0.58532
# [4,   141] loss: 0.48633
# [4,   151] loss: 0.65278
# [4,   161] loss: 0.40690
# [4,   171] loss: 0.55348
# [4,   181] loss: 0.50807
# epoch 4 average training loss: 0.55984
# epoch 4 average val loss: 0.57541
# epoch 4 validation sens. : 0.94030, spec. : 0.50000; combined: 0.72015
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [5,     1] loss: 0.03429
# [5,    11] loss: 0.46359
# [5,    21] loss: 0.54336
# [5,    31] loss: 0.46116
# [5,    41] loss: 0.48920
# [5,    51] loss: 0.47125
# [5,    61] loss: 0.47973
# [5,    71] loss: 0.50353
# [5,    81] loss: 0.38622
# [5,    91] loss: 0.46814
# [5,   101] loss: 0.38083
# [5,   111] loss: 0.55576
# [5,   121] loss: 0.39474
# [5,   131] loss: 0.30522
# [5,   141] loss: 0.44216
# [5,   151] loss: 0.37211
# [5,   161] loss: 0.29066
# [5,   171] loss: 0.34227
# [5,   181] loss: 0.39190
# epoch 5 average training loss: 0.43106
# epoch 5 average val loss: 0.50208
# epoch 5 validation sens. : 0.96269, spec. : 0.62000; combined: 0.79134
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [6,     1] loss: 0.04403
# [6,    11] loss: 0.22550
# [6,    21] loss: 0.48819
# [6,    31] loss: 0.31041
# [6,    41] loss: 0.40847
# [6,    51] loss: 0.19194
# [6,    61] loss: 0.35106
# [6,    71] loss: 0.43387
# [6,    81] loss: 0.27992
# [6,    91] loss: 0.44654
# [6,   101] loss: 0.35364
# [6,   111] loss: 0.23375
# [6,   121] loss: 0.26406
# [6,   131] loss: 0.26218
# [6,   141] loss: 0.20481
# [6,   151] loss: 0.19051
# [6,   161] loss: 0.29153
# [6,   171] loss: 0.15077
# [6,   181] loss: 0.40341
# epoch 6 average training loss: 0.30223
# epoch 6 average val loss: 0.47880
# epoch 6 validation sens. : 1.00000, spec. : 0.56000; combined: 0.78000
#
#  Epochs without improvement =  1
# [7,     1] loss: 0.01508
# [7,    11] loss: 0.34498
# [7,    21] loss: 0.23864
# [7,    31] loss: 0.20019
# [7,    41] loss: 0.21019
# [7,    51] loss: 0.31587
# [7,    61] loss: 0.19335
# [7,    71] loss: 0.18184
# [7,    81] loss: 0.10163
# [7,    91] loss: 0.17527
# [7,   101] loss: 0.18683
# [7,   111] loss: 0.14122
# [7,   121] loss: 0.11011
# [7,   131] loss: 0.11610
# [7,   141] loss: 0.20322
# [7,   151] loss: 0.32238
# [7,   161] loss: 0.10977
# [7,   171] loss: 0.16631
# [7,   181] loss: 0.16108
# epoch 7 average training loss: 0.19211
# epoch 7 average val loss: 0.42385
# epoch 7 validation sens. : 0.98507, spec. : 0.70000; combined: 0.84254
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [8,     1] loss: 0.00658
# [8,    11] loss: 0.07696
# [8,    21] loss: 0.13479
# [8,    31] loss: 0.14622
# [8,    41] loss: 0.16150
# [8,    51] loss: 0.08911
# [8,    61] loss: 0.13248
# [8,    71] loss: 0.19496
# [8,    81] loss: 0.07126
# [8,    91] loss: 0.10309
# [8,   101] loss: 0.09746
# [8,   111] loss: 0.23235
# [8,   121] loss: 0.13005
# [8,   131] loss: 0.23957
# [8,   141] loss: 0.09209
# [8,   151] loss: 0.11720
# [8,   161] loss: 0.16637
# [8,   171] loss: 0.15741
# [8,   181] loss: 0.16705
# epoch 8 average training loss: 0.13774
# epoch 8 average val loss: 0.31268
# epoch 8 validation sens. : 0.95522, spec. : 0.90000; combined: 0.92761
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [9,     1] loss: 0.00218
# [9,    11] loss: 0.07453
# [9,    21] loss: 0.10916
# [9,    31] loss: 0.03180
# [9,    41] loss: 0.10829
# [9,    51] loss: 0.11003
# [9,    61] loss: 0.05715
# [9,    71] loss: 0.06427
# [9,    81] loss: 0.12886
# [9,    91] loss: 0.07585
# [9,   101] loss: 0.03338
# [9,   111] loss: 0.11394
# [9,   121] loss: 0.11579
# [9,   131] loss: 0.05435
# [9,   141] loss: 0.04290
# [9,   151] loss: 0.08713
# [9,   161] loss: 0.05304
# [9,   171] loss: 0.06007
# [9,   181] loss: 0.07529
# epoch 9 average training loss: 0.07736
# epoch 9 average val loss: 0.33741
# epoch 9 validation sens. : 0.98507, spec. : 0.86000; combined: 0.92254
#
#  Epochs without improvement =  1
# [10,     1] loss: 0.00371
# [10,    11] loss: 0.03862
# [10,    21] loss: 0.01895
# [10,    31] loss: 0.04097
# [10,    41] loss: 0.02915
# [10,    51] loss: 0.07049
# [10,    61] loss: 0.09159
# [10,    71] loss: 0.06114
# [10,    81] loss: 0.04740
# [10,    91] loss: 0.03614
# [10,   101] loss: 0.01773
# [10,   111] loss: 0.03223
# [10,   121] loss: 0.03727
# [10,   131] loss: 0.01367
# [10,   141] loss: 0.03690
# [10,   151] loss: 0.06983
# [10,   161] loss: 0.03628
# [10,   171] loss: 0.02076
# [10,   181] loss: 0.03896
# epoch 10 average training loss: 0.04096
# epoch 10 average val loss: 0.33142
# epoch 10 validation sens. : 0.98507, spec. : 0.82000; combined: 0.90254
#
#  Epochs without improvement =  2
# [11,     1] loss: 0.00024
# [11,    11] loss: 0.03004
# [11,    21] loss: 0.02401
# [11,    31] loss: 0.02921
# [11,    41] loss: 0.03171
# [11,    51] loss: 0.01377
# [11,    61] loss: 0.01741
# [11,    71] loss: 0.04413
# [11,    81] loss: 0.01461
# [11,    91] loss: 0.02191
# [11,   101] loss: 0.03814
# [11,   111] loss: 0.02602
# [11,   121] loss: 0.01951
# [11,   131] loss: 0.01963
# [11,   141] loss: 0.02393
# [11,   151] loss: 0.03304
# [11,   161] loss: 0.01397
# [11,   171] loss: 0.01448
# [11,   181] loss: 0.01530
# epoch 11 average training loss: 0.02394
# epoch 11 average val loss: 0.29366
# epoch 11 validation sens. : 0.99254, spec. : 0.86000; combined: 0.92627
#
#  Epochs without improvement =  3
#
#  Stopped training because 3 epochs without improvement. . .
# <ipython-input-6-4cddcf9c6f9d>:267: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('./best_base_STNet_fold_pd_'+str(k) +'.pt', map_location=device))
# Test set sens. : 0.95833, spec. : 0.21429, combined: 0.58631, auc: 0.36905
#
# Fold  5
# Patient items in training set:  171
# Control items in training set:  197
# Patient items in validation set:  53
# Control items in validation set:  39
#
# Test patient items:
#
# ['bar_39_1.pkl', 'bar_39_2.pkl', 'bar_39_3.pkl', 'bar_39_4.pkl', 'bar_63_1.pkl', 'bar_63_2.pkl', 'bar_63_3.pkl', 'bar_63_4.pkl', 'ctrl_46_1.pkl', 'ctrl_46_2.pkl', 'ctrl_46_3.pkl', 'ctrl_46_4.pkl', 'ctrl_62_1.pkl', 'ctrl_62_2.pkl', 'ctrl_62_3.pkl', 'ctrl_62_4.pkl', 'link_12_1.pkl', 'link_12_2.pkl', 'link_12_3.pkl', 'link_12_4.pkl', 'link_6_1.pkl', 'link_6_2.pkl', 'link_6_3.pkl', 'link_6_4.pkl']
# Training data:  Dataset DatasetFolder
#     Number of datapoints: 368
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented/train_cookie_theft
# Validation data:  Dataset DatasetFolder
#     Number of datapoints: 92
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented/val_cookie_theft
# Test data:  Dataset DatasetFolder
#     Number of datapoints: 52
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented/test_cookie_theft
# [1,     1] loss: 0.06793
# [1,    11] loss: 0.69565
# [1,    21] loss: 0.66977
# [1,    31] loss: 0.69160
# [1,    41] loss: 0.70325
# [1,    51] loss: 0.66284
# [1,    61] loss: 0.73691
# [1,    71] loss: 0.65073
# [1,    81] loss: 0.66088
# [1,    91] loss: 0.66454
# [1,   101] loss: 0.67565
# [1,   111] loss: 0.74713
# [1,   121] loss: 0.72574
# [1,   131] loss: 0.68421
# [1,   141] loss: 0.68653
# [1,   151] loss: 0.68563
# [1,   161] loss: 0.71129
# [1,   171] loss: 0.67714
# [1,   181] loss: 0.69674
# epoch 1 average training loss: 0.69174
# epoch 1 average val loss: 0.72029
# epoch 1 validation sens. : 0.13740, spec. : 0.64151; combined: 0.38946
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [2,     1] loss: 0.05536
# [2,    11] loss: 0.64019
# [2,    21] loss: 0.73488
# [2,    31] loss: 0.65049
# [2,    41] loss: 0.65311
# [2,    51] loss: 0.62465
# [2,    61] loss: 0.70329
# [2,    71] loss: 0.66848
# [2,    81] loss: 0.63493
# [2,    91] loss: 0.72147
# [2,   101] loss: 0.78585
# [2,   111] loss: 0.67702
# [2,   121] loss: 0.68010
# [2,   131] loss: 0.70069
# [2,   141] loss: 0.68030
# [2,   151] loss: 0.69686
# [2,   161] loss: 0.64741
# [2,   171] loss: 0.67000
# [2,   181] loss: 0.70471
# epoch 2 average training loss: 0.68080
# epoch 2 average val loss: 0.68061
# epoch 2 validation sens. : 0.82443, spec. : 0.77358; combined: 0.79901
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [3,     1] loss: 0.06400
# [3,    11] loss: 0.66517
# [3,    21] loss: 0.65461
# [3,    31] loss: 0.68757
# [3,    41] loss: 0.68620
# [3,    51] loss: 0.68349
# [3,    61] loss: 0.62472
# [3,    71] loss: 0.73551
# [3,    81] loss: 0.64138
# [3,    91] loss: 0.65953
# [3,   101] loss: 0.65303
# [3,   111] loss: 0.61422
# [3,   121] loss: 0.71127
# [3,   131] loss: 0.64353
# [3,   141] loss: 0.64694
# [3,   151] loss: 0.65279
# [3,   161] loss: 0.67126
# [3,   171] loss: 0.69238
# [3,   181] loss: 0.62557
# epoch 3 average training loss: 0.66482
# epoch 3 average val loss: 0.70573
# epoch 3 validation sens. : 0.21374, spec. : 0.62264; combined: 0.41819
#
#  Epochs without improvement =  1
# [4,     1] loss: 0.08146
# [4,    11] loss: 0.63537
# [4,    21] loss: 0.61930
# [4,    31] loss: 0.60518
# [4,    41] loss: 0.64256
# [4,    51] loss: 0.62670
# [4,    61] loss: 0.60598
# [4,    71] loss: 0.63107
# [4,    81] loss: 0.68365
# [4,    91] loss: 0.60620
# [4,   101] loss: 0.70075
# [4,   111] loss: 0.62422
# [4,   121] loss: 0.62935
# [4,   131] loss: 0.62995
# [4,   141] loss: 0.53818
# [4,   151] loss: 0.71185
# [4,   161] loss: 0.54115
# [4,   171] loss: 0.64909
# [4,   181] loss: 0.61301
# epoch 4 average training loss: 0.62914
# epoch 4 average val loss: 0.61850
# epoch 4 validation sens. : 0.89313, spec. : 0.75472; combined: 0.82392
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [5,     1] loss: 0.04388
# [5,    11] loss: 0.54961
# [5,    21] loss: 0.70507
# [5,    31] loss: 0.49770
# [5,    41] loss: 0.67458
# [5,    51] loss: 0.52752
# [5,    61] loss: 0.55503
# [5,    71] loss: 0.53754
# [5,    81] loss: 0.54304
# [5,    91] loss: 0.56796
# [5,   101] loss: 0.44503
# [5,   111] loss: 0.71724
# [5,   121] loss: 0.52814
# [5,   131] loss: 0.47716
# [5,   141] loss: 0.51216
# [5,   151] loss: 0.54884
# [5,   161] loss: 0.45821
# [5,   171] loss: 0.46736
# [5,   181] loss: 0.53354
# epoch 5 average training loss: 0.54443
# epoch 5 average val loss: 0.60526
# epoch 5 validation sens. : 0.94656, spec. : 0.60377; combined: 0.77517
#
#  Epochs without improvement =  1
# [6,     1] loss: 0.04396
# [6,    11] loss: 0.41430
# [6,    21] loss: 0.57161
# [6,    31] loss: 0.37948
# [6,    41] loss: 0.50438
# [6,    51] loss: 0.38294
# [6,    61] loss: 0.40842
# [6,    71] loss: 0.49304
# [6,    81] loss: 0.41910
# [6,    91] loss: 0.46445
# [6,   101] loss: 0.53926
# [6,   111] loss: 0.36801
# [6,   121] loss: 0.44512
# [6,   131] loss: 0.36026
# [6,   141] loss: 0.41827
# [6,   151] loss: 0.35977
# [6,   161] loss: 0.35533
# [6,   171] loss: 0.24599
# [6,   181] loss: 0.39188
# epoch 6 average training loss: 0.42229
# epoch 6 average val loss: 0.55839
# epoch 6 validation sens. : 0.93893, spec. : 0.71698; combined: 0.82796
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [7,     1] loss: 0.01579
# [7,    11] loss: 0.34952
# [7,    21] loss: 0.34879
# [7,    31] loss: 0.32613
# [7,    41] loss: 0.39115
# [7,    51] loss: 0.37267
# [7,    61] loss: 0.23654
# [7,    71] loss: 0.29112
# [7,    81] loss: 0.34643
# [7,    91] loss: 0.24654
# [7,   101] loss: 0.24673
# [7,   111] loss: 0.18287
# [7,   121] loss: 0.26498
# [7,   131] loss: 0.34682
# [7,   141] loss: 0.44062
# [7,   151] loss: 0.25757
# [7,   161] loss: 0.44141
# [7,   171] loss: 0.30701
# [7,   181] loss: 0.34489
# epoch 7 average training loss: 0.31584
# epoch 7 average val loss: 0.45693
# epoch 7 validation sens. : 0.97710, spec. : 0.77358; combined: 0.87534
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [8,     1] loss: 0.01543
# [8,    11] loss: 0.22002
# [8,    21] loss: 0.26315
# [8,    31] loss: 0.23484
# [8,    41] loss: 0.26328
# [8,    51] loss: 0.29272
# [8,    61] loss: 0.22938
# [8,    71] loss: 0.13370
# [8,    81] loss: 0.20372
# [8,    91] loss: 0.19796
# [8,   101] loss: 0.19492
# [8,   111] loss: 0.27393
# [8,   121] loss: 0.18608
# [8,   131] loss: 0.20024
# [8,   141] loss: 0.17619
# [8,   151] loss: 0.18754
# [8,   161] loss: 0.13123
# [8,   171] loss: 0.20728
# [8,   181] loss: 0.28927
# epoch 8 average training loss: 0.21474
# epoch 8 average val loss: 0.37140
# epoch 8 validation sens. : 0.90076, spec. : 0.92453; combined: 0.91265
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [9,     1] loss: 0.00372
# [9,    11] loss: 0.17718
# [9,    21] loss: 0.12548
# [9,    31] loss: 0.13512
# [9,    41] loss: 0.14841
# [9,    51] loss: 0.25423
# [9,    61] loss: 0.11975
# [9,    71] loss: 0.09847
# [9,    81] loss: 0.19560
# [9,    91] loss: 0.14086
# [9,   101] loss: 0.13350
# [9,   111] loss: 0.12965
# [9,   121] loss: 0.15637
# [9,   131] loss: 0.15314
# [9,   141] loss: 0.17276
# [9,   151] loss: 0.15165
# [9,   161] loss: 0.07865
# [9,   171] loss: 0.06247
# [9,   181] loss: 0.13064
# epoch 9 average training loss: 0.14157
# epoch 9 average val loss: 0.41309
# epoch 9 validation sens. : 0.96947, spec. : 0.84906; combined: 0.90926
#
#  Epochs without improvement =  1
# [10,     1] loss: 0.00113
# [10,    11] loss: 0.13087
# [10,    21] loss: 0.07676
# [10,    31] loss: 0.10795
# [10,    41] loss: 0.10216
# [10,    51] loss: 0.11934
# [10,    61] loss: 0.19219
# [10,    71] loss: 0.18224
# [10,    81] loss: 0.08785
# [10,    91] loss: 0.10853
# [10,   101] loss: 0.12051
# [10,   111] loss: 0.05485
# [10,   121] loss: 0.09736
# [10,   131] loss: 0.06396
# [10,   141] loss: 0.11246
# [10,   151] loss: 0.05145
# [10,   161] loss: 0.03457
# [10,   171] loss: 0.07396
# [10,   181] loss: 0.10286
# epoch 10 average training loss: 0.09963
# epoch 10 average val loss: 0.44027
# epoch 10 validation sens. : 0.96947, spec. : 0.84906; combined: 0.90926
#
#  Epochs without improvement =  2
# [11,     1] loss: 0.00093
# [11,    11] loss: 0.08825
# [11,    21] loss: 0.04832
# [11,    31] loss: 0.04822
# [11,    41] loss: 0.06108
# [11,    51] loss: 0.03746
# [11,    61] loss: 0.04475
# [11,    71] loss: 0.05569
# [11,    81] loss: 0.03371
# [11,    91] loss: 0.03365
# [11,   101] loss: 0.10461
# [11,   111] loss: 0.03841
# [11,   121] loss: 0.05126
# [11,   131] loss: 0.05006
# [11,   141] loss: 0.05940
# [11,   151] loss: 0.05573
# [11,   161] loss: 0.03304
# [11,   171] loss: 0.03542
# [11,   181] loss: 0.03000
# epoch 11 average training loss: 0.05165
# epoch 11 average val loss: 0.33347
# epoch 11 validation sens. : 0.93893, spec. : 0.94340; combined: 0.94116
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [12,     1] loss: 0.00176
# [12,    11] loss: 0.04589
# [12,    21] loss: 0.03836
# [12,    31] loss: 0.03503
# [12,    41] loss: 0.02794
# [12,    51] loss: 0.02461
# [12,    61] loss: 0.05692
# [12,    71] loss: 0.02737
# [12,    81] loss: 0.05700
# [12,    91] loss: 0.03995
# [12,   101] loss: 0.03714
# [12,   111] loss: 0.07827
# [12,   121] loss: 0.10936
# [12,   131] loss: 0.02913
# [12,   141] loss: 0.02498
# [12,   151] loss: 0.02982
# [12,   161] loss: 0.06278
# [12,   171] loss: 0.03292
# [12,   181] loss: 0.03719
# epoch 12 average training loss: 0.04374
# epoch 12 average val loss: 0.30621
# epoch 12 validation sens. : 0.96183, spec. : 0.92453; combined: 0.94318
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [13,     1] loss: 0.00761
# [13,    11] loss: 0.02428
# [13,    21] loss: 0.01164
# [13,    31] loss: 0.02485
# [13,    41] loss: 0.02900
# [13,    51] loss: 0.01209
# [13,    61] loss: 0.01745
# [13,    71] loss: 0.02301
# [13,    81] loss: 0.02783
# [13,    91] loss: 0.01757
# [13,   101] loss: 0.02345
# [13,   111] loss: 0.00990
# [13,   121] loss: 0.03146
# [13,   131] loss: 0.03210
# ...
# [7,   131] loss: 0.12566
# [7,   141] loss: 0.07128
# [7,   151] loss: 0.10609
# [7,   161] loss: 0.32333
# [7,   171] loss: 0.14707
# [7,   181] loss: 0.21338
# epoch 7 average training loss: 0.17821
# epoch 7 average val loss: 0.34184
# epoch 7 validation sens. : 0.96403, spec. : 0.86667; combined: 0.91535
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [8,     1] loss: 0.00511
# [8,    11] loss: 0.06298
# [8,    21] loss: 0.10642
# [8,    31] loss: 0.06460
# [8,    41] loss: 0.10722
# [8,    51] loss: 0.13710
# [8,    61] loss: 0.08505
# [8,    71] loss: 0.09575
# [8,    81] loss: 0.10921
# [8,    91] loss: 0.04364
# [8,   101] loss: 0.03311
# [8,   111] loss: 0.10130
# [8,   121] loss: 0.05876
# [8,   131] loss: 0.12839
# [8,   141] loss: 0.07849
# [8,   151] loss: 0.27628
# [8,   161] loss: 0.21196
# [8,   171] loss: 0.07620
# [8,   181] loss: 0.10041
# epoch 8 average training loss: 0.10482
# epoch 8 average val loss: 0.40937
# epoch 8 validation sens. : 0.99286, spec. : 0.70455; combined: 0.84870
#
#  Epochs without improvement =  1
# [9,     1] loss: 0.02822
# [9,    11] loss: 0.09399
# [9,    21] loss: 0.11768
# [9,    31] loss: 0.03694
# [9,    41] loss: 0.06198
# [9,    51] loss: 0.11059
# [9,    61] loss: 0.06202
# [9,    71] loss: 0.04809
# [9,    81] loss: 0.07515
# [9,    91] loss: 0.03106
# [9,   101] loss: 0.04075
# [9,   111] loss: 0.03177
# [9,   121] loss: 0.02731
# [9,   131] loss: 0.12560
# [9,   141] loss: 0.09853
# [9,   151] loss: 0.22306
# [9,   161] loss: 0.07643
# [9,   171] loss: 0.07663
# [9,   181] loss: 0.02521
# epoch 9 average training loss: 0.07684
# epoch 9 average val loss: 0.29798
# epoch 9 validation sens. : 0.96403, spec. : 0.88889; combined: 0.92646
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [10,     1] loss: 0.00862
# [10,    11] loss: 0.04697
# [10,    21] loss: 0.02388
# [10,    31] loss: 0.02919
# [10,    41] loss: 0.09044
# [10,    51] loss: 0.05017
# [10,    61] loss: 0.04981
# [10,    71] loss: 0.06558
# [10,    81] loss: 0.06605
# [10,    91] loss: 0.01992
# [10,   101] loss: 0.02639
# [10,   111] loss: 0.03593
# [10,   121] loss: 0.02634
# [10,   131] loss: 0.04324
# [10,   141] loss: 0.02084
# [10,   151] loss: 0.03032
# [10,   161] loss: 0.03564
# [10,   171] loss: 0.02443
# [10,   181] loss: 0.02254
# epoch 10 average training loss: 0.03928
# epoch 10 average val loss: 0.29064
# epoch 10 validation sens. : 0.98561, spec. : 0.88889; combined: 0.93725
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [11,     1] loss: 0.00443
# [11,    11] loss: 0.01607
# [11,    21] loss: 0.01908
# [11,    31] loss: 0.01496
# [11,    41] loss: 0.01287
# [11,    51] loss: 0.02272
# [11,    61] loss: 0.01978
# [11,    71] loss: 0.01770
# [11,    81] loss: 0.01925
# [11,    91] loss: 0.01861
# [11,   101] loss: 0.01918
# [11,   111] loss: 0.02456
# [11,   121] loss: 0.02042
# [11,   131] loss: 0.01413
# [11,   141] loss: 0.01477
# [11,   151] loss: 0.04083
# [11,   161] loss: 0.01144
# [11,   171] loss: 0.01595
# [11,   181] loss: 0.04286
# epoch 11 average training loss: 0.02012
# epoch 11 average val loss: 0.26855
# epoch 11 validation sens. : 0.95683, spec. : 0.91111; combined: 0.93397
#
#  Epochs without improvement =  1
# [12,     1] loss: 0.00105
# [12,    11] loss: 0.02149
# [12,    21] loss: 0.00620
# [12,    31] loss: 0.01751
# [12,    41] loss: 0.00810
# [12,    51] loss: 0.01193
# [12,    61] loss: 0.01632
# [12,    71] loss: 0.01111
# [12,    81] loss: 0.00727
# [12,    91] loss: 0.01505
# [12,   101] loss: 0.00971
# [12,   111] loss: 0.02636
# [12,   121] loss: 0.00842
# [12,   131] loss: 0.01159
# [12,   141] loss: 0.00552
# [12,   151] loss: 0.00683
# [12,   161] loss: 0.00745
# [12,   171] loss: 0.00716
# [12,   181] loss: 0.02952
# epoch 12 average training loss: 0.01269
# epoch 12 average val loss: 0.26524
# epoch 12 validation sens. : 0.95683, spec. : 0.91111; combined: 0.93397
#
#  Epochs without improvement =  2
# [13,     1] loss: 0.00038
# [13,    11] loss: 0.00525
# [13,    21] loss: 0.01315
# [13,    31] loss: 0.00868
# [13,    41] loss: 0.00826
# [13,    51] loss: 0.00505
# [13,    61] loss: 0.00979
# [13,    71] loss: 0.00331
# [13,    81] loss: 0.00927
# [13,    91] loss: 0.00778
# [13,   101] loss: 0.00596
# [13,   111] loss: 0.00996
# [13,   121] loss: 0.00414
# [13,   131] loss: 0.01077
# [13,   141] loss: 0.01198
# [13,   151] loss: 0.01464
# [13,   161] loss: 0.00694
# [13,   171] loss: 0.00384
# [13,   181] loss: 0.00213
# epoch 13 average training loss: 0.00768
# epoch 13 average val loss: 0.27776
# epoch 13 validation sens. : 0.97143, spec. : 0.88636; combined: 0.92890
#
#  Epochs without improvement =  3
#
#  Stopped training because 3 epochs without improvement. . .
# <ipython-input-6-4cddcf9c6f9d>:267: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('./best_base_STNet_fold_pd_'+str(k) +'.pt', map_location=device))
# Test set sens. : 0.25000, spec. : 0.81250, combined: 0.53125, auc: 0.32617
#
# Fold  10
# Patient items in training set:  183
# Control items in training set:  188
# Patient items in validation set:  41
# Control items in validation set:  52
#
# Test patient items:
#
# ['bar_44_1.pkl', 'bar_44_2.pkl', 'bar_44_3.pkl', 'bar_44_4.pkl', 'ctrl_40_1.pkl', 'ctrl_40_2.pkl', 'ctrl_40_3.pkl', 'ctrl_40_4.pkl', 'ctrl_55_1.pkl', 'ctrl_55_2.pkl', 'ctrl_55_3.pkl', 'ctrl_55_4.pkl', 'ctrl_67_1.pkl', 'ctrl_67_2.pkl', 'ctrl_67_3.pkl', 'ctrl_67_4.pkl', 'ctrl_77_1.pkl', 'ctrl_77_2.pkl', 'ctrl_77_3.pkl', 'ctrl_77_4.pkl', 'link_33_1.pkl', 'link_33_2.pkl', 'link_33_3.pkl', 'link_33_4.pkl']
# Training data:  Dataset DatasetFolder
#     Number of datapoints: 371
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented/train_cookie_theft
# Validation data:  Dataset DatasetFolder
#     Number of datapoints: 93
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented/val_cookie_theft
# Test data:  Dataset DatasetFolder
#     Number of datapoints: 48
#     Root location: /content/drive/My Drive/msnv_data/VTNet_att/dataset/augmented/test_cookie_theft
# [1,     1] loss: 0.07049
# [1,    11] loss: 0.67775
# [1,    21] loss: 0.63438
# [1,    31] loss: 0.79895
# [1,    41] loss: 0.65160
# [1,    51] loss: 0.67225
# [1,    61] loss: 0.70741
# [1,    71] loss: 0.69278
# [1,    81] loss: 0.69834
# [1,    91] loss: 0.69815
# [1,   101] loss: 0.70972
# [1,   111] loss: 0.69225
# [1,   121] loss: 0.67573
# [1,   131] loss: 0.68734
# [1,   141] loss: 0.68360
# [1,   151] loss: 0.68720
# [1,   161] loss: 0.69924
# [1,   171] loss: 0.69391
# [1,   181] loss: 0.68218
# epoch 1 average training loss: 0.69186
# epoch 1 average val loss: 0.68305
# epoch 1 validation sens. : 0.19580, spec. : 0.63415; combined: 0.41498
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [2,     1] loss: 0.07192
# [2,    11] loss: 0.70297
# [2,    21] loss: 0.67085
# [2,    31] loss: 0.68349
# [2,    41] loss: 0.67860
# [2,    51] loss: 0.67874
# [2,    61] loss: 0.64817
# [2,    71] loss: 0.66233
# [2,    81] loss: 0.66743
# [2,    91] loss: 0.69891
# [2,   101] loss: 0.66228
# [2,   111] loss: 0.68803
# [2,   121] loss: 0.64636
# [2,   131] loss: 0.64776
# [2,   141] loss: 0.75269
# [2,   151] loss: 0.69048
# [2,   161] loss: 0.67812
# [2,   171] loss: 0.63873
# [2,   181] loss: 0.66511
# epoch 2 average training loss: 0.67575
# epoch 2 average val loss: 0.68372
# epoch 2 validation sens. : 0.10490, spec. : 0.82927; combined: 0.46708
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [3,     1] loss: 0.06057
# [3,    11] loss: 0.64805
# [3,    21] loss: 0.62978
# [3,    31] loss: 0.62142
# [3,    41] loss: 0.70572
# [3,    51] loss: 0.64646
# [3,    61] loss: 0.58080
# [3,    71] loss: 0.63498
# [3,    81] loss: 0.71669
# [3,    91] loss: 0.63569
# [3,   101] loss: 0.64877
# [3,   111] loss: 0.63695
# [3,   121] loss: 0.64669
# [3,   131] loss: 0.65445
# [3,   141] loss: 0.54741
# [3,   151] loss: 0.69388
# [3,   161] loss: 0.62021
# [3,   171] loss: 0.61844
# [3,   181] loss: 0.59247
# epoch 3 average training loss: 0.63800
# epoch 3 average val loss: 0.65305
# epoch 3 validation sens. : 0.97917, spec. : 0.22500; combined: 0.60208
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [4,     1] loss: 0.05943
# [4,    11] loss: 0.60030
# [4,    21] loss: 0.57841
# [4,    31] loss: 0.57224
# [4,    41] loss: 0.54114
# [4,    51] loss: 0.59460
# [4,    61] loss: 0.53519
# [4,    71] loss: 0.57279
# [4,    81] loss: 0.53206
# [4,    91] loss: 0.49735
# [4,   101] loss: 0.55921
# [4,   111] loss: 0.48968
# [4,   121] loss: 0.55516
# [4,   131] loss: 0.60705
# [4,   141] loss: 0.61039
# [4,   151] loss: 0.50734
# [4,   161] loss: 0.56837
# [4,   171] loss: 0.51865
# [4,   181] loss: 0.51765
# epoch 4 average training loss: 0.54957
# epoch 4 average val loss: 0.60718
# epoch 4 validation sens. : 0.92361, spec. : 0.45000; combined: 0.68681
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [5,     1] loss: 0.06810
# [5,    11] loss: 0.39741
# [5,    21] loss: 0.43829
# [5,    31] loss: 0.39341
# [5,    41] loss: 0.48995
# [5,    51] loss: 0.40047
# [5,    61] loss: 0.52584
# [5,    71] loss: 0.32113
# [5,    81] loss: 0.41323
# [5,    91] loss: 0.45404
# [5,   101] loss: 0.34630
# [5,   111] loss: 0.39305
# [5,   121] loss: 0.46978
# [5,   131] loss: 0.25692
# [5,   141] loss: 0.32213
# [5,   151] loss: 0.37672
# [5,   161] loss: 0.47154
# [5,   171] loss: 0.31595
# [5,   181] loss: 0.44683
# epoch 5 average training loss: 0.40356
# epoch 5 average val loss: 0.51668
# epoch 5 validation sens. : 0.95804, spec. : 0.65854; combined: 0.80829
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [6,     1] loss: 0.03534
# [6,    11] loss: 0.24592
# [6,    21] loss: 0.23020
# [6,    31] loss: 0.42451
# [6,    41] loss: 0.21764
# [6,    51] loss: 0.36194
# [6,    61] loss: 0.47948
# [6,    71] loss: 0.36370
# [6,    81] loss: 0.32966
# [6,    91] loss: 0.21255
# [6,   101] loss: 0.23804
# [6,   111] loss: 0.26255
# [6,   121] loss: 0.17964
# [6,   131] loss: 0.29386
# [6,   141] loss: 0.18271
# [6,   151] loss: 0.22346
# [6,   161] loss: 0.21898
# [6,   171] loss: 0.25177
# [6,   181] loss: 0.29679
# epoch 6 average training loss: 0.27710
# epoch 6 average val loss: 0.52416
# epoch 6 validation sens. : 0.93056, spec. : 0.80000; combined: 0.86528
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [7,     1] loss: 0.01241
# [7,    11] loss: 0.18881
# [7,    21] loss: 0.12330
# [7,    31] loss: 0.11779
# [7,    41] loss: 0.15082
# [7,    51] loss: 0.14581
# [7,    61] loss: 0.10722
# [7,    71] loss: 0.21251
# [7,    81] loss: 0.26599
# [7,    91] loss: 0.20834
# [7,   101] loss: 0.12688
# [7,   111] loss: 0.40014
# [7,   121] loss: 0.10908
# [7,   131] loss: 0.13233
# [7,   141] loss: 0.14748
# [7,   151] loss: 0.17466
# [7,   161] loss: 0.13778
# [7,   171] loss: 0.14493
# [7,   181] loss: 0.15632
# epoch 7 average training loss: 0.17005
# epoch 7 average val loss: 0.44009
# epoch 7 validation sens. : 0.98601, spec. : 0.78049; combined: 0.88325
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [8,     1] loss: 0.00510
# [8,    11] loss: 0.11936
# [8,    21] loss: 0.18762
# [8,    31] loss: 0.09315
# [8,    41] loss: 0.13205
# [8,    51] loss: 0.10142
# [8,    61] loss: 0.08070
# [8,    71] loss: 0.07542
# [8,    81] loss: 0.05914
# [8,    91] loss: 0.07266
# [8,   101] loss: 0.06462
# [8,   111] loss: 0.09963
# [8,   121] loss: 0.04229
# [8,   131] loss: 0.07614
# [8,   141] loss: 0.04947
# [8,   151] loss: 0.08869
# [8,   161] loss: 0.05024
# [8,   171] loss: 0.13871
# [8,   181] loss: 0.34124
# epoch 8 average training loss: 0.10211
# epoch 8 average val loss: 0.43959
# epoch 8 validation sens. : 0.95833, spec. : 0.85000; combined: 0.90417
# New best validation combined accuracy found. Saving model...
#
#  Epochs without improvement =  0
# [9,     1] loss: 0.00161
# [9,    11] loss: 0.06450
# [9,    21] loss: 0.05765
# [9,    31] loss: 0.06412
# [9,    41] loss: 0.07144
# [9,    51] loss: 0.04602
# [9,    61] loss: 0.03793
# [9,    71] loss: 0.04293
# [9,    81] loss: 0.09716
# [9,    91] loss: 0.04374
# [9,   101] loss: 0.22087
# [9,   111] loss: 0.05764
# [9,   121] loss: 0.11063
# [9,   131] loss: 0.03514
# [9,   141] loss: 0.03583
# [9,   151] loss: 0.04009
# [9,   161] loss: 0.05216
# [9,   171] loss: 0.06612
# [9,   181] loss: 0.05873
# epoch 9 average training loss: 0.06612
# epoch 9 average val loss: 0.44530
# epoch 9 validation sens. : 1.00000, spec. : 0.73171; combined: 0.86585
#
#  Epochs without improvement =  1
# [10,     1] loss: 0.02728
# [10,    11] loss: 0.05250
# [10,    21] loss: 0.04911
# [10,    31] loss: 0.09901
# [10,    41] loss: 0.01880
# [10,    51] loss: 0.04414
# [10,    61] loss: 0.03298
# [10,    71] loss: 0.03521
# [10,    81] loss: 0.02538
# [10,    91] loss: 0.01801
# [10,   101] loss: 0.03055
# [10,   111] loss: 0.04546
# [10,   121] loss: 0.05105
# [10,   131] loss: 0.01892
# [10,   141] loss: 0.02495
# [10,   151] loss: 0.03649
# [10,   161] loss: 0.01410
# [10,   171] loss: 0.01550
# [10,   181] loss: 0.01701
# epoch 10 average training loss: 0.03627
# epoch 10 average val loss: 0.41088
# epoch 10 validation sens. : 0.95804, spec. : 0.82927; combined: 0.89366
#
#  Epochs without improvement =  2
# [11,     1] loss: 0.00115
# [11,    11] loss: 0.03031
# [11,    21] loss: 0.02765
# [11,    31] loss: 0.03016
# [11,    41] loss: 0.01505
# [11,    51] loss: 0.02035
# [11,    61] loss: 0.01926
# [11,    71] loss: 0.00857
# [11,    81] loss: 0.00639
# [11,    91] loss: 0.02036
# [11,   101] loss: 0.02257
# [11,   111] loss: 0.02374
# [11,   121] loss: 0.03723
# [11,   131] loss: 0.01002
# [11,   141] loss: 0.01301
# [11,   151] loss: 0.01570
# [11,   161] loss: 0.02191
# [11,   171] loss: 0.00496
# [11,   181] loss: 0.00568
# epoch 11 average training loss: 0.01853
# epoch 11 average val loss: 0.44160
# epoch 11 validation sens. : 0.95804, spec. : 0.82927; combined: 0.89366
#
#  Epochs without improvement =  3
#
#  Stopped training because 3 epochs without improvement. . .
# <ipython-input-6-4cddcf9c6f9d>:267: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('./best_base_STNet_fold_pd_'+str(k) +'.pt', map_location=device))
# Test set sens. : 0.50000, spec. : 0.33333, combined: 0.41667, auc: 0.31250
#
#  Average 10-fold CV test sensitivity: 0.60164, specificity: 0.49220, combined: 0.54692, AUC: 0.46477
# sensitivities:  [0.6016369047619048]
# specificities:  [0.4922023809523809]
# combined:  [0.5469196428571429]
# auc:  [0.4647650049603175]
# average sensitivity:  0.6016369047619048
# average specificity:  0.4922023809523809
# average combined:  0.5469196428571429
# average auc:  0.4647650049603175
