# %%
import os
import pandas as pd
import pickle
import re

def extract_user_id(filename):
    """
    Extracts digits from a filename regardless of extension.
    Example: "msnv1.seg" or "msnv1.tsv" -> 1
    """
    match = re.search(r'(\d+)\.', filename)
    if match:
        return int(match.group(1))
    else:
        return None

def cyclic_split_df(df, n=4):
    """
    Splits a DataFrame into n groups in a cyclic (round-robin) manner.
    For example, with n=4:
      - Group 0 gets rows 0, 4, 8, ...
      - Group 1 gets rows 1, 5, 9, ...
      - etc.
    """
    return [df.iloc[i::n].reset_index(drop=True) for i in range(n)]

def crop_merge_and_cyclic_split_from_seg(seg_directory, raw_directory, output_directory, mode='full'):
    """
    Processes segmentation files (.seg) and corresponding raw TSV data to:
      1. For each user:
          - Read all tasks from the seg file.
          - For each task, crop the raw data based on rec_start and rec_end.
          - If mode is '29s', restrict each task to the first 29 seconds 
            (i.e. first 3480 rows at 120Hz). If the task is too short, keep what is available.
          - Filter out invalid rows (rows with NaN or -1 in valid columns) and keep only selected columns.
          - Tag each task with its mmd_id.
      2. Merge all tasks (sorted by task_id) for that user into a single DataFrame.
      3. Compute per-user statistics (e.g., total length, mean segment length, minimum and maximum task lengths in '29s' mode).
      4. Cyclically split the merged DataFrame into 4 groups.
      5. Save each cyclic split as a pickle file.
      6. Save group-level statistics across all users.
    
    Parameters:
      seg_directory (str): Directory containing segmentation (.seg) files.
      raw_directory (str): Directory containing raw TSV files for each user.
      output_directory (str): Directory where output pickle files and stats will be saved.
      mode (str): Either 'full' (use entire task duration) or '29s' (limit each task to the first 29 seconds at 120Hz).
    """
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)
    
    # Define the valid columns.
    valid_columns = [
        'GazePointLeftX (ADCSpx)', 'GazePointLeftY (ADCSpx)',
        'GazePointRightX (ADCSpx)', 'GazePointRightY (ADCSpx)',
        'GazePointX (ADCSpx)', 'GazePointY (ADCSpx)', 
        'GazePointX (MCSpx)', 'GazePointY (MCSpx)',
        'GazePointLeftX (ADCSmm)', 'GazePointLeftY (ADCSmm)', 
        'GazePointRightX (ADCSmm)', 'GazePointRightY (ADCSmm)',
        'DistanceLeft', 'DistanceRight',
        'PupilLeft', 'PupilRight', 
        'FixationPointX (MCSpx)', 'FixationPointY (MCSpx)'
    ]
    
    # Determine prefix from raw_directory name.
    raw_directory_lower = raw_directory.lower()
    if 'adaptive-bar' in raw_directory_lower:
        prefix = "bar"
    elif 'adaptive-link' in raw_directory_lower:
        prefix = "link"
    elif 'control' in raw_directory_lower:
        prefix = "ctrl"
    else:
        prefix = "unknown"
    
    # Container to hold per-user statistics.
    user_stats = []
    
    # List all segmentation files.
    seg_files = [f for f in os.listdir(seg_directory) if f.endswith('.seg')]
    
    for seg_file in seg_files:
        seg_path = os.path.join(seg_directory, seg_file)
        try:
            # Read segmentation file (whitespace-separated, no header).
            df_seg = pd.read_csv(seg_path, sep='\s+', header=None,
                                 names=['mmd_id', 'mmd_id_dup', 'rec_start', 'rec_end'])
        except Exception as e:
            print(f"Error reading seg file {seg_path}: {e}")
            continue
        
        # Extract user id from the seg filename.
        user_id = extract_user_id(seg_file)
        if user_id is None:
            print(f"Could not extract user id from seg file {seg_file}")
            continue
        
        # Find the corresponding raw TSV file.
        raw_files = [f for f in os.listdir(raw_directory) if f.endswith('.tsv') and str(user_id) in f]
        if not raw_files:
            print(f"No raw TSV file found for user {user_id} in {raw_directory}")
            continue
        raw_file = raw_files[0]  # assuming one raw file per user.
        raw_path = os.path.join(raw_directory, raw_file)
        
        try:
            df_raw = pd.read_csv(raw_path, delimiter='\t', low_memory=False)
        except Exception as e:
            print(f"Error reading raw file {raw_path}: {e}")
            continue
        
        if 'RecordingTimestamp' not in df_raw.columns:
            print(f"'RecordingTimestamp' column not found in {raw_path}. Skipping user {user_id}.")
            continue
        
        # List to store valid segments (DataFrames) for this user.
        user_segments = []
        segment_lengths = []  # store each segment's length (number of rows)
        
        # Process each task in the segmentation file.
        for idx, row in df_seg.iterrows():
            mmd_id = row['mmd_id']
            rec_start = row['rec_start']
            rec_end = row['rec_end']
            
            # Process based on mode.
            if mode == '29s':
                # Grab first 29 seconds based on sampling rate (120Hz): 120*29 = 3480 rows.
                segment_df = df_raw[df_raw['RecordingTimestamp'] >= rec_start].copy()
                segment_df = segment_df.head(120 * 29)
            else:
                # Use the full duration.
                segment_df = df_raw[(df_raw['RecordingTimestamp'] >= rec_start) &
                                    (df_raw['RecordingTimestamp'] <= rec_end)].copy()
            
            if segment_df.empty:
                print(f"No data for user {user_id}, mmd_id {mmd_id} in the specified window.")
                continue
            
            # Remove rows with NaN in valid columns.
            segment_df = segment_df.dropna(subset=valid_columns)
            # Remove rows where any required column equals -1.
            for col in valid_columns:
                segment_df = segment_df[segment_df[col] != -1]
            
            if segment_df.empty:
                print(f"All rows invalid for user {user_id}, mmd_id {mmd_id}.")
                continue
            
            # Restrict to only the valid columns.
            if not set(valid_columns).issubset(segment_df.columns):
                print(f"Warning: Not all valid columns found for user {user_id}, mmd_id {mmd_id}. Skipping.")
                continue
            segment_df = segment_df[valid_columns].copy()
            
            # Add a column for the task id (for sorting later).
            segment_df['task_id'] = mmd_id
            
            # Record the length of this segment.
            seg_len = len(segment_df)
            segment_lengths.append(seg_len)
            
            user_segments.append(segment_df)
        
        if not user_segments:
            print(f"No valid segments found for user {user_id}")
            continue
        
        # Sort the segments by task_id (assuming mmd_id is numeric).
        user_segments_sorted = sorted(user_segments, key=lambda df: df['task_id'].iloc[0])
        
        # Merge (concatenate) all segments into a single DataFrame.
        merged_df = pd.concat(user_segments_sorted, ignore_index=True)
        total_length = len(merged_df)
        mean_length = sum(segment_lengths) / len(segment_lengths)
        min_length = min(segment_lengths)
        max_length = max(segment_lengths)
        
        # Record per-user stats.
        user_stats.append({
            'user_id': user_id,
            'num_segments': len(user_segments),
            'total_length': total_length,
            'mean_segment_length': mean_length,
            'min_segment_length': min_length if mode == '29s' else None,
            'max_segment_length': max_length if mode == '29s' else None
        })
        
        # Cyclically split the merged data into 4 groups.
        cyclic_groups = cyclic_split_df(merged_df, n=4)
        for i, cyclic_df in enumerate(cyclic_groups):
            output_filename = os.path.join(output_directory, f"{prefix}_{user_id}_{i}.pkl")
            with open(output_filename, 'wb') as f:
                pickle.dump(cyclic_df, f)
            print(f"Saved cyclic group {i} for user {user_id} as {output_filename}")
    
    # Compute group-level statistics.
    stats_df = pd.DataFrame(user_stats)
    print("Group-level statistics:")
    print(stats_df.describe())
    
    # Optionally, save the group stats.
    stats_filename = os.path.join(output_directory, f"{prefix}_group_stats.pkl")
    with open(stats_filename, 'wb') as f:
        pickle.dump(stats_df, f)
    print(f"Saved group-level stats as {stats_filename}")

# For full tasks:
crop_merge_and_cyclic_split_from_seg('control_segs', 'control/raw_data', 'data_combined', mode='29s')
crop_merge_and_cyclic_split_from_seg('bar_segs', 'adaptive-bar/raw_data', 'data_combined', mode='29s')
crop_merge_and_cyclic_split_from_seg('link_segs', 'adaptive-link/raw_data', 'data_combined', mode='29s')
# Out:
# No raw TSV file found for user 253 in control/raw_data
# No raw TSV file found for user 247 in control/raw_data
# Saved cyclic group 0 for user 30 as data_combined/ctrl_30_0.pkl
# Saved cyclic group 1 for user 30 as data_combined/ctrl_30_1.pkl
# Saved cyclic group 2 for user 30 as data_combined/ctrl_30_2.pkl
# Saved cyclic group 3 for user 30 as data_combined/ctrl_30_3.pkl
# Saved cyclic group 0 for user 18 as data_combined/ctrl_18_0.pkl
# Saved cyclic group 1 for user 18 as data_combined/ctrl_18_1.pkl
# Saved cyclic group 2 for user 18 as data_combined/ctrl_18_2.pkl
# Saved cyclic group 3 for user 18 as data_combined/ctrl_18_3.pkl
# Saved cyclic group 0 for user 19 as data_combined/ctrl_19_0.pkl
# Saved cyclic group 1 for user 19 as data_combined/ctrl_19_1.pkl
# Saved cyclic group 2 for user 19 as data_combined/ctrl_19_2.pkl
# Saved cyclic group 3 for user 19 as data_combined/ctrl_19_3.pkl
# Saved cyclic group 0 for user 31 as data_combined/ctrl_31_0.pkl
# Saved cyclic group 1 for user 31 as data_combined/ctrl_31_1.pkl
# Saved cyclic group 2 for user 31 as data_combined/ctrl_31_2.pkl
# Saved cyclic group 3 for user 31 as data_combined/ctrl_31_3.pkl
# Saved cyclic group 0 for user 25 as data_combined/ctrl_25_0.pkl
# Saved cyclic group 1 for user 25 as data_combined/ctrl_25_1.pkl
# Saved cyclic group 2 for user 25 as data_combined/ctrl_25_2.pkl
# Saved cyclic group 3 for user 25 as data_combined/ctrl_25_3.pkl
# No raw TSV file found for user 246 in control/raw_data
# No raw TSV file found for user 252 in control/raw_data
# No raw TSV file found for user 244 in control/raw_data
# No raw TSV file found for user 250 in control/raw_data
# Saved cyclic group 0 for user 26 as data_combined/ctrl_26_0.pkl
# Saved cyclic group 1 for user 26 as data_combined/ctrl_26_1.pkl
# Saved cyclic group 2 for user 26 as data_combined/ctrl_26_2.pkl
# Saved cyclic group 3 for user 26 as data_combined/ctrl_26_3.pkl
# No raw TSV file found for user 251 in control/raw_data
# No raw TSV file found for user 245 in control/raw_data
# No raw TSV file found for user 241 in control/raw_data
# Saved cyclic group 0 for user 36 as data_combined/ctrl_36_0.pkl
# Saved cyclic group 1 for user 36 as data_combined/ctrl_36_1.pkl
# Saved cyclic group 2 for user 36 as data_combined/ctrl_36_2.pkl
# Saved cyclic group 3 for user 36 as data_combined/ctrl_36_3.pkl
# No raw TSV file found for user 254 in control/raw_data
# No raw TSV file found for user 240 in control/raw_data
# No raw TSV file found for user 256 in control/raw_data
# No raw TSV file found for user 242 in control/raw_data
# Saved cyclic group 0 for user 21 as data_combined/ctrl_21_0.pkl
# Saved cyclic group 1 for user 21 as data_combined/ctrl_21_1.pkl
# Saved cyclic group 2 for user 21 as data_combined/ctrl_21_2.pkl
# Saved cyclic group 3 for user 21 as data_combined/ctrl_21_3.pkl
# No raw TSV file found for user 257 in control/raw_data
# No raw TSV file found for user 218 in control/raw_data
# No raw TSV file found for user 224 in control/raw_data
# All rows invalid for user 1, mmd_id 76.
# Saved cyclic group 0 for user 1 as data_combined/ctrl_1_0.pkl
# Saved cyclic group 1 for user 1 as data_combined/ctrl_1_1.pkl
# Saved cyclic group 2 for user 1 as data_combined/ctrl_1_2.pkl
# Saved cyclic group 3 for user 1 as data_combined/ctrl_1_3.pkl
# Saved cyclic group 0 for user 84 as data_combined/ctrl_84_0.pkl
# Saved cyclic group 1 for user 84 as data_combined/ctrl_84_1.pkl
# Saved cyclic group 2 for user 84 as data_combined/ctrl_84_2.pkl
# Saved cyclic group 3 for user 84 as data_combined/ctrl_84_3.pkl
# Saved cyclic group 0 for user 90 as data_combined/ctrl_90_0.pkl
# Saved cyclic group 1 for user 90 as data_combined/ctrl_90_1.pkl
# Saved cyclic group 2 for user 90 as data_combined/ctrl_90_2.pkl
# Saved cyclic group 3 for user 90 as data_combined/ctrl_90_3.pkl
# Saved cyclic group 0 for user 91 as data_combined/ctrl_91_0.pkl
# Saved cyclic group 1 for user 91 as data_combined/ctrl_91_1.pkl
# Saved cyclic group 2 for user 91 as data_combined/ctrl_91_2.pkl
# Saved cyclic group 3 for user 91 as data_combined/ctrl_91_3.pkl
# Saved cyclic group 0 for user 85 as data_combined/ctrl_85_0.pkl
# Saved cyclic group 1 for user 85 as data_combined/ctrl_85_1.pkl
# Saved cyclic group 2 for user 85 as data_combined/ctrl_85_2.pkl
# Saved cyclic group 3 for user 85 as data_combined/ctrl_85_3.pkl
# Saved cyclic group 0 for user 52 as data_combined/ctrl_52_0.pkl
# Saved cyclic group 1 for user 52 as data_combined/ctrl_52_1.pkl
# Saved cyclic group 2 for user 52 as data_combined/ctrl_52_2.pkl
# Saved cyclic group 3 for user 52 as data_combined/ctrl_52_3.pkl
# Saved cyclic group 0 for user 46 as data_combined/ctrl_46_0.pkl
# Saved cyclic group 1 for user 46 as data_combined/ctrl_46_1.pkl
# Saved cyclic group 2 for user 46 as data_combined/ctrl_46_2.pkl
# Saved cyclic group 3 for user 46 as data_combined/ctrl_46_3.pkl
# No raw TSV file found for user 225 in control/raw_data
# No raw TSV file found for user 231 in control/raw_data
# No raw TSV file found for user 219 in control/raw_data
# No raw TSV file found for user 227 in control/raw_data
# No raw TSV file found for user 233 in control/raw_data
# Saved cyclic group 0 for user 50 as data_combined/ctrl_50_0.pkl
# Saved cyclic group 1 for user 50 as data_combined/ctrl_50_1.pkl
# Saved cyclic group 2 for user 50 as data_combined/ctrl_50_2.pkl
# Saved cyclic group 3 for user 50 as data_combined/ctrl_50_3.pkl
# Saved cyclic group 0 for user 78 as data_combined/ctrl_78_0.pkl
# Saved cyclic group 1 for user 78 as data_combined/ctrl_78_1.pkl
# Saved cyclic group 2 for user 78 as data_combined/ctrl_78_2.pkl
# Saved cyclic group 3 for user 78 as data_combined/ctrl_78_3.pkl
# Saved cyclic group 0 for user 93 as data_combined/ctrl_93_0.pkl
# Saved cyclic group 1 for user 93 as data_combined/ctrl_93_1.pkl
# Saved cyclic group 2 for user 93 as data_combined/ctrl_93_2.pkl
# Saved cyclic group 3 for user 93 as data_combined/ctrl_93_3.pkl
# Saved cyclic group 0 for user 92 as data_combined/ctrl_92_0.pkl
# Saved cyclic group 1 for user 92 as data_combined/ctrl_92_1.pkl
# Saved cyclic group 2 for user 92 as data_combined/ctrl_92_2.pkl
# Saved cyclic group 3 for user 92 as data_combined/ctrl_92_3.pkl
# Saved cyclic group 0 for user 79 as data_combined/ctrl_79_0.pkl
# Saved cyclic group 1 for user 79 as data_combined/ctrl_79_1.pkl
# Saved cyclic group 2 for user 79 as data_combined/ctrl_79_2.pkl
# Saved cyclic group 3 for user 79 as data_combined/ctrl_79_3.pkl
# Saved cyclic group 0 for user 45 as data_combined/ctrl_45_0.pkl
# Saved cyclic group 1 for user 45 as data_combined/ctrl_45_1.pkl
# Saved cyclic group 2 for user 45 as data_combined/ctrl_45_2.pkl
# Saved cyclic group 3 for user 45 as data_combined/ctrl_45_3.pkl
# No raw TSV file found for user 226 in control/raw_data
# No raw TSV file found for user 236 in control/raw_data
# Saved cyclic group 0 for user 69 as data_combined/ctrl_69_0.pkl
# Saved cyclic group 1 for user 69 as data_combined/ctrl_69_1.pkl
# Saved cyclic group 2 for user 69 as data_combined/ctrl_69_2.pkl
# Saved cyclic group 3 for user 69 as data_combined/ctrl_69_3.pkl
# Saved cyclic group 0 for user 55 as data_combined/ctrl_55_0.pkl
# Saved cyclic group 1 for user 55 as data_combined/ctrl_55_1.pkl
# Saved cyclic group 2 for user 55 as data_combined/ctrl_55_2.pkl
# Saved cyclic group 3 for user 55 as data_combined/ctrl_55_3.pkl
# Saved cyclic group 0 for user 82 as data_combined/ctrl_82_0.pkl
# Saved cyclic group 1 for user 82 as data_combined/ctrl_82_1.pkl
# Saved cyclic group 2 for user 82 as data_combined/ctrl_82_2.pkl
# Saved cyclic group 3 for user 82 as data_combined/ctrl_82_3.pkl
# Saved cyclic group 0 for user 97 as data_combined/ctrl_97_0.pkl
# Saved cyclic group 1 for user 97 as data_combined/ctrl_97_1.pkl
# Saved cyclic group 2 for user 97 as data_combined/ctrl_97_2.pkl
# Saved cyclic group 3 for user 97 as data_combined/ctrl_97_3.pkl
# Saved cyclic group 0 for user 40 as data_combined/ctrl_40_0.pkl
# Saved cyclic group 1 for user 40 as data_combined/ctrl_40_1.pkl
# Saved cyclic group 2 for user 40 as data_combined/ctrl_40_2.pkl
# Saved cyclic group 3 for user 40 as data_combined/ctrl_40_3.pkl
# All rows invalid for user 68, mmd_id 20.
# All rows invalid for user 68, mmd_id 18.
# All rows invalid for user 68, mmd_id 9.
# All rows invalid for user 68, mmd_id 11.
# Saved cyclic group 0 for user 68 as data_combined/ctrl_68_0.pkl
# Saved cyclic group 1 for user 68 as data_combined/ctrl_68_1.pkl
# Saved cyclic group 2 for user 68 as data_combined/ctrl_68_2.pkl
# Saved cyclic group 3 for user 68 as data_combined/ctrl_68_3.pkl
# No raw TSV file found for user 237 in control/raw_data
# No raw TSV file found for user 223 in control/raw_data
# No raw TSV file found for user 235 in control/raw_data
# No raw TSV file found for user 221 in control/raw_data
# No raw TSV file found for user 209 in control/raw_data
# Saved cyclic group 0 for user 42 as data_combined/ctrl_42_0.pkl
# Saved cyclic group 1 for user 42 as data_combined/ctrl_42_1.pkl
# Saved cyclic group 2 for user 42 as data_combined/ctrl_42_2.pkl
# Saved cyclic group 3 for user 42 as data_combined/ctrl_42_3.pkl
# Saved cyclic group 0 for user 81 as data_combined/ctrl_81_0.pkl
# Saved cyclic group 1 for user 81 as data_combined/ctrl_81_1.pkl
# Saved cyclic group 2 for user 81 as data_combined/ctrl_81_2.pkl
# Saved cyclic group 3 for user 81 as data_combined/ctrl_81_3.pkl
# Saved cyclic group 0 for user 95 as data_combined/ctrl_95_0.pkl
# Saved cyclic group 1 for user 95 as data_combined/ctrl_95_1.pkl
# Saved cyclic group 2 for user 95 as data_combined/ctrl_95_2.pkl
# Saved cyclic group 3 for user 95 as data_combined/ctrl_95_3.pkl
# All rows invalid for user 80, mmd_id 27.
# All rows invalid for user 80, mmd_id 9.
# All rows invalid for user 80, mmd_id 76.
# All rows invalid for user 80, mmd_id 30.
# Saved cyclic group 0 for user 80 as data_combined/ctrl_80_0.pkl
# Saved cyclic group 1 for user 80 as data_combined/ctrl_80_1.pkl
# Saved cyclic group 2 for user 80 as data_combined/ctrl_80_2.pkl
# Saved cyclic group 3 for user 80 as data_combined/ctrl_80_3.pkl
# No raw TSV file found for user 208 in control/raw_data
# No raw TSV file found for user 220 in control/raw_data
# No raw TSV file found for user 234 in control/raw_data
# No raw TSV file found for user 239 in control/raw_data
# No raw TSV file found for user 211 in control/raw_data
# No raw TSV file found for user 205 in control/raw_data
# Saved cyclic group 0 for user 66 as data_combined/ctrl_66_0.pkl
# Saved cyclic group 1 for user 66 as data_combined/ctrl_66_1.pkl
# Saved cyclic group 2 for user 66 as data_combined/ctrl_66_2.pkl
# Saved cyclic group 3 for user 66 as data_combined/ctrl_66_3.pkl
# All rows invalid for user 72, mmd_id 20.
# All rows invalid for user 72, mmd_id 3.
# All rows invalid for user 72, mmd_id 5.
# All rows invalid for user 72, mmd_id 66.
# All rows invalid for user 72, mmd_id 74.
# Saved cyclic group 0 for user 72 as data_combined/ctrl_72_0.pkl
# Saved cyclic group 1 for user 72 as data_combined/ctrl_72_1.pkl
# Saved cyclic group 2 for user 72 as data_combined/ctrl_72_2.pkl
# Saved cyclic group 3 for user 72 as data_combined/ctrl_72_3.pkl
# Saved cyclic group 0 for user 9 as data_combined/ctrl_9_0.pkl
# Saved cyclic group 1 for user 9 as data_combined/ctrl_9_1.pkl
# Saved cyclic group 2 for user 9 as data_combined/ctrl_9_2.pkl
# Saved cyclic group 3 for user 9 as data_combined/ctrl_9_3.pkl
# Saved cyclic group 0 for user 73 as data_combined/ctrl_73_0.pkl
# Saved cyclic group 1 for user 73 as data_combined/ctrl_73_1.pkl
# Saved cyclic group 2 for user 73 as data_combined/ctrl_73_2.pkl
# Saved cyclic group 3 for user 73 as data_combined/ctrl_73_3.pkl
# Saved cyclic group 0 for user 67 as data_combined/ctrl_67_0.pkl
# Saved cyclic group 1 for user 67 as data_combined/ctrl_67_1.pkl
# Saved cyclic group 2 for user 67 as data_combined/ctrl_67_2.pkl
# Saved cyclic group 3 for user 67 as data_combined/ctrl_67_3.pkl
# No raw TSV file found for user 204 in control/raw_data
# No raw TSV file found for user 210 in control/raw_data
# No raw TSV file found for user 238 in control/raw_data
# No raw TSV file found for user 206 in control/raw_data
# No raw TSV file found for user 212 in control/raw_data
# Saved cyclic group 0 for user 71 as data_combined/ctrl_71_0.pkl
# Saved cyclic group 1 for user 71 as data_combined/ctrl_71_1.pkl
# Saved cyclic group 2 for user 71 as data_combined/ctrl_71_2.pkl
# Saved cyclic group 3 for user 71 as data_combined/ctrl_71_3.pkl
# Saved cyclic group 0 for user 65 as data_combined/ctrl_65_0.pkl
# Saved cyclic group 1 for user 65 as data_combined/ctrl_65_1.pkl
# Saved cyclic group 2 for user 65 as data_combined/ctrl_65_2.pkl
# Saved cyclic group 3 for user 65 as data_combined/ctrl_65_3.pkl
# Saved cyclic group 0 for user 59 as data_combined/ctrl_59_0.pkl
# Saved cyclic group 1 for user 59 as data_combined/ctrl_59_1.pkl
# Saved cyclic group 2 for user 59 as data_combined/ctrl_59_2.pkl
# Saved cyclic group 3 for user 59 as data_combined/ctrl_59_3.pkl
# Saved cyclic group 0 for user 58 as data_combined/ctrl_58_0.pkl
# Saved cyclic group 1 for user 58 as data_combined/ctrl_58_1.pkl
# Saved cyclic group 2 for user 58 as data_combined/ctrl_58_2.pkl
# Saved cyclic group 3 for user 58 as data_combined/ctrl_58_3.pkl
# Saved cyclic group 0 for user 64 as data_combined/ctrl_64_0.pkl
# Saved cyclic group 1 for user 64 as data_combined/ctrl_64_1.pkl
# Saved cyclic group 2 for user 64 as data_combined/ctrl_64_2.pkl
# Saved cyclic group 3 for user 64 as data_combined/ctrl_64_3.pkl
# Saved cyclic group 0 for user 70 as data_combined/ctrl_70_0.pkl
# Saved cyclic group 1 for user 70 as data_combined/ctrl_70_1.pkl
# Saved cyclic group 2 for user 70 as data_combined/ctrl_70_2.pkl
# Saved cyclic group 3 for user 70 as data_combined/ctrl_70_3.pkl
# No raw TSV file found for user 213 in control/raw_data
# No raw TSV file found for user 207 in control/raw_data
# No raw TSV file found for user 203 in control/raw_data
# No raw TSV file found for user 217 in control/raw_data
# All rows invalid for user 74, mmd_id 3.
# All rows invalid for user 74, mmd_id 72.
# Saved cyclic group 0 for user 74 as data_combined/ctrl_74_0.pkl
# Saved cyclic group 1 for user 74 as data_combined/ctrl_74_1.pkl
# Saved cyclic group 2 for user 74 as data_combined/ctrl_74_2.pkl
# Saved cyclic group 3 for user 74 as data_combined/ctrl_74_3.pkl
# Saved cyclic group 0 for user 60 as data_combined/ctrl_60_0.pkl
# Saved cyclic group 1 for user 60 as data_combined/ctrl_60_1.pkl
# Saved cyclic group 2 for user 60 as data_combined/ctrl_60_2.pkl
# Saved cyclic group 3 for user 60 as data_combined/ctrl_60_3.pkl
# Saved cyclic group 0 for user 61 as data_combined/ctrl_61_0.pkl
# Saved cyclic group 1 for user 61 as data_combined/ctrl_61_1.pkl
# Saved cyclic group 2 for user 61 as data_combined/ctrl_61_2.pkl
# Saved cyclic group 3 for user 61 as data_combined/ctrl_61_3.pkl
# Saved cyclic group 0 for user 75 as data_combined/ctrl_75_0.pkl
# Saved cyclic group 1 for user 75 as data_combined/ctrl_75_1.pkl
# Saved cyclic group 2 for user 75 as data_combined/ctrl_75_2.pkl
# Saved cyclic group 3 for user 75 as data_combined/ctrl_75_3.pkl
# No raw TSV file found for user 202 in control/raw_data
# No raw TSV file found for user 214 in control/raw_data
# No raw TSV file found for user 200 in control/raw_data
# No raw TSV file found for user 228 in control/raw_data
# Saved cyclic group 0 for user 63 as data_combined/ctrl_63_0.pkl
# Saved cyclic group 1 for user 63 as data_combined/ctrl_63_1.pkl
# Saved cyclic group 2 for user 63 as data_combined/ctrl_63_2.pkl
# Saved cyclic group 3 for user 63 as data_combined/ctrl_63_3.pkl
# Saved cyclic group 0 for user 77 as data_combined/ctrl_77_0.pkl
# Saved cyclic group 1 for user 77 as data_combined/ctrl_77_1.pkl
# Saved cyclic group 2 for user 77 as data_combined/ctrl_77_2.pkl
# Saved cyclic group 3 for user 77 as data_combined/ctrl_77_3.pkl
# Saved cyclic group 0 for user 88 as data_combined/ctrl_88_0.pkl
# Saved cyclic group 1 for user 88 as data_combined/ctrl_88_1.pkl
# Saved cyclic group 2 for user 88 as data_combined/ctrl_88_2.pkl
# Saved cyclic group 3 for user 88 as data_combined/ctrl_88_3.pkl
# Saved cyclic group 0 for user 89 as data_combined/ctrl_89_0.pkl
# Saved cyclic group 1 for user 89 as data_combined/ctrl_89_1.pkl
# Saved cyclic group 2 for user 89 as data_combined/ctrl_89_2.pkl
# Saved cyclic group 3 for user 89 as data_combined/ctrl_89_3.pkl
# Saved cyclic group 0 for user 76 as data_combined/ctrl_76_0.pkl
# Saved cyclic group 1 for user 76 as data_combined/ctrl_76_1.pkl
# Saved cyclic group 2 for user 76 as data_combined/ctrl_76_2.pkl
# Saved cyclic group 3 for user 76 as data_combined/ctrl_76_3.pkl
# All rows invalid for user 62, mmd_id 74.
# Saved cyclic group 0 for user 62 as data_combined/ctrl_62_0.pkl
# Saved cyclic group 1 for user 62 as data_combined/ctrl_62_1.pkl
# Saved cyclic group 2 for user 62 as data_combined/ctrl_62_2.pkl
# Saved cyclic group 3 for user 62 as data_combined/ctrl_62_3.pkl
# No raw TSV file found for user 229 in control/raw_data
# No raw TSV file found for user 201 in control/raw_data
# No raw TSV file found for user 215 in control/raw_data
# Saved cyclic group 0 for user 38 as data_combined/ctrl_38_0.pkl
# Saved cyclic group 1 for user 38 as data_combined/ctrl_38_1.pkl
# Saved cyclic group 2 for user 38 as data_combined/ctrl_38_2.pkl
# Saved cyclic group 3 for user 38 as data_combined/ctrl_38_3.pkl
# Saved cyclic group 0 for user 12 as data_combined/ctrl_12_0.pkl
# Saved cyclic group 1 for user 12 as data_combined/ctrl_12_1.pkl
# Saved cyclic group 2 for user 12 as data_combined/ctrl_12_2.pkl
# Saved cyclic group 3 for user 12 as data_combined/ctrl_12_3.pkl
# No raw TSV file found for user 248 in control/raw_data
# Saved cyclic group 0 for user 16 as data_combined/ctrl_16_0.pkl
# Saved cyclic group 1 for user 16 as data_combined/ctrl_16_1.pkl
# Saved cyclic group 2 for user 16 as data_combined/ctrl_16_2.pkl
# Saved cyclic group 3 for user 16 as data_combined/ctrl_16_3.pkl
# No raw TSV file found for user 249 in control/raw_data
# Group-level statistics:
#          user_id  num_segments  total_length  mean_segment_length  \
# count  55.000000     55.000000     55.000000            55.000000
# mean   59.381818     14.672727  35795.600000          2415.459385
# std    25.450381      1.037350   8657.884947           534.132643
# min     1.000000     10.000000   1415.000000           141.500000
# 25%    41.000000     15.000000  32268.500000          2151.233333
# 50%    65.000000     15.000000  38567.000000          2571.133333
# 75%    78.500000     15.000000  42308.500000          2820.566667
# max    97.000000     15.000000  45397.000000          3026.466667
#
#        min_segment_length  max_segment_length
# count           55.000000           55.000000
# mean          1763.909091         2777.800000
# std            889.661385          352.107381
# min              1.000000         1133.000000
# 25%           1251.500000         2679.500000
# 50%           2017.000000         2856.000000
# 75%           2505.000000         2983.500000
# max           2841.000000         3160.000000
# Saved group-level stats as data_combined/ctrl_group_stats.pkl
# Saved cyclic group 0 for user 60 as data_combined/bar_60_0.pkl
# Saved cyclic group 1 for user 60 as data_combined/bar_60_1.pkl
# Saved cyclic group 2 for user 60 as data_combined/bar_60_2.pkl
# Saved cyclic group 3 for user 60 as data_combined/bar_60_3.pkl
# Saved cyclic group 0 for user 75 as data_combined/bar_75_0.pkl
# Saved cyclic group 1 for user 75 as data_combined/bar_75_1.pkl
# Saved cyclic group 2 for user 75 as data_combined/bar_75_2.pkl
# Saved cyclic group 3 for user 75 as data_combined/bar_75_3.pkl
# Saved cyclic group 0 for user 49 as data_combined/bar_49_0.pkl
# Saved cyclic group 1 for user 49 as data_combined/bar_49_1.pkl
# Saved cyclic group 2 for user 49 as data_combined/bar_49_2.pkl
# Saved cyclic group 3 for user 49 as data_combined/bar_49_3.pkl
# Saved cyclic group 0 for user 77 as data_combined/bar_77_0.pkl
# Saved cyclic group 1 for user 77 as data_combined/bar_77_1.pkl
# Saved cyclic group 2 for user 77 as data_combined/bar_77_2.pkl
# Saved cyclic group 3 for user 77 as data_combined/bar_77_3.pkl
# Saved cyclic group 0 for user 63 as data_combined/bar_63_0.pkl
# Saved cyclic group 1 for user 63 as data_combined/bar_63_1.pkl
# Saved cyclic group 2 for user 63 as data_combined/bar_63_2.pkl
# Saved cyclic group 3 for user 63 as data_combined/bar_63_3.pkl
# Saved cyclic group 0 for user 66 as data_combined/bar_66_0.pkl
# Saved cyclic group 1 for user 66 as data_combined/bar_66_1.pkl
# Saved cyclic group 2 for user 66 as data_combined/bar_66_2.pkl
# Saved cyclic group 3 for user 66 as data_combined/bar_66_3.pkl
# No data for user 9, mmd_id 28 in the specified window.
# Saved cyclic group 0 for user 9 as data_combined/bar_9_0.pkl
# Saved cyclic group 1 for user 9 as data_combined/bar_9_1.pkl
# Saved cyclic group 2 for user 9 as data_combined/bar_9_2.pkl
# Saved cyclic group 3 for user 9 as data_combined/bar_9_3.pkl
# Saved cyclic group 0 for user 73 as data_combined/bar_73_0.pkl
# Saved cyclic group 1 for user 73 as data_combined/bar_73_1.pkl
# Saved cyclic group 2 for user 73 as data_combined/bar_73_2.pkl
# Saved cyclic group 3 for user 73 as data_combined/bar_73_3.pkl
# Saved cyclic group 0 for user 71 as data_combined/bar_71_0.pkl
# Saved cyclic group 1 for user 71 as data_combined/bar_71_1.pkl
# Saved cyclic group 2 for user 71 as data_combined/bar_71_2.pkl
# Saved cyclic group 3 for user 71 as data_combined/bar_71_3.pkl
# Saved cyclic group 0 for user 17 as data_combined/bar_17_0.pkl
# Saved cyclic group 1 for user 17 as data_combined/bar_17_1.pkl
# Saved cyclic group 2 for user 17 as data_combined/bar_17_2.pkl
# Saved cyclic group 3 for user 17 as data_combined/bar_17_3.pkl
# Saved cyclic group 0 for user 14 as data_combined/bar_14_0.pkl
# Saved cyclic group 1 for user 14 as data_combined/bar_14_1.pkl
# Saved cyclic group 2 for user 14 as data_combined/bar_14_2.pkl
# Saved cyclic group 3 for user 14 as data_combined/bar_14_3.pkl
# Saved cyclic group 0 for user 15 as data_combined/bar_15_0.pkl
# Saved cyclic group 1 for user 15 as data_combined/bar_15_1.pkl
# Saved cyclic group 2 for user 15 as data_combined/bar_15_2.pkl
# Saved cyclic group 3 for user 15 as data_combined/bar_15_3.pkl
# Saved cyclic group 0 for user 29 as data_combined/bar_29_0.pkl
# Saved cyclic group 1 for user 29 as data_combined/bar_29_1.pkl
# Saved cyclic group 2 for user 29 as data_combined/bar_29_2.pkl
# Saved cyclic group 3 for user 29 as data_combined/bar_29_3.pkl
# Saved cyclic group 0 for user 39 as data_combined/bar_39_0.pkl
# Saved cyclic group 1 for user 39 as data_combined/bar_39_1.pkl
# Saved cyclic group 2 for user 39 as data_combined/bar_39_2.pkl
# Saved cyclic group 3 for user 39 as data_combined/bar_39_3.pkl
# Saved cyclic group 0 for user 38 as data_combined/bar_38_0.pkl
# Saved cyclic group 1 for user 38 as data_combined/bar_38_1.pkl
# Saved cyclic group 2 for user 38 as data_combined/bar_38_2.pkl
# Saved cyclic group 3 for user 38 as data_combined/bar_38_3.pkl
# Saved cyclic group 0 for user 10 as data_combined/bar_10_0.pkl
# Saved cyclic group 1 for user 10 as data_combined/bar_10_1.pkl
# Saved cyclic group 2 for user 10 as data_combined/bar_10_2.pkl
# Saved cyclic group 3 for user 10 as data_combined/bar_10_3.pkl
# Saved cyclic group 0 for user 12 as data_combined/bar_12_0.pkl
# Saved cyclic group 1 for user 12 as data_combined/bar_12_1.pkl
# Saved cyclic group 2 for user 12 as data_combined/bar_12_2.pkl
# Saved cyclic group 3 for user 12 as data_combined/bar_12_3.pkl
# Saved cyclic group 0 for user 13 as data_combined/bar_13_0.pkl
# Saved cyclic group 1 for user 13 as data_combined/bar_13_1.pkl
# Saved cyclic group 2 for user 13 as data_combined/bar_13_2.pkl
# Saved cyclic group 3 for user 13 as data_combined/bar_13_3.pkl
# Saved cyclic group 0 for user 22 as data_combined/bar_22_0.pkl
# Saved cyclic group 1 for user 22 as data_combined/bar_22_1.pkl
# Saved cyclic group 2 for user 22 as data_combined/bar_22_2.pkl
# Saved cyclic group 3 for user 22 as data_combined/bar_22_3.pkl
# Saved cyclic group 0 for user 37 as data_combined/bar_37_0.pkl
# Saved cyclic group 1 for user 37 as data_combined/bar_37_1.pkl
# Saved cyclic group 2 for user 37 as data_combined/bar_37_2.pkl
# Saved cyclic group 3 for user 37 as data_combined/bar_37_3.pkl
# Saved cyclic group 0 for user 35 as data_combined/bar_35_0.pkl
# Saved cyclic group 1 for user 35 as data_combined/bar_35_1.pkl
# Saved cyclic group 2 for user 35 as data_combined/bar_35_2.pkl
# Saved cyclic group 3 for user 35 as data_combined/bar_35_3.pkl
# Saved cyclic group 0 for user 21 as data_combined/bar_21_0.pkl
# Saved cyclic group 1 for user 21 as data_combined/bar_21_1.pkl
# Saved cyclic group 2 for user 21 as data_combined/bar_21_2.pkl
# Saved cyclic group 3 for user 21 as data_combined/bar_21_3.pkl
# Saved cyclic group 0 for user 20 as data_combined/bar_20_0.pkl
# Saved cyclic group 1 for user 20 as data_combined/bar_20_1.pkl
# Saved cyclic group 2 for user 20 as data_combined/bar_20_2.pkl
# Saved cyclic group 3 for user 20 as data_combined/bar_20_3.pkl
# Saved cyclic group 0 for user 34 as data_combined/bar_34_0.pkl
# Saved cyclic group 1 for user 34 as data_combined/bar_34_1.pkl
# Saved cyclic group 2 for user 34 as data_combined/bar_34_2.pkl
# Saved cyclic group 3 for user 34 as data_combined/bar_34_3.pkl
# Saved cyclic group 0 for user 30 as data_combined/bar_30_0.pkl
# Saved cyclic group 1 for user 30 as data_combined/bar_30_1.pkl
# Saved cyclic group 2 for user 30 as data_combined/bar_30_2.pkl
# Saved cyclic group 3 for user 30 as data_combined/bar_30_3.pkl
# Saved cyclic group 0 for user 24 as data_combined/bar_24_0.pkl
# Saved cyclic group 1 for user 24 as data_combined/bar_24_1.pkl
# Saved cyclic group 2 for user 24 as data_combined/bar_24_2.pkl
# Saved cyclic group 3 for user 24 as data_combined/bar_24_3.pkl
# Saved cyclic group 0 for user 18 as data_combined/bar_18_0.pkl
# Saved cyclic group 1 for user 18 as data_combined/bar_18_1.pkl
# Saved cyclic group 2 for user 18 as data_combined/bar_18_2.pkl
# Saved cyclic group 3 for user 18 as data_combined/bar_18_3.pkl
# Saved cyclic group 0 for user 25 as data_combined/bar_25_0.pkl
# Saved cyclic group 1 for user 25 as data_combined/bar_25_1.pkl
# Saved cyclic group 2 for user 25 as data_combined/bar_25_2.pkl
# Saved cyclic group 3 for user 25 as data_combined/bar_25_3.pkl
# Saved cyclic group 0 for user 82 as data_combined/bar_82_0.pkl
# Saved cyclic group 1 for user 82 as data_combined/bar_82_1.pkl
# Saved cyclic group 2 for user 82 as data_combined/bar_82_2.pkl
# Saved cyclic group 3 for user 82 as data_combined/bar_82_3.pkl
# Saved cyclic group 0 for user 69 as data_combined/bar_69_0.pkl
# Saved cyclic group 1 for user 69 as data_combined/bar_69_1.pkl
# Saved cyclic group 2 for user 69 as data_combined/bar_69_2.pkl
# Saved cyclic group 3 for user 69 as data_combined/bar_69_3.pkl
# Saved cyclic group 0 for user 41 as data_combined/bar_41_0.pkl
# Saved cyclic group 1 for user 41 as data_combined/bar_41_1.pkl
# Saved cyclic group 2 for user 41 as data_combined/bar_41_2.pkl
# Saved cyclic group 3 for user 41 as data_combined/bar_41_3.pkl
# Saved cyclic group 0 for user 6 as data_combined/bar_6_0.pkl
# Saved cyclic group 1 for user 6 as data_combined/bar_6_1.pkl
# Saved cyclic group 2 for user 6 as data_combined/bar_6_2.pkl
# Saved cyclic group 3 for user 6 as data_combined/bar_6_3.pkl
# Saved cyclic group 0 for user 54 as data_combined/bar_54_0.pkl
# Saved cyclic group 1 for user 54 as data_combined/bar_54_1.pkl
# Saved cyclic group 2 for user 54 as data_combined/bar_54_2.pkl
# Saved cyclic group 3 for user 54 as data_combined/bar_54_3.pkl
# Saved cyclic group 0 for user 68 as data_combined/bar_68_0.pkl
# Saved cyclic group 1 for user 68 as data_combined/bar_68_1.pkl
# Saved cyclic group 2 for user 68 as data_combined/bar_68_2.pkl
# Saved cyclic group 3 for user 68 as data_combined/bar_68_3.pkl
# Saved cyclic group 0 for user 81 as data_combined/bar_81_0.pkl
# Saved cyclic group 1 for user 81 as data_combined/bar_81_1.pkl
# Saved cyclic group 2 for user 81 as data_combined/bar_81_2.pkl
# Saved cyclic group 3 for user 81 as data_combined/bar_81_3.pkl
# Saved cyclic group 0 for user 56 as data_combined/bar_56_0.pkl
# Saved cyclic group 1 for user 56 as data_combined/bar_56_1.pkl
# Saved cyclic group 2 for user 56 as data_combined/bar_56_2.pkl
# Saved cyclic group 3 for user 56 as data_combined/bar_56_3.pkl
# Saved cyclic group 0 for user 42 as data_combined/bar_42_0.pkl
# Saved cyclic group 1 for user 42 as data_combined/bar_42_1.pkl
# Saved cyclic group 2 for user 42 as data_combined/bar_42_2.pkl
# Saved cyclic group 3 for user 42 as data_combined/bar_42_3.pkl
# Saved cyclic group 0 for user 4 as data_combined/bar_4_0.pkl
# Saved cyclic group 1 for user 4 as data_combined/bar_4_1.pkl
# Saved cyclic group 2 for user 4 as data_combined/bar_4_2.pkl
# Saved cyclic group 3 for user 4 as data_combined/bar_4_3.pkl
# Saved cyclic group 0 for user 5 as data_combined/bar_5_0.pkl
# Saved cyclic group 1 for user 5 as data_combined/bar_5_1.pkl
# Saved cyclic group 2 for user 5 as data_combined/bar_5_2.pkl
# Saved cyclic group 3 for user 5 as data_combined/bar_5_3.pkl
# Saved cyclic group 0 for user 43 as data_combined/bar_43_0.pkl
# Saved cyclic group 1 for user 43 as data_combined/bar_43_1.pkl
# Saved cyclic group 2 for user 43 as data_combined/bar_43_2.pkl
# Saved cyclic group 3 for user 43 as data_combined/bar_43_3.pkl
# Saved cyclic group 0 for user 1 as data_combined/bar_1_0.pkl
# Saved cyclic group 1 for user 1 as data_combined/bar_1_1.pkl
# Saved cyclic group 2 for user 1 as data_combined/bar_1_2.pkl
# Saved cyclic group 3 for user 1 as data_combined/bar_1_3.pkl
# Saved cyclic group 0 for user 46 as data_combined/bar_46_0.pkl
# Saved cyclic group 1 for user 46 as data_combined/bar_46_1.pkl
# Saved cyclic group 2 for user 46 as data_combined/bar_46_2.pkl
# Saved cyclic group 3 for user 46 as data_combined/bar_46_3.pkl
# Saved cyclic group 0 for user 85 as data_combined/bar_85_0.pkl
# Saved cyclic group 1 for user 85 as data_combined/bar_85_1.pkl
# Saved cyclic group 2 for user 85 as data_combined/bar_85_2.pkl
# Saved cyclic group 3 for user 85 as data_combined/bar_85_3.pkl
# Saved cyclic group 0 for user 44 as data_combined/bar_44_0.pkl
# Saved cyclic group 1 for user 44 as data_combined/bar_44_1.pkl
# Saved cyclic group 2 for user 44 as data_combined/bar_44_2.pkl
# Saved cyclic group 3 for user 44 as data_combined/bar_44_3.pkl
# Saved cyclic group 0 for user 50 as data_combined/bar_50_0.pkl
# Saved cyclic group 1 for user 50 as data_combined/bar_50_1.pkl
# Saved cyclic group 2 for user 50 as data_combined/bar_50_2.pkl
# Saved cyclic group 3 for user 50 as data_combined/bar_50_3.pkl
# Saved cyclic group 0 for user 78 as data_combined/bar_78_0.pkl
# Saved cyclic group 1 for user 78 as data_combined/bar_78_1.pkl
# Saved cyclic group 2 for user 78 as data_combined/bar_78_2.pkl
# Saved cyclic group 3 for user 78 as data_combined/bar_78_3.pkl
# Saved cyclic group 0 for user 2 as data_combined/bar_2_0.pkl
# Saved cyclic group 1 for user 2 as data_combined/bar_2_1.pkl
# Saved cyclic group 2 for user 2 as data_combined/bar_2_2.pkl
# Saved cyclic group 3 for user 2 as data_combined/bar_2_3.pkl
# Saved cyclic group 0 for user 79 as data_combined/bar_79_0.pkl
# Saved cyclic group 1 for user 79 as data_combined/bar_79_1.pkl
# Saved cyclic group 2 for user 79 as data_combined/bar_79_2.pkl
# Saved cyclic group 3 for user 79 as data_combined/bar_79_3.pkl
# Saved cyclic group 0 for user 51 as data_combined/bar_51_0.pkl
# Saved cyclic group 1 for user 51 as data_combined/bar_51_1.pkl
# Saved cyclic group 2 for user 51 as data_combined/bar_51_2.pkl
# Saved cyclic group 3 for user 51 as data_combined/bar_51_3.pkl
# Group-level statistics:
#          user_id  num_segments  total_length  mean_segment_length  \
# count  49.000000     49.000000     49.000000            49.000000
# mean   40.469388     13.979592  35048.102041          2506.987890
# std    25.540085      0.142857   5533.366050           393.810846
# min     1.000000     13.000000  12582.000000           898.714286
# 25%    18.000000     14.000000  34692.000000          2478.000000
# 50%    39.000000     14.000000  36025.000000          2573.214286
# 75%    63.000000     14.000000  37825.000000          2701.785714
# max    85.000000     14.000000  41761.000000          2982.928571
#
#        min_segment_length  max_segment_length
# count           49.000000           49.000000
# mean          1937.734694         2811.448980
# std            694.340418          295.146719
# min            147.000000         1795.000000
# 25%           1575.000000         2717.000000
# 50%           2116.000000         2905.000000
# 75%           2494.000000         2984.000000
# max           2815.000000         3134.000000
# Saved group-level stats as data_combined/bar_group_stats.pkl
# Saved cyclic group 0 for user 4 as data_combined/link_4_0.pkl
# Saved cyclic group 1 for user 4 as data_combined/link_4_1.pkl
# Saved cyclic group 2 for user 4 as data_combined/link_4_2.pkl
# Saved cyclic group 3 for user 4 as data_combined/link_4_3.pkl
# Saved cyclic group 0 for user 5 as data_combined/link_5_0.pkl
# Saved cyclic group 1 for user 5 as data_combined/link_5_1.pkl
# Saved cyclic group 2 for user 5 as data_combined/link_5_2.pkl
# Saved cyclic group 3 for user 5 as data_combined/link_5_3.pkl
# Saved cyclic group 0 for user 6 as data_combined/link_6_0.pkl
# Saved cyclic group 1 for user 6 as data_combined/link_6_1.pkl
# Saved cyclic group 2 for user 6 as data_combined/link_6_2.pkl
# Saved cyclic group 3 for user 6 as data_combined/link_6_3.pkl
# Saved cyclic group 0 for user 3 as data_combined/link_3_0.pkl
# Saved cyclic group 1 for user 3 as data_combined/link_3_1.pkl
# Saved cyclic group 2 for user 3 as data_combined/link_3_2.pkl
# Saved cyclic group 3 for user 3 as data_combined/link_3_3.pkl
# Saved cyclic group 0 for user 1 as data_combined/link_1_0.pkl
# Saved cyclic group 1 for user 1 as data_combined/link_1_1.pkl
# Saved cyclic group 2 for user 1 as data_combined/link_1_2.pkl
# Saved cyclic group 3 for user 1 as data_combined/link_1_3.pkl
# Saved cyclic group 0 for user 19 as data_combined/link_19_0.pkl
# Saved cyclic group 1 for user 19 as data_combined/link_19_1.pkl
# Saved cyclic group 2 for user 19 as data_combined/link_19_2.pkl
# Saved cyclic group 3 for user 19 as data_combined/link_19_3.pkl
# Saved cyclic group 0 for user 30 as data_combined/link_30_0.pkl
# Saved cyclic group 1 for user 30 as data_combined/link_30_1.pkl
# Saved cyclic group 2 for user 30 as data_combined/link_30_2.pkl
# Saved cyclic group 3 for user 30 as data_combined/link_30_3.pkl
# Saved cyclic group 0 for user 18 as data_combined/link_18_0.pkl
# Saved cyclic group 1 for user 18 as data_combined/link_18_1.pkl
# Saved cyclic group 2 for user 18 as data_combined/link_18_2.pkl
# Saved cyclic group 3 for user 18 as data_combined/link_18_3.pkl
# Saved cyclic group 0 for user 32 as data_combined/link_32_0.pkl
# Saved cyclic group 1 for user 32 as data_combined/link_32_1.pkl
# Saved cyclic group 2 for user 32 as data_combined/link_32_2.pkl
# Saved cyclic group 3 for user 32 as data_combined/link_32_3.pkl
# Saved cyclic group 0 for user 26 as data_combined/link_26_0.pkl
# Saved cyclic group 1 for user 26 as data_combined/link_26_1.pkl
# Saved cyclic group 2 for user 26 as data_combined/link_26_2.pkl
# Saved cyclic group 3 for user 26 as data_combined/link_26_3.pkl
# Saved cyclic group 0 for user 33 as data_combined/link_33_0.pkl
# Saved cyclic group 1 for user 33 as data_combined/link_33_1.pkl
# Saved cyclic group 2 for user 33 as data_combined/link_33_2.pkl
# Saved cyclic group 3 for user 33 as data_combined/link_33_3.pkl
# Saved cyclic group 0 for user 23 as data_combined/link_23_0.pkl
# Saved cyclic group 1 for user 23 as data_combined/link_23_1.pkl
# Saved cyclic group 2 for user 23 as data_combined/link_23_2.pkl
# Saved cyclic group 3 for user 23 as data_combined/link_23_3.pkl
# Saved cyclic group 0 for user 20 as data_combined/link_20_0.pkl
# Saved cyclic group 1 for user 20 as data_combined/link_20_1.pkl
# Saved cyclic group 2 for user 20 as data_combined/link_20_2.pkl
# Saved cyclic group 3 for user 20 as data_combined/link_20_3.pkl
# Saved cyclic group 0 for user 34 as data_combined/link_34_0.pkl
# Saved cyclic group 1 for user 34 as data_combined/link_34_1.pkl
# Saved cyclic group 2 for user 34 as data_combined/link_34_2.pkl
# Saved cyclic group 3 for user 34 as data_combined/link_34_3.pkl
# Saved cyclic group 0 for user 35 as data_combined/link_35_0.pkl
# Saved cyclic group 1 for user 35 as data_combined/link_35_1.pkl
# Saved cyclic group 2 for user 35 as data_combined/link_35_2.pkl
# Saved cyclic group 3 for user 35 as data_combined/link_35_3.pkl
# Saved cyclic group 0 for user 21 as data_combined/link_21_0.pkl
# Saved cyclic group 1 for user 21 as data_combined/link_21_1.pkl
# Saved cyclic group 2 for user 21 as data_combined/link_21_2.pkl
# Saved cyclic group 3 for user 21 as data_combined/link_21_3.pkl
# Saved cyclic group 0 for user 10 as data_combined/link_10_0.pkl
# Saved cyclic group 1 for user 10 as data_combined/link_10_1.pkl
# Saved cyclic group 2 for user 10 as data_combined/link_10_2.pkl
# Saved cyclic group 3 for user 10 as data_combined/link_10_3.pkl
# Saved cyclic group 0 for user 11 as data_combined/link_11_0.pkl
# Saved cyclic group 1 for user 11 as data_combined/link_11_1.pkl
# Saved cyclic group 2 for user 11 as data_combined/link_11_2.pkl
# Saved cyclic group 3 for user 11 as data_combined/link_11_3.pkl
# All rows invalid for user 13, mmd_id 62.
# All rows invalid for user 13, mmd_id 27.
# All rows invalid for user 13, mmd_id 20.
# Saved cyclic group 0 for user 13 as data_combined/link_13_0.pkl
# Saved cyclic group 1 for user 13 as data_combined/link_13_1.pkl
# Saved cyclic group 2 for user 13 as data_combined/link_13_2.pkl
# Saved cyclic group 3 for user 13 as data_combined/link_13_3.pkl
# Saved cyclic group 0 for user 12 as data_combined/link_12_0.pkl
# Saved cyclic group 1 for user 12 as data_combined/link_12_1.pkl
# Saved cyclic group 2 for user 12 as data_combined/link_12_2.pkl
# Saved cyclic group 3 for user 12 as data_combined/link_12_3.pkl
# Saved cyclic group 0 for user 16 as data_combined/link_16_0.pkl
# Saved cyclic group 1 for user 16 as data_combined/link_16_1.pkl
# Saved cyclic group 2 for user 16 as data_combined/link_16_2.pkl
# Saved cyclic group 3 for user 16 as data_combined/link_16_3.pkl
# Saved cyclic group 0 for user 17 as data_combined/link_17_0.pkl
# Saved cyclic group 1 for user 17 as data_combined/link_17_1.pkl
# Saved cyclic group 2 for user 17 as data_combined/link_17_2.pkl
# Saved cyclic group 3 for user 17 as data_combined/link_17_3.pkl
# Saved cyclic group 0 for user 15 as data_combined/link_15_0.pkl
# Saved cyclic group 1 for user 15 as data_combined/link_15_1.pkl
# Saved cyclic group 2 for user 15 as data_combined/link_15_2.pkl
# Saved cyclic group 3 for user 15 as data_combined/link_15_3.pkl
# Saved cyclic group 0 for user 29 as data_combined/link_29_0.pkl
# Saved cyclic group 1 for user 29 as data_combined/link_29_1.pkl
# Saved cyclic group 2 for user 29 as data_combined/link_29_2.pkl
# Saved cyclic group 3 for user 29 as data_combined/link_29_3.pkl
# No data for user 14, mmd_id 30 in the specified window.
# No data for user 14, mmd_id 72 in the specified window.
# No data for user 14, mmd_id 11 in the specified window.
# Saved cyclic group 0 for user 14 as data_combined/link_14_0.pkl
# Saved cyclic group 1 for user 14 as data_combined/link_14_1.pkl
# Saved cyclic group 2 for user 14 as data_combined/link_14_2.pkl
# Saved cyclic group 3 for user 14 as data_combined/link_14_3.pkl
# Saved cyclic group 0 for user 8 as data_combined/link_8_0.pkl
# Saved cyclic group 1 for user 8 as data_combined/link_8_1.pkl
# Saved cyclic group 2 for user 8 as data_combined/link_8_2.pkl
# Saved cyclic group 3 for user 8 as data_combined/link_8_3.pkl
# No data for user 9, mmd_id 20 in the specified window.
# No data for user 9, mmd_id 62 in the specified window.
# Saved cyclic group 0 for user 9 as data_combined/link_9_0.pkl
# Saved cyclic group 1 for user 9 as data_combined/link_9_1.pkl
# Saved cyclic group 2 for user 9 as data_combined/link_9_2.pkl
# Saved cyclic group 3 for user 9 as data_combined/link_9_3.pkl
# Group-level statistics:
#          user_id  num_segments  total_length  mean_segment_length  \
# count  27.000000     27.000000     27.000000            27.000000
# mean   17.185185     13.703704  35623.962963          2582.964887
# std    10.235823      0.868899   9008.385762           603.668852
# min     1.000000     11.000000   6687.000000           477.642857
# 25%     9.500000     14.000000  34744.500000          2555.785714
# 50%    16.000000     14.000000  38010.000000          2715.000000
# 75%    24.500000     14.000000  40905.500000          2921.821429
# max    35.000000     14.000000  43756.000000          3125.428571
#
#        min_segment_length  max_segment_length
# count           27.000000           27.000000
# mean          2192.111111         2865.222222
# std            800.581728          350.128694
# min             12.000000         1609.000000
# 25%           1978.500000         2797.500000
# 50%           2434.000000         2987.000000
# 75%           2721.500000         3077.500000
# max           2952.000000         3199.000000
# Saved group-level stats as data_combined/link_group_stats.pkl

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

def scanpath_from_pickle(pickle_directory, output_directory):
    """
    For each pickle file in pickle_directory, this function:
      1. Loads the pickle file (assumed to be a preprocessed DataFrame containing gaze data).
      2. Removes rows with invalid gaze points (i.e. any required gaze column equals -1).
      3. Computes the average gaze coordinates from left and right gaze columns.
      4. Plots a single scanpath image (scatter for fixations and line for saccades) for the entire DataFrame.
      5. Saves the image as a PNG file using the pickle file’s base name.
    
    Parameters:
      pickle_directory (str): Directory containing pickle files.
      output_directory (str): Directory where output scanpath images will be saved.
    """
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)
    
    # Define required gaze columns.
    valid_gaze_columns = [
        'GazePointLeftX (ADCSpx)',
        'GazePointLeftY (ADCSpx)',
        'GazePointRightX (ADCSpx)',
        'GazePointRightY (ADCSpx)'
    ]
    
    # List all pickle files in the directory.
    pickle_files = [f for f in os.listdir(pickle_directory) if f.lower().endswith('.pkl')]
    
    for pickle_file in pickle_files:
        pickle_path = os.path.join(pickle_directory, pickle_file)
        try:
            # Load the preprocessed DataFrame from the pickle file.
            df = pd.read_pickle(pickle_path)
        except Exception as e:
            print(f"Error reading pickle file {pickle_path}: {e}")
            continue
        
        # Check if the required gaze columns exist.
        missing_cols = [col for col in valid_gaze_columns if col not in df.columns]
        if missing_cols:
            print(f"File {pickle_file} is missing columns: {missing_cols}. Skipping.")
            continue
        
        # Remove rows where any required gaze column equals -1.
        for col in valid_gaze_columns:
            df = df[df[col] != -1]
        
        if df.empty:
            print(f"No valid gaze data in {pickle_file}. Skipping.")
            continue
        
        # Compute average gaze coordinates.
        df['r_GazePointX (ADCSpx)'] = (df['GazePointLeftX (ADCSpx)'] + df['GazePointRightX (ADCSpx)']) / 2
        df['r_GazePointY (ADCSpx)'] = (df['GazePointLeftY (ADCSpx)'] + df['GazePointRightY (ADCSpx)']) / 2
        
        # Drop any rows with NaN in the computed gaze points.
        df = df.dropna(subset=['r_GazePointX (ADCSpx)', 'r_GazePointY (ADCSpx)'])
        
        # Extract the computed gaze coordinates.
        x = df['r_GazePointX (ADCSpx)'].values
        y = df['r_GazePointY (ADCSpx)'].values
        
        if len(x) == 0 or len(y) == 0:
            print(f"No valid computed gaze data in {pickle_file}. Skipping.")
            continue
        
        # Plot the scanpath: scatter for fixations and a line to indicate the path.
        try:
            plt.figure()
            plt.scatter(x, y, s=5)  # You can adjust marker size and color as needed.
            plt.plot(x, y, linewidth=1)
            plt.axis('off')  # Hide axis for a cleaner image.
            
            # Use the pickle file's base name as the output file name.
            base_name = os.path.splitext(pickle_file)[0]
            output_filename = os.path.join(output_directory, f"{base_name}.png")
            plt.savefig(output_filename, bbox_inches='tight', pad_inches=0)
            print(f"Saved scanpath image for {pickle_file} as {output_filename}")
            plt.close()
        except Exception as e:
            print(f"Error generating scanpath for {pickle_file}: {e}")
            plt.close()
# Out:
# Saved scanpath image for ctrl_70_0.pkl as data_combined/ctrl_70_0.png
# Saved scanpath image for bar_21_3.pkl as data_combined/bar_21_3.png
# Saved scanpath image for link_16_2.pkl as data_combined/link_16_2.png
# Saved scanpath image for link_30_1.pkl as data_combined/link_30_1.png
# Saved scanpath image for bar_42_0.pkl as data_combined/bar_42_0.png
# Saved scanpath image for ctrl_72_2.pkl as data_combined/ctrl_72_2.png
# Saved scanpath image for link_14_0.pkl as data_combined/link_14_0.png
# Saved scanpath image for bar_66_1.pkl as data_combined/bar_66_1.png
# Saved scanpath image for link_32_3.pkl as data_combined/link_32_3.png
# Saved scanpath image for link_29_0.pkl as data_combined/link_29_0.png
# Saved scanpath image for bar_38_2.pkl as data_combined/bar_38_2.png
# Saved scanpath image for ctrl_69_1.pkl as data_combined/ctrl_69_1.png
# Saved scanpath image for bar_82_0.pkl as data_combined/bar_82_0.png
# Saved scanpath image for bar_82_1.pkl as data_combined/bar_82_1.png
# Saved scanpath image for ctrl_69_0.pkl as data_combined/ctrl_69_0.png
# Saved scanpath image for bar_38_3.pkl as data_combined/bar_38_3.png
# Saved scanpath image for link_29_1.pkl as data_combined/link_29_1.png
# Saved scanpath image for link_32_2.pkl as data_combined/link_32_2.png
# Saved scanpath image for link_14_1.pkl as data_combined/link_14_1.png
# Saved scanpath image for bar_66_0.pkl as data_combined/bar_66_0.png
# Saved scanpath image for ctrl_72_3.pkl as data_combined/ctrl_72_3.png
# Saved scanpath image for link_30_0.pkl as data_combined/link_30_0.png
# Saved scanpath image for bar_42_1.pkl as data_combined/bar_42_1.png
# Saved scanpath image for link_16_3.pkl as data_combined/link_16_3.png
# Saved scanpath image for bar_21_2.pkl as data_combined/bar_21_2.png
# Saved scanpath image for ctrl_70_1.pkl as data_combined/ctrl_70_1.png
# Saved scanpath image for ctrl_70_3.pkl as data_combined/ctrl_70_3.png
# Saved scanpath image for bar_42_3.pkl as data_combined/bar_42_3.png
# Saved scanpath image for link_30_2.pkl as data_combined/link_30_2.png
# Saved scanpath image for bar_21_0.pkl as data_combined/bar_21_0.png
# Saved scanpath image for link_16_1.pkl as data_combined/link_16_1.png
# Saved scanpath image for ctrl_72_1.pkl as data_combined/ctrl_72_1.png
# Saved scanpath image for link_32_0.pkl as data_combined/link_32_0.png
# Saved scanpath image for bar_66_2.pkl as data_combined/bar_66_2.png
# Saved scanpath image for link_14_3.pkl as data_combined/link_14_3.png
# Saved scanpath image for bar_38_1.pkl as data_combined/bar_38_1.png
# Saved scanpath image for link_29_3.pkl as data_combined/link_29_3.png
# Saved scanpath image for ctrl_69_2.pkl as data_combined/ctrl_69_2.png
# Saved scanpath image for bar_82_3.pkl as data_combined/bar_82_3.png
# Saved scanpath image for bar_82_2.pkl as data_combined/bar_82_2.png
# Saved scanpath image for ctrl_69_3.pkl as data_combined/ctrl_69_3.png
# Saved scanpath image for link_29_2.pkl as data_combined/link_29_2.png
# Saved scanpath image for bar_38_0.pkl as data_combined/bar_38_0.png
# Saved scanpath image for bar_66_3.pkl as data_combined/bar_66_3.png
# Saved scanpath image for link_14_2.pkl as data_combined/link_14_2.png
# Saved scanpath image for link_32_1.pkl as data_combined/link_32_1.png
# Saved scanpath image for ctrl_72_0.pkl as data_combined/ctrl_72_0.png
# Saved scanpath image for link_16_0.pkl as data_combined/link_16_0.png
# Saved scanpath image for bar_21_1.pkl as data_combined/bar_21_1.png
# Saved scanpath image for bar_42_2.pkl as data_combined/bar_42_2.png
# Saved scanpath image for link_30_3.pkl as data_combined/link_30_3.png
# Saved scanpath image for ctrl_70_2.pkl as data_combined/ctrl_70_2.png
# Saved scanpath image for bar_79_0.pkl as data_combined/bar_79_0.png
# Saved scanpath image for ctrl_90_3.pkl as data_combined/ctrl_90_3.png
# Saved scanpath image for bar_18_1.pkl as data_combined/bar_18_1.png
# Saved scanpath image for ctrl_92_1.pkl as data_combined/ctrl_92_1.png
# Saved scanpath image for ctrl_52_1.pkl as data_combined/ctrl_52_1.png
# Saved scanpath image for ctrl_31_2.pkl as data_combined/ctrl_31_2.png
# Saved scanpath image for ctrl_74_2.pkl as data_combined/ctrl_74_2.png
# Saved scanpath image for link_12_0.pkl as data_combined/link_12_0.png
# Saved scanpath image for bar_25_1.pkl as data_combined/bar_25_1.png
# Saved scanpath image for ctrl_89_2.pkl as data_combined/ctrl_89_2.png
# Saved scanpath image for bar_60_1.pkl as data_combined/bar_60_1.png
# Saved scanpath image for bar_46_2.pkl as data_combined/bar_46_2.png
# Saved scanpath image for link_34_3.pkl as data_combined/link_34_3.png
# Saved scanpath image for ctrl_50_3.pkl as data_combined/ctrl_50_3.png
# Saved scanpath image for ctrl_76_0.pkl as data_combined/ctrl_76_0.png
# Saved scanpath image for link_9_3.pkl as data_combined/link_9_3.png
# Saved scanpath image for link_10_2.pkl as data_combined/link_10_2.png
# Saved scanpath image for bar_44_0.pkl as data_combined/bar_44_0.png
# Saved scanpath image for bar_44_1.pkl as data_combined/bar_44_1.png
# Saved scanpath image for link_10_3.pkl as data_combined/link_10_3.png
# Saved scanpath image for link_9_2.pkl as data_combined/link_9_2.png
# Saved scanpath image for ctrl_76_1.pkl as data_combined/ctrl_76_1.png
# Saved scanpath image for ctrl_50_2.pkl as data_combined/ctrl_50_2.png
# Saved scanpath image for bar_46_3.pkl as data_combined/bar_46_3.png
# Saved scanpath image for link_34_2.pkl as data_combined/link_34_2.png
# Saved scanpath image for ctrl_89_3.pkl as data_combined/ctrl_89_3.png
# Saved scanpath image for bar_25_0.pkl as data_combined/bar_25_0.png
# Saved scanpath image for link_12_1.pkl as data_combined/link_12_1.png
# Saved scanpath image for bar_60_0.pkl as data_combined/bar_60_0.png
# Saved scanpath image for ctrl_31_3.pkl as data_combined/ctrl_31_3.png
# Saved scanpath image for ctrl_74_3.pkl as data_combined/ctrl_74_3.png
# Saved scanpath image for ctrl_52_0.pkl as data_combined/ctrl_52_0.png
# Saved scanpath image for ctrl_92_0.pkl as data_combined/ctrl_92_0.png
# Saved scanpath image for bar_18_0.pkl as data_combined/bar_18_0.png
# Saved scanpath image for bar_79_1.pkl as data_combined/bar_79_1.png
# Saved scanpath image for ctrl_90_2.pkl as data_combined/ctrl_90_2.png
# Saved scanpath image for ctrl_90_0.pkl as data_combined/ctrl_90_0.png
# Saved scanpath image for bar_79_3.pkl as data_combined/bar_79_3.png
# Saved scanpath image for ctrl_92_2.pkl as data_combined/ctrl_92_2.png
# Saved scanpath image for bar_18_2.pkl as data_combined/bar_18_2.png
# Saved scanpath image for ctrl_74_1.pkl as data_combined/ctrl_74_1.png
# Saved scanpath image for ctrl_31_1.pkl as data_combined/ctrl_31_1.png
# Saved scanpath image for ctrl_52_2.pkl as data_combined/ctrl_52_2.png
# Saved scanpath image for link_34_0.pkl as data_combined/link_34_0.png
# Saved scanpath image for bar_46_1.pkl as data_combined/bar_46_1.png
# Saved scanpath image for bar_60_2.pkl as data_combined/bar_60_2.png
# Saved scanpath image for link_12_3.pkl as data_combined/link_12_3.png
# Saved scanpath image for bar_25_2.pkl as data_combined/bar_25_2.png
# Saved scanpath image for ctrl_89_1.pkl as data_combined/ctrl_89_1.png
# Saved scanpath image for ctrl_76_3.pkl as data_combined/ctrl_76_3.png
# Saved scanpath image for ctrl_50_0.pkl as data_combined/ctrl_50_0.png
# Saved scanpath image for link_9_0.pkl as data_combined/link_9_0.png
# Saved scanpath image for bar_44_3.pkl as data_combined/bar_44_3.png
# Saved scanpath image for link_10_1.pkl as data_combined/link_10_1.png
# Saved scanpath image for link_10_0.pkl as data_combined/link_10_0.png
# Saved scanpath image for bar_44_2.pkl as data_combined/bar_44_2.png
# Saved scanpath image for link_9_1.pkl as data_combined/link_9_1.png
# Saved scanpath image for ctrl_50_1.pkl as data_combined/ctrl_50_1.png
# Saved scanpath image for ctrl_76_2.pkl as data_combined/ctrl_76_2.png
# Saved scanpath image for bar_60_3.pkl as data_combined/bar_60_3.png
# Saved scanpath image for ctrl_89_0.pkl as data_combined/ctrl_89_0.png
# Saved scanpath image for bar_25_3.pkl as data_combined/bar_25_3.png
# Saved scanpath image for link_12_2.pkl as data_combined/link_12_2.png
# Saved scanpath image for link_34_1.pkl as data_combined/link_34_1.png
# Saved scanpath image for bar_46_0.pkl as data_combined/bar_46_0.png
# Saved scanpath image for ctrl_52_3.pkl as data_combined/ctrl_52_3.png
# Saved scanpath image for ctrl_74_0.pkl as data_combined/ctrl_74_0.png
# Saved scanpath image for ctrl_31_0.pkl as data_combined/ctrl_31_0.png
# Saved scanpath image for bar_18_3.pkl as data_combined/bar_18_3.png
# Saved scanpath image for ctrl_92_3.pkl as data_combined/ctrl_92_3.png
# Saved scanpath image for ctrl_90_1.pkl as data_combined/ctrl_90_1.png
# Saved scanpath image for bar_79_2.pkl as data_combined/bar_79_2.png
# Saved scanpath image for ctrl_97_0.pkl as data_combined/ctrl_97_0.png
# Saved scanpath image for ctrl_95_2.pkl as data_combined/ctrl_95_2.png
# Saved scanpath image for bar_39_1.pkl as data_combined/bar_39_1.png
# Saved scanpath image for bar_81_1.pkl as data_combined/bar_81_1.png
# Saved scanpath image for ctrl_68_2.pkl as data_combined/ctrl_68_2.png
# Saved scanpath image for ctrl_36_1.pkl as data_combined/ctrl_36_1.png
# Saved scanpath image for ctrl_73_1.pkl as data_combined/ctrl_73_1.png
# Saved scanpath image for ctrl_55_2.pkl as data_combined/ctrl_55_2.png
# Saved scanpath image for bar_41_1.pkl as data_combined/bar_41_1.png
# Saved scanpath image for link_33_0.pkl as data_combined/link_33_0.png
# Saved scanpath image for bar_22_2.pkl as data_combined/bar_22_2.png
# Saved scanpath image for link_15_3.pkl as data_combined/link_15_3.png
# Saved scanpath image for bar_9_2.pkl as data_combined/bar_9_2.png
# Saved scanpath image for ctrl_71_3.pkl as data_combined/ctrl_71_3.png
# Saved scanpath image for ctrl_1_0.pkl as data_combined/ctrl_1_0.png
# Saved scanpath image for ctrl_12_0.pkl as data_combined/ctrl_12_0.png
# Saved scanpath image for bar_43_3.pkl as data_combined/bar_43_3.png
# Saved scanpath image for link_17_1.pkl as data_combined/link_17_1.png
# Saved scanpath image for bar_20_0.pkl as data_combined/bar_20_0.png
# Saved scanpath image for bar_20_1.pkl as data_combined/bar_20_1.png
# Saved scanpath image for link_17_0.pkl as data_combined/link_17_0.png
# Saved scanpath image for bar_43_2.pkl as data_combined/bar_43_2.png
# Saved scanpath image for ctrl_12_1.pkl as data_combined/ctrl_12_1.png
# Saved scanpath image for ctrl_71_2.pkl as data_combined/ctrl_71_2.png
# Saved scanpath image for ctrl_1_1.pkl as data_combined/ctrl_1_1.png
# Saved scanpath image for bar_9_3.pkl as data_combined/bar_9_3.png
# Saved scanpath image for link_15_2.pkl as data_combined/link_15_2.png
# Saved scanpath image for bar_22_3.pkl as data_combined/bar_22_3.png
# Saved scanpath image for bar_41_0.pkl as data_combined/bar_41_0.png
# Saved scanpath image for link_33_1.pkl as data_combined/link_33_1.png
# Saved scanpath image for ctrl_55_3.pkl as data_combined/ctrl_55_3.png
# Saved scanpath image for ctrl_36_0.pkl as data_combined/ctrl_36_0.png
# Saved scanpath image for ctrl_73_0.pkl as data_combined/ctrl_73_0.png
# Saved scanpath image for bar_81_0.pkl as data_combined/bar_81_0.png
# Saved scanpath image for ctrl_68_3.pkl as data_combined/ctrl_68_3.png
# Saved scanpath image for bar_39_0.pkl as data_combined/bar_39_0.png
# Saved scanpath image for ctrl_95_3.pkl as data_combined/ctrl_95_3.png
# Saved scanpath image for ctrl_97_1.pkl as data_combined/ctrl_97_1.png
# Saved scanpath image for ctrl_97_3.pkl as data_combined/ctrl_97_3.png
# Saved scanpath image for ctrl_95_1.pkl as data_combined/ctrl_95_1.png
# Saved scanpath image for bar_39_2.pkl as data_combined/bar_39_2.png
# Saved scanpath image for ctrl_68_1.pkl as data_combined/ctrl_68_1.png
# Saved scanpath image for bar_81_2.pkl as data_combined/bar_81_2.png
# Saved scanpath image for ctrl_55_1.pkl as data_combined/ctrl_55_1.png
# Saved scanpath image for ctrl_73_2.pkl as data_combined/ctrl_73_2.png
# Saved scanpath image for ctrl_36_2.pkl as data_combined/ctrl_36_2.png
# Saved scanpath image for bar_22_1.pkl as data_combined/bar_22_1.png
# Saved scanpath image for link_15_0.pkl as data_combined/link_15_0.png
# Saved scanpath image for link_33_3.pkl as data_combined/link_33_3.png
# Saved scanpath image for bar_41_2.pkl as data_combined/bar_41_2.png
# Saved scanpath image for bar_9_1.pkl as data_combined/bar_9_1.png
# Saved scanpath image for ctrl_12_3.pkl as data_combined/ctrl_12_3.png
# Saved scanpath image for ctrl_1_3.pkl as data_combined/ctrl_1_3.png
# Saved scanpath image for ctrl_71_0.pkl as data_combined/ctrl_71_0.png
# Saved scanpath image for link_17_2.pkl as data_combined/link_17_2.png
# Saved scanpath image for bar_20_3.pkl as data_combined/bar_20_3.png
# Saved scanpath image for bar_43_0.pkl as data_combined/bar_43_0.png
# Saved scanpath image for bar_43_1.pkl as data_combined/bar_43_1.png
# Saved scanpath image for bar_20_2.pkl as data_combined/bar_20_2.png
# Saved scanpath image for link_17_3.pkl as data_combined/link_17_3.png
# Saved scanpath image for ctrl_1_2.pkl as data_combined/ctrl_1_2.png
# Saved scanpath image for ctrl_71_1.pkl as data_combined/ctrl_71_1.png
# Saved scanpath image for ctrl_12_2.pkl as data_combined/ctrl_12_2.png
# Saved scanpath image for bar_9_0.pkl as data_combined/bar_9_0.png
# Saved scanpath image for link_33_2.pkl as data_combined/link_33_2.png
# Saved scanpath image for bar_41_3.pkl as data_combined/bar_41_3.png
# Saved scanpath image for link_15_1.pkl as data_combined/link_15_1.png
# Saved scanpath image for bar_22_0.pkl as data_combined/bar_22_0.png
# Saved scanpath image for ctrl_73_3.pkl as data_combined/ctrl_73_3.png
# Saved scanpath image for ctrl_36_3.pkl as data_combined/ctrl_36_3.png
# Saved scanpath image for ctrl_55_0.pkl as data_combined/ctrl_55_0.png
# Saved scanpath image for ctrl_68_0.pkl as data_combined/ctrl_68_0.png
# Saved scanpath image for bar_81_3.pkl as data_combined/bar_81_3.png
# Saved scanpath image for bar_39_3.pkl as data_combined/bar_39_3.png
# Saved scanpath image for ctrl_95_0.pkl as data_combined/ctrl_95_0.png
# Saved scanpath image for ctrl_97_2.pkl as data_combined/ctrl_97_2.png
# Saved scanpath image for ctrl_77_3.pkl as data_combined/ctrl_77_3.png
# Saved scanpath image for link_8_0.pkl as data_combined/link_8_0.png
# Saved scanpath image for bar_63_0.pkl as data_combined/bar_63_0.png
# Saved scanpath image for link_11_1.pkl as data_combined/link_11_1.png
# Saved scanpath image for ctrl_30_1.pkl as data_combined/ctrl_30_1.png
# Saved scanpath image for ctrl_75_1.pkl as data_combined/ctrl_75_1.png
# Saved scanpath image for ctrl_16_2.pkl as data_combined/ctrl_16_2.png
# Saved scanpath image for link_35_0.pkl as data_combined/link_35_0.png
# Saved scanpath image for bar_24_2.pkl as data_combined/bar_24_2.png
# Saved scanpath image for link_13_3.pkl as data_combined/link_13_3.png
# Saved scanpath image for ctrl_88_1.pkl as data_combined/ctrl_88_1.png
# Saved scanpath image for ctrl_93_2.pkl as data_combined/ctrl_93_2.png
# Saved scanpath image for bar_78_3.pkl as data_combined/bar_78_3.png
# Saved scanpath image for ctrl_91_0.pkl as data_combined/ctrl_91_0.png
# Saved scanpath image for bar_85_3.pkl as data_combined/bar_85_3.png
# Saved scanpath image for bar_85_2.pkl as data_combined/bar_85_2.png
# Saved scanpath image for bar_78_2.pkl as data_combined/bar_78_2.png
# Saved scanpath image for ctrl_91_1.pkl as data_combined/ctrl_91_1.png
# Saved scanpath image for ctrl_93_3.pkl as data_combined/ctrl_93_3.png
# Saved scanpath image for ctrl_88_0.pkl as data_combined/ctrl_88_0.png
# Saved scanpath image for link_13_2.pkl as data_combined/link_13_2.png
# Saved scanpath image for bar_24_3.pkl as data_combined/bar_24_3.png
# Saved scanpath image for link_35_1.pkl as data_combined/link_35_1.png
# Saved scanpath image for ctrl_16_3.pkl as data_combined/ctrl_16_3.png
# Saved scanpath image for ctrl_30_0.pkl as data_combined/ctrl_30_0.png
# Saved scanpath image for ctrl_75_0.pkl as data_combined/ctrl_75_0.png
# Saved scanpath image for bar_63_1.pkl as data_combined/bar_63_1.png
# Saved scanpath image for link_11_0.pkl as data_combined/link_11_0.png
# Saved scanpath image for link_8_1.pkl as data_combined/link_8_1.png
# Saved scanpath image for ctrl_77_2.pkl as data_combined/ctrl_77_2.png
# Saved scanpath image for ctrl_77_0.pkl as data_combined/ctrl_77_0.png
# Saved scanpath image for link_8_3.pkl as data_combined/link_8_3.png
# Saved scanpath image for link_11_2.pkl as data_combined/link_11_2.png
# Saved scanpath image for bar_63_3.pkl as data_combined/bar_63_3.png
# Saved scanpath image for ctrl_16_1.pkl as data_combined/ctrl_16_1.png
# Saved scanpath image for ctrl_75_2.pkl as data_combined/ctrl_75_2.png
# Saved scanpath image for ctrl_30_2.pkl as data_combined/ctrl_30_2.png
# Saved scanpath image for bar_24_1.pkl as data_combined/bar_24_1.png
# Saved scanpath image for link_13_0.pkl as data_combined/link_13_0.png
# Saved scanpath image for ctrl_88_2.pkl as data_combined/ctrl_88_2.png
# Saved scanpath image for link_35_3.pkl as data_combined/link_35_3.png
# Saved scanpath image for ctrl_93_1.pkl as data_combined/ctrl_93_1.png
# Saved scanpath image for ctrl_91_3.pkl as data_combined/ctrl_91_3.png
# Saved scanpath image for bar_78_0.pkl as data_combined/bar_78_0.png
# Saved scanpath image for bar_85_0.pkl as data_combined/bar_85_0.png
# Saved scanpath image for bar_85_1.pkl as data_combined/bar_85_1.png
# Saved scanpath image for ctrl_91_2.pkl as data_combined/ctrl_91_2.png
# Saved scanpath image for bar_78_1.pkl as data_combined/bar_78_1.png
# Saved scanpath image for ctrl_93_0.pkl as data_combined/ctrl_93_0.png
# Saved scanpath image for link_35_2.pkl as data_combined/link_35_2.png
# Saved scanpath image for ctrl_88_3.pkl as data_combined/ctrl_88_3.png
# Saved scanpath image for link_13_1.pkl as data_combined/link_13_1.png
# Saved scanpath image for bar_24_0.pkl as data_combined/bar_24_0.png
# Saved scanpath image for ctrl_75_3.pkl as data_combined/ctrl_75_3.png
# Saved scanpath image for ctrl_30_3.pkl as data_combined/ctrl_30_3.png
# Saved scanpath image for ctrl_16_0.pkl as data_combined/ctrl_16_0.png
# Saved scanpath image for link_11_3.pkl as data_combined/link_11_3.png
# Saved scanpath image for bar_63_2.pkl as data_combined/bar_63_2.png
# Saved scanpath image for link_8_2.pkl as data_combined/link_8_2.png
# Saved scanpath image for ctrl_77_1.pkl as data_combined/ctrl_77_1.png
# Saved scanpath image for link_6_0.pkl as data_combined/link_6_0.png
# Saved scanpath image for ctrl_84_3.pkl as data_combined/ctrl_84_3.png
# Saved scanpath image for ctrl_79_3.pkl as data_combined/ctrl_79_3.png
# Saved scanpath image for ctrl_9_0.pkl as data_combined/ctrl_9_0.png
# Saved scanpath image for link_4_2.pkl as data_combined/link_4_2.png
# Saved scanpath image for bar_1_2.pkl as data_combined/bar_1_2.png
# Saved scanpath image for bar_49_1.pkl as data_combined/bar_49_1.png
# Saved scanpath image for ctrl_18_2.pkl as data_combined/ctrl_18_2.png
# Saved scanpath image for ctrl_25_2.pkl as data_combined/ctrl_25_2.png
# Saved scanpath image for ctrl_60_2.pkl as data_combined/ctrl_60_2.png
# Saved scanpath image for ctrl_46_1.pkl as data_combined/ctrl_46_1.png
# Saved scanpath image for link_20_3.pkl as data_combined/link_20_3.png
# Saved scanpath image for bar_17_2.pkl as data_combined/bar_17_2.png
# Saved scanpath image for ctrl_62_0.pkl as data_combined/ctrl_62_0.png
# Saved scanpath image for bar_15_0.pkl as data_combined/bar_15_0.png
# Saved scanpath image for bar_50_0.pkl as data_combined/bar_50_0.png
# Saved scanpath image for bar_15_1.pkl as data_combined/bar_15_1.png
# Saved scanpath image for bar_50_1.pkl as data_combined/bar_50_1.png
# Saved scanpath image for ctrl_62_1.pkl as data_combined/ctrl_62_1.png
# Saved scanpath image for bar_17_3.pkl as data_combined/bar_17_3.png
# Saved scanpath image for link_20_2.pkl as data_combined/link_20_2.png
# Saved scanpath image for ctrl_46_0.pkl as data_combined/ctrl_46_0.png
# Saved scanpath image for ctrl_25_3.pkl as data_combined/ctrl_25_3.png
# Saved scanpath image for ctrl_60_3.pkl as data_combined/ctrl_60_3.png
# Saved scanpath image for ctrl_18_3.pkl as data_combined/ctrl_18_3.png
# Saved scanpath image for bar_49_0.pkl as data_combined/bar_49_0.png
# Saved scanpath image for bar_1_3.pkl as data_combined/bar_1_3.png
# Saved scanpath image for link_4_3.pkl as data_combined/link_4_3.png
# Saved scanpath image for ctrl_79_2.pkl as data_combined/ctrl_79_2.png
# Saved scanpath image for ctrl_9_1.pkl as data_combined/ctrl_9_1.png
# Saved scanpath image for ctrl_84_2.pkl as data_combined/ctrl_84_2.png
# Saved scanpath image for link_6_1.pkl as data_combined/link_6_1.png
# Saved scanpath image for link_6_3.pkl as data_combined/link_6_3.png
# Saved scanpath image for ctrl_84_0.pkl as data_combined/ctrl_84_0.png
# Saved scanpath image for ctrl_9_3.pkl as data_combined/ctrl_9_3.png
# Saved scanpath image for ctrl_79_0.pkl as data_combined/ctrl_79_0.png
# Saved scanpath image for bar_1_1.pkl as data_combined/bar_1_1.png
# Saved scanpath image for link_4_1.pkl as data_combined/link_4_1.png
# Saved scanpath image for bar_49_2.pkl as data_combined/bar_49_2.png
# Saved scanpath image for ctrl_18_1.pkl as data_combined/ctrl_18_1.png
# Saved scanpath image for ctrl_46_2.pkl as data_combined/ctrl_46_2.png
# Saved scanpath image for ctrl_60_1.pkl as data_combined/ctrl_60_1.png
# Saved scanpath image for ctrl_25_1.pkl as data_combined/ctrl_25_1.png
# Saved scanpath image for link_20_0.pkl as data_combined/link_20_0.png
# Saved scanpath image for bar_17_1.pkl as data_combined/bar_17_1.png
# Saved scanpath image for ctrl_62_3.pkl as data_combined/ctrl_62_3.png
# Saved scanpath image for bar_50_3.pkl as data_combined/bar_50_3.png
# Saved scanpath image for bar_15_3.pkl as data_combined/bar_15_3.png
# Saved scanpath image for bar_50_2.pkl as data_combined/bar_50_2.png
# Saved scanpath image for bar_15_2.pkl as data_combined/bar_15_2.png
# Saved scanpath image for ctrl_62_2.pkl as data_combined/ctrl_62_2.png
# Saved scanpath image for bar_17_0.pkl as data_combined/bar_17_0.png
# Saved scanpath image for link_20_1.pkl as data_combined/link_20_1.png
# Saved scanpath image for ctrl_60_0.pkl as data_combined/ctrl_60_0.png
# Saved scanpath image for ctrl_25_0.pkl as data_combined/ctrl_25_0.png
# Saved scanpath image for ctrl_46_3.pkl as data_combined/ctrl_46_3.png
# Saved scanpath image for ctrl_18_0.pkl as data_combined/ctrl_18_0.png
# Saved scanpath image for bar_49_3.pkl as data_combined/bar_49_3.png
# Saved scanpath image for link_4_0.pkl as data_combined/link_4_0.png
# Saved scanpath image for bar_1_0.pkl as data_combined/bar_1_0.png
# Saved scanpath image for ctrl_9_2.pkl as data_combined/ctrl_9_2.png
# Saved scanpath image for ctrl_79_1.pkl as data_combined/ctrl_79_1.png
# Saved scanpath image for ctrl_84_1.pkl as data_combined/ctrl_84_1.png
# Saved scanpath image for link_6_2.pkl as data_combined/link_6_2.png
# Saved scanpath image for ctrl_64_0.pkl as data_combined/ctrl_64_0.png
# Saved scanpath image for ctrl_21_0.pkl as data_combined/ctrl_21_0.png
# Saved scanpath image for ctrl_42_3.pkl as data_combined/ctrl_42_3.png
# Saved scanpath image for bar_13_0.pkl as data_combined/bar_13_0.png
# Saved scanpath image for bar_56_0.pkl as data_combined/bar_56_0.png
# Saved scanpath image for bar_35_3.pkl as data_combined/bar_35_3.png
# Saved scanpath image for ctrl_66_2.pkl as data_combined/ctrl_66_2.png
# Saved scanpath image for ctrl_40_1.pkl as data_combined/ctrl_40_1.png
# Saved scanpath image for bar_54_2.pkl as data_combined/bar_54_2.png
# Saved scanpath image for link_26_3.pkl as data_combined/link_26_3.png
# Saved scanpath image for bar_37_1.pkl as data_combined/bar_37_1.png
# Saved scanpath image for ctrl_80_1.pkl as data_combined/ctrl_80_1.png
# Saved scanpath image for bar_69_2.pkl as data_combined/bar_69_2.png
# Saved scanpath image for ctrl_38_1.pkl as data_combined/ctrl_38_1.png
# Saved scanpath image for link_19_1.pkl as data_combined/link_19_1.png
# Saved scanpath image for ctrl_82_3.pkl as data_combined/ctrl_82_3.png
# Saved scanpath image for bar_5_0.pkl as data_combined/bar_5_0.png
# Saved scanpath image for ctrl_59_0.pkl as data_combined/ctrl_59_0.png
# Saved scanpath image for ctrl_59_1.pkl as data_combined/ctrl_59_1.png
# Saved scanpath image for bar_5_1.pkl as data_combined/bar_5_1.png
# Saved scanpath image for ctrl_82_2.pkl as data_combined/ctrl_82_2.png
# Saved scanpath image for link_19_0.pkl as data_combined/link_19_0.png
# Saved scanpath image for ctrl_38_0.pkl as data_combined/ctrl_38_0.png
# Saved scanpath image for ctrl_80_0.pkl as data_combined/ctrl_80_0.png
# Saved scanpath image for bar_69_3.pkl as data_combined/bar_69_3.png
# Saved scanpath image for bar_37_0.pkl as data_combined/bar_37_0.png
# Saved scanpath image for bar_54_3.pkl as data_combined/bar_54_3.png
# Saved scanpath image for link_26_2.pkl as data_combined/link_26_2.png
# Saved scanpath image for ctrl_40_0.pkl as data_combined/ctrl_40_0.png
# Saved scanpath image for ctrl_66_3.pkl as data_combined/ctrl_66_3.png
# Saved scanpath image for bar_35_2.pkl as data_combined/bar_35_2.png
# Saved scanpath image for bar_13_1.pkl as data_combined/bar_13_1.png
# Saved scanpath image for bar_56_1.pkl as data_combined/bar_56_1.png
# Saved scanpath image for ctrl_42_2.pkl as data_combined/ctrl_42_2.png
# Saved scanpath image for ctrl_64_1.pkl as data_combined/ctrl_64_1.png
# Saved scanpath image for ctrl_21_1.pkl as data_combined/ctrl_21_1.png
# Saved scanpath image for ctrl_42_0.pkl as data_combined/ctrl_42_0.png
# Saved scanpath image for ctrl_21_3.pkl as data_combined/ctrl_21_3.png
# Saved scanpath image for ctrl_64_3.pkl as data_combined/ctrl_64_3.png
# Saved scanpath image for bar_35_0.pkl as data_combined/bar_35_0.png
# Saved scanpath image for bar_56_3.pkl as data_combined/bar_56_3.png
# Saved scanpath image for bar_13_3.pkl as data_combined/bar_13_3.png
# Saved scanpath image for ctrl_40_2.pkl as data_combined/ctrl_40_2.png
# Saved scanpath image for ctrl_66_1.pkl as data_combined/ctrl_66_1.png
# Saved scanpath image for bar_37_2.pkl as data_combined/bar_37_2.png
# Saved scanpath image for link_26_0.pkl as data_combined/link_26_0.png
# Saved scanpath image for bar_54_1.pkl as data_combined/bar_54_1.png
# Saved scanpath image for bar_69_1.pkl as data_combined/bar_69_1.png
# Saved scanpath image for ctrl_80_2.pkl as data_combined/ctrl_80_2.png
# Saved scanpath image for ctrl_38_2.pkl as data_combined/ctrl_38_2.png
# Saved scanpath image for link_19_2.pkl as data_combined/link_19_2.png
# Saved scanpath image for ctrl_82_0.pkl as data_combined/ctrl_82_0.png
# Saved scanpath image for bar_5_3.pkl as data_combined/bar_5_3.png
# Saved scanpath image for ctrl_59_3.pkl as data_combined/ctrl_59_3.png
# Saved scanpath image for ctrl_59_2.pkl as data_combined/ctrl_59_2.png
# Saved scanpath image for bar_5_2.pkl as data_combined/bar_5_2.png
# Saved scanpath image for ctrl_82_1.pkl as data_combined/ctrl_82_1.png
# Saved scanpath image for link_19_3.pkl as data_combined/link_19_3.png
# Saved scanpath image for ctrl_38_3.pkl as data_combined/ctrl_38_3.png
# Saved scanpath image for bar_69_0.pkl as data_combined/bar_69_0.png
# Saved scanpath image for ctrl_80_3.pkl as data_combined/ctrl_80_3.png
# Saved scanpath image for link_26_1.pkl as data_combined/link_26_1.png
# Saved scanpath image for bar_54_0.pkl as data_combined/bar_54_0.png
# Saved scanpath image for bar_37_3.pkl as data_combined/bar_37_3.png
# Saved scanpath image for ctrl_66_0.pkl as data_combined/ctrl_66_0.png
# Saved scanpath image for ctrl_40_3.pkl as data_combined/ctrl_40_3.png
# Saved scanpath image for bar_56_2.pkl as data_combined/bar_56_2.png
# Saved scanpath image for bar_13_2.pkl as data_combined/bar_13_2.png
# Saved scanpath image for bar_35_1.pkl as data_combined/bar_35_1.png
# Saved scanpath image for ctrl_21_2.pkl as data_combined/ctrl_21_2.png
# Saved scanpath image for ctrl_64_2.pkl as data_combined/ctrl_64_2.png
# Saved scanpath image for ctrl_42_1.pkl as data_combined/ctrl_42_1.png
# Saved scanpath image for ctrl_45_0.pkl as data_combined/ctrl_45_0.png
# Saved scanpath image for ctrl_63_3.pkl as data_combined/ctrl_63_3.png
# Saved scanpath image for ctrl_26_3.pkl as data_combined/ctrl_26_3.png
# Saved scanpath image for bar_77_0.pkl as data_combined/bar_77_0.png
# Saved scanpath image for link_23_2.pkl as data_combined/link_23_2.png
# Saved scanpath image for bar_14_3.pkl as data_combined/bar_14_3.png
# Saved scanpath image for bar_51_3.pkl as data_combined/bar_51_3.png
# Saved scanpath image for ctrl_61_1.pkl as data_combined/ctrl_61_1.png
# Saved scanpath image for bar_30_2.pkl as data_combined/bar_30_2.png
# Saved scanpath image for bar_75_2.pkl as data_combined/bar_75_2.png
# Saved scanpath image for link_21_0.pkl as data_combined/link_21_0.png
# Saved scanpath image for link_5_1.pkl as data_combined/link_5_1.png
# Saved scanpath image for ctrl_19_1.pkl as data_combined/ctrl_19_1.png
# Saved scanpath image for bar_2_3.pkl as data_combined/bar_2_3.png
# Saved scanpath image for bar_29_3.pkl as data_combined/bar_29_3.png
# Saved scanpath image for ctrl_85_0.pkl as data_combined/ctrl_85_0.png
# Saved scanpath image for ctrl_78_0.pkl as data_combined/ctrl_78_0.png
# Saved scanpath image for ctrl_78_1.pkl as data_combined/ctrl_78_1.png
# Saved scanpath image for ctrl_85_1.pkl as data_combined/ctrl_85_1.png
# Saved scanpath image for bar_29_2.pkl as data_combined/bar_29_2.png
# Saved scanpath image for bar_2_2.pkl as data_combined/bar_2_2.png
# Saved scanpath image for ctrl_19_0.pkl as data_combined/ctrl_19_0.png
# Saved scanpath image for link_5_0.pkl as data_combined/link_5_0.png
# Saved scanpath image for link_21_1.pkl as data_combined/link_21_1.png
# Saved scanpath image for bar_30_3.pkl as data_combined/bar_30_3.png
# Saved scanpath image for bar_75_3.pkl as data_combined/bar_75_3.png
# Saved scanpath image for ctrl_61_0.pkl as data_combined/ctrl_61_0.png
# Saved scanpath image for bar_14_2.pkl as data_combined/bar_14_2.png
# Saved scanpath image for link_23_3.pkl as data_combined/link_23_3.png
# Saved scanpath image for bar_51_2.pkl as data_combined/bar_51_2.png
# Saved scanpath image for bar_77_1.pkl as data_combined/bar_77_1.png
# Saved scanpath image for ctrl_63_2.pkl as data_combined/ctrl_63_2.png
# Saved scanpath image for ctrl_26_2.pkl as data_combined/ctrl_26_2.png
# Saved scanpath image for ctrl_45_1.pkl as data_combined/ctrl_45_1.png
# Saved scanpath image for ctrl_26_0.pkl as data_combined/ctrl_26_0.png
# Saved scanpath image for ctrl_63_0.pkl as data_combined/ctrl_63_0.png
# Saved scanpath image for ctrl_45_3.pkl as data_combined/ctrl_45_3.png
# Saved scanpath image for bar_51_0.pkl as data_combined/bar_51_0.png
# Saved scanpath image for link_23_1.pkl as data_combined/link_23_1.png
# Saved scanpath image for bar_14_0.pkl as data_combined/bar_14_0.png
# Saved scanpath image for bar_77_3.pkl as data_combined/bar_77_3.png
# Saved scanpath image for ctrl_61_2.pkl as data_combined/ctrl_61_2.png
# Saved scanpath image for link_21_3.pkl as data_combined/link_21_3.png
# Saved scanpath image for bar_75_1.pkl as data_combined/bar_75_1.png
# Saved scanpath image for bar_30_1.pkl as data_combined/bar_30_1.png
# Saved scanpath image for link_5_2.pkl as data_combined/link_5_2.png
# Saved scanpath image for ctrl_19_2.pkl as data_combined/ctrl_19_2.png
# Saved scanpath image for bar_2_0.pkl as data_combined/bar_2_0.png
# Saved scanpath image for bar_29_0.pkl as data_combined/bar_29_0.png
# Saved scanpath image for ctrl_85_3.pkl as data_combined/ctrl_85_3.png
# Saved scanpath image for ctrl_78_3.pkl as data_combined/ctrl_78_3.png
# Saved scanpath image for ctrl_78_2.pkl as data_combined/ctrl_78_2.png
# Saved scanpath image for ctrl_85_2.pkl as data_combined/ctrl_85_2.png
# Saved scanpath image for bar_29_1.pkl as data_combined/bar_29_1.png
# Saved scanpath image for bar_2_1.pkl as data_combined/bar_2_1.png
# Saved scanpath image for ctrl_19_3.pkl as data_combined/ctrl_19_3.png
# Saved scanpath image for link_5_3.pkl as data_combined/link_5_3.png
# Saved scanpath image for bar_75_0.pkl as data_combined/bar_75_0.png
# Saved scanpath image for bar_30_0.pkl as data_combined/bar_30_0.png
# Saved scanpath image for link_21_2.pkl as data_combined/link_21_2.png
# Saved scanpath image for ctrl_61_3.pkl as data_combined/ctrl_61_3.png
# Saved scanpath image for bar_77_2.pkl as data_combined/bar_77_2.png
# Saved scanpath image for bar_51_1.pkl as data_combined/bar_51_1.png
# Saved scanpath image for bar_14_1.pkl as data_combined/bar_14_1.png
# Saved scanpath image for link_23_0.pkl as data_combined/link_23_0.png
# Saved scanpath image for ctrl_45_2.pkl as data_combined/ctrl_45_2.png
# Saved scanpath image for ctrl_26_1.pkl as data_combined/ctrl_26_1.png
# Saved scanpath image for ctrl_63_1.pkl as data_combined/ctrl_63_1.png
# Saved scanpath image for link_18_2.pkl as data_combined/link_18_2.png
# Saved scanpath image for bar_4_3.pkl as data_combined/bar_4_3.png
# Saved scanpath image for link_1_3.pkl as data_combined/link_1_3.png
# Saved scanpath image for ctrl_58_3.pkl as data_combined/ctrl_58_3.png
# Saved scanpath image for ctrl_81_2.pkl as data_combined/ctrl_81_2.png
# Saved scanpath image for bar_68_1.pkl as data_combined/bar_68_1.png
# Saved scanpath image for bar_6_1.pkl as data_combined/bar_6_1.png
# Saved scanpath image for link_3_1.pkl as data_combined/link_3_1.png
# Saved scanpath image for ctrl_67_1.pkl as data_combined/ctrl_67_1.png
# Saved scanpath image for bar_73_2.pkl as data_combined/bar_73_2.png
# Saved scanpath image for bar_10_1.pkl as data_combined/bar_10_1.png
# Saved scanpath image for ctrl_65_3.pkl as data_combined/ctrl_65_3.png
# Saved scanpath image for bar_71_0.pkl as data_combined/bar_71_0.png
# Saved scanpath image for bar_34_0.pkl as data_combined/bar_34_0.png
# Saved scanpath image for bar_12_3.pkl as data_combined/bar_12_3.png
# Saved scanpath image for bar_12_2.pkl as data_combined/bar_12_2.png
# Saved scanpath image for bar_71_1.pkl as data_combined/bar_71_1.png
# Saved scanpath image for bar_34_1.pkl as data_combined/bar_34_1.png
# Saved scanpath image for ctrl_65_2.pkl as data_combined/ctrl_65_2.png
# Saved scanpath image for bar_10_0.pkl as data_combined/bar_10_0.png
# Saved scanpath image for bar_73_3.pkl as data_combined/bar_73_3.png
# Saved scanpath image for ctrl_67_0.pkl as data_combined/ctrl_67_0.png
# Saved scanpath image for link_3_0.pkl as data_combined/link_3_0.png
# Saved scanpath image for bar_6_0.pkl as data_combined/bar_6_0.png
# Saved scanpath image for ctrl_81_3.pkl as data_combined/ctrl_81_3.png
# Saved scanpath image for bar_68_0.pkl as data_combined/bar_68_0.png
# Saved scanpath image for ctrl_58_2.pkl as data_combined/ctrl_58_2.png
# Saved scanpath image for link_1_2.pkl as data_combined/link_1_2.png
# Saved scanpath image for bar_4_2.pkl as data_combined/bar_4_2.png
# Saved scanpath image for link_18_3.pkl as data_combined/link_18_3.png
# Saved scanpath image for link_18_1.pkl as data_combined/link_18_1.png
# Saved scanpath image for link_1_0.pkl as data_combined/link_1_0.png
# Saved scanpath image for bar_4_0.pkl as data_combined/bar_4_0.png
# Saved scanpath image for ctrl_58_0.pkl as data_combined/ctrl_58_0.png
# Saved scanpath image for bar_68_2.pkl as data_combined/bar_68_2.png
# Saved scanpath image for ctrl_81_1.pkl as data_combined/ctrl_81_1.png
# Saved scanpath image for link_3_2.pkl as data_combined/link_3_2.png
# Saved scanpath image for bar_6_2.pkl as data_combined/bar_6_2.png
# Saved scanpath image for ctrl_67_2.pkl as data_combined/ctrl_67_2.png
# Saved scanpath image for bar_10_2.pkl as data_combined/bar_10_2.png
# Saved scanpath image for bar_73_1.pkl as data_combined/bar_73_1.png
# Saved scanpath image for ctrl_65_0.pkl as data_combined/ctrl_65_0.png
# Saved scanpath image for bar_12_0.pkl as data_combined/bar_12_0.png
# Saved scanpath image for bar_34_3.pkl as data_combined/bar_34_3.png
# Saved scanpath image for bar_71_3.pkl as data_combined/bar_71_3.png
# Saved scanpath image for bar_34_2.pkl as data_combined/bar_34_2.png
# Saved scanpath image for bar_71_2.pkl as data_combined/bar_71_2.png
# Saved scanpath image for bar_12_1.pkl as data_combined/bar_12_1.png
# Saved scanpath image for ctrl_65_1.pkl as data_combined/ctrl_65_1.png
# Saved scanpath image for bar_73_0.pkl as data_combined/bar_73_0.png
# Saved scanpath image for bar_10_3.pkl as data_combined/bar_10_3.png
# Saved scanpath image for ctrl_67_3.pkl as data_combined/ctrl_67_3.png
# Saved scanpath image for bar_6_3.pkl as data_combined/bar_6_3.png
# Saved scanpath image for link_3_3.pkl as data_combined/link_3_3.png
# Saved scanpath image for bar_68_3.pkl as data_combined/bar_68_3.png
# Saved scanpath image for ctrl_81_0.pkl as data_combined/ctrl_81_0.png
# Saved scanpath image for ctrl_58_1.pkl as data_combined/ctrl_58_1.png
# Saved scanpath image for bar_4_1.pkl as data_combined/bar_4_1.png
# Saved scanpath image for link_1_1.pkl as data_combined/link_1_1.png
# Saved scanpath image for link_18_0.pkl as data_combined/link_18_0.png
